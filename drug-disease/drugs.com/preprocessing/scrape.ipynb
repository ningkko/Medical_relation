# %%
from bs4 import BeautifulSoup
import requests

url = "https://www.drugs.com/medical_conditions.html"
req = requests.get(url)
soup = BeautifulSoup(req.content, 'html.parser')

print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Medical Treatment Options for Diseases &amp; Conditions - Drugs.com
#   </title>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="ie=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="Find your disease or condition and discover what medication options are available for you. Sort drugs by popularity, reviews, ratings and more..." name="description"/>
#   <meta content="origin-when-cross-origin" name="referrer"/>
#   <!-- Facebook Open Graph Summary -->
#   <meta content="Medical Treatment Options for Diseases &amp; Conditions - Drugs.com" property="og:title"/>
#   <meta content="https://www.drugs.com/img/social/ddc-facebook-icon.png" property="og:image"/>
#   <meta content="Drugs.com" property="og:site_name"/>
#   <meta content="en_US" property="og:locale"/>
#   <meta content="article" property="og:type"/>
#   <meta content="1470988726468809" property="fb:app_id"/>
#   <meta content="https://www.facebook.com/Drugscom" property="article:author"/>
#   <meta content="https://www.facebook.com/Drugscom" property="article:publisher"/>
#   <meta content="Find your disease or condition and discover what medication options are available for you. Sort drugs by popularity, reviews, ratings and more..." property="og:description"/>
#   <meta content="https://www.drugs.com/medical_conditions.html" property="og:url"/>
#   <!-- Twitter Summary Card -->
#   <meta content="summary" name="twitter:card"/>
#   <meta content="@drugscom" name="twitter:site"/>
#   <meta content="Medical Treatment Options for Diseases &amp; Conditions - Drugs.com" name="twitter:title"/>
#   <meta content="https://www.drugs.com/img/social/ddc-facebook-icon.png" name="twitter:image"/>
#   <meta content="Find your disease or condition and discover what medication options are available for you. Sort drugs by popularity, reviews, ratings and more..." name="twitter:description"/>
#   <link href="https://www.drugs.com/medical_conditions.html" rel="canonical"/>
#   <!-- Favicons -->
#   <link href="/manifest.json" rel="manifest"/>
#   <link href="/img/favicon/ddc-icon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#   <link href="/img/favicon/ddc-icon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
#   <link href="/img/favicon/apple-touch-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/>
#   <link href="/img/favicon/apple-touch-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
#   <link href="/img/favicon/apple-touch-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
#   <link href="/img/favicon/apple-touch-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
#   <meta content="#2a9cd7" name="theme-color"/>
#   <style>
#    img {max-width: 100%; height: auto;}
# .contentBox {overflow-wrap: break-word; word-wrap: break-word;}
#   </style>
#   <link href="/bundle/css/ddc-pack-base.min.625231d1.css" rel="stylesheet"/>
#   <link href="/bundle/css/ddc-pack-site.min.59f70303.css" rel="stylesheet"/>
#   <link href="/bundle/css/component/component.paging.min.1ac2bd3f.css" rel="stylesheet"/>
#   <link href="/bundle/css/ddc-print.min.b3696f6c.css" media="print" rel="stylesheet"/>
#   <link href="/opensearch.xml" rel="search" title="Drugs.com" type="application/opensearchdescription+xml"/>
#   <script type="application/ld+json">
#    [{"@context":"http://schema.org/","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","position":1,"name":"Treatment Options","item":{"@type":"MedicalWebPage","@id":"https://www.drugs.com/medical_conditions.html#"}}]},{"@context":"http://schema.org/","@type":"MedicalWebPage","@id":"https://www.drugs.com/medical_conditions.html","url":"https://www.drugs.com/medical_conditions.html","audience":{"@context":"https://schema.org","@type":"medicalAudience","audienceType":["Patient"]},"publisher":{"@context":"http://schema.org/","@type":"Organization","@id":"https://www.drugs.com/#organization","name":"Drugs.com","url":"https://www.drugs.com","logo":{"@context":"http://schema.org","@type":"ImageObject","url":"https://www.drugs.com/img/layout/ddc-amp-publisher-logo.png","width":600,"height":60}},"image":{"@type":"ImageObject","contentUrl":"https://www.drugs.com/img/layout/ddc-logo-organization.png","url":"https://www.drugs.com/img/layout/ddc-logo-organization.png","caption":""},"name":"Treatment Options","description":"Find your disease or condition and discover what medication options are available for you. Sort drugs by popularity, reviews, ratings and more..."}]
#   </script>
#   <script>
#    (window.BOOMR_mq=window.BOOMR_mq||[]).push(["addVar",{"rua.upush":"false","rua.cpush":"false","rua.upre":"false","rua.cpre":"false","rua.uprl":"false","rua.cprl":"false","rua.cprf":"false","rua.trans":"","rua.cook":"false","rua.ims":"false","rua.ufprl":"false","rua.cfprl":"false"}]);
#   </script>
#   <script>
#    !function(a){var e="https://s.go-mpulse.net/boomerang/",t="addEventListener";if("False"=="True")a.BOOMR_config=a.BOOMR_config||{},a.BOOMR_config.PageParams=a.BOOMR_config.PageParams||{},a.BOOMR_config.PageParams.pci=!0,e="https://s2.go-mpulse.net/boomerang/";if(window.BOOMR_API_key="7M5JF-NRG3P-HNUHC-65BD4-6NUYT",function(){function n(e){a.BOOMR_onload=e&&e.timeStamp||(new Date).getTime()}if(!a.BOOMR||!a.BOOMR.version&&!a.BOOMR.snippetExecuted){a.BOOMR=a.BOOMR||{},a.BOOMR.snippetExecuted=!0;var i,o,_,r=document.createElement("iframe");if(a[t])a[t]("load",n,!1);else if(a.attachEvent)a.attachEvent("onload",n);r.src="javascript:void(0)",r.title="",r.role="presentation",(r.frameElement||r).style.cssText="width:0;height:0;border:0;display:none;",_=document.getElementsByTagName("script")[0],_.parentNode.insertBefore(r,_);try{o=r.contentWindow.document}catch(O){i=document.domain,r.src="javascript:var d=document.open();d.domain='"+i+"';void(0);",o=r.contentWindow.document}o.open()._l=function(){var a=this.createElement("script");if(i)this.domain=i;a.id="boomr-if-as",a.src=e+"7M5JF-NRG3P-HNUHC-65BD4-6NUYT",BOOMR_lstart=(new Date).getTime(),this.body.appendChild(a)},o.write("<bo"+'dy onload="document._l();">'),o.close()}}(),"".length>0)if(a&&"performance"in a&&a.performance&&"function"==typeof a.performance.setResourceTimingBufferSize)a.performance.setResourceTimingBufferSize();!function(){if(BOOMR=a.BOOMR||{},BOOMR.plugins=BOOMR.plugins||{},!BOOMR.plugins.AK){var e=""=="true"?1:0,t="",n="jfm4qmtijxr2axxi4gbq-f-55f8f6d02-clientnsv4-s.akamaihd.net",i={"ak.v":"27","ak.cp":"184776","ak.ai":parseInt("133940",10),"ak.ol":"0","ak.cr":24,"ak.ipv":4,"ak.proto":"","ak.rid":"2bf8d998","ak.r":35804,"ak.a2":e,"ak.m":"dscx","ak.n":"essl","ak.bpcip":"73.89.200.0","ak.cport":59697,"ak.gh":"23.36.39.190","ak.quicv":"","ak.tlsv":"tls1.3","ak.0rtt":"","ak.csrc":"-","ak.acc":"reno","ak.t":"1592320387","ak.ak":"hOBiQwZUYzCg5VSAfCLimQ==...","ak.pv":"268"};if(""!==t)i["ak.ruds"]=t;var o={i:!1,av:function(e){var t="http.initiator";if(e&&(!e[t]||"spa_hard"===e[t]))i["ak.feo"]=void 0!==a.aFeoApplied?1:0,BOOMR.addVar(i)},rv:function(){var a=["ak.bpcip","ak.cport","ak.cr","ak.csrc","ak.gh","ak.ipv","ak.m","ak.n","ak.ol","ak.proto","ak.quicv","ak.tlsv","ak.0rtt","ak.r","ak.acc","ak.t"];BOOMR.removeVar(a)}};BOOMR.plugins.AK={akVars:i,akDNSPreFetchDomain:n,init:function(){if(!o.i){var a=BOOMR.subscribe;a("before_beacon",o.av,null,null),a("onbeacon",o.rv,null,null),o.i=!0}return this},is_complete:function(){return!0}}}}()}(window);
#   </script>
#  </head>
#  <body class="page-section-condition page-doctype-index page-medical-conditions-html">
#   <div class="layoutRightColWide" id="wrap">
#    <div id="inner-wrap">
#     <a accesskey="2" class="skipContent" href="#content">
#      Skip to Content
#     </a>
#     <header id="header">
#      <div class="top-container">
#       <div class="header-wrap container">
#        <div class="header">
#         <div class="brand">
#          <a class="logo-link" href="//www.drugs.com/">
#           <img alt="Drugs.com" class="logo" data-ga-action="Logo" data-ga-category="Top Nav" src="/img/layout/ddc-logo-retina.png"/>
#          </a>
#         </div>
#         <form action="/search.php" class="search-main" method="get">
#          <div class="input-group-attached">
#           <label class="label-placeholder" for="livesearch-main">
#            Search Drugs.com
#           </label>
#           <input accesskey="s" class="livesearch placeholder input-text webkit-speech" data-required="1" id="livesearch-main" maxlength="70" name="searchterm" placeholder="Search" type="text" value=""/>
#           <div class="search-filter">
#            <div class="nav-facade-active header-select-wrapper">
#             <span class="search-filter__label" data-value="search-alias=aps">
#              <span data-search-select-value="">
#               All
#              </span>
#              <i aria-hidden="true" class="search-filter__icon icon icon-arrow-down">
#              </i>
#             </span>
#             <label>
#              <span class="sr-only">
#               Select the section you want to search in
#              </span>
#              <select class="search-filter__select" data-search-select="" name="sources[]">
#               <option value="">
#                All
#               </option>
#               <option value="consumer">
#                Consumer
#               </option>
#               <option value="professional">
#                Professional
#               </option>
#               <option value="drugimages">
#                Pill ID
#               </option>
#               <option value="interactions">
#                Interactions
#               </option>
#               <option value="news">
#                News
#               </option>
#               <option value="fdaalerts">
#                FDA Alerts
#               </option>
#               <option value="newdrugapprovals">
#                Approvals
#               </option>
#               <option value="newdrugapplications">
#                Pipeline
#               </option>
#               <option value="clinicaltrials">
#                Clinical Trials
#               </option>
#               <option value="cg">
#                Care Notes
#               </option>
#               <option value="natural">
#                Natural Products
#               </option>
#              </select>
#             </label>
#            </div>
#           </div>
#           <a class="search-close" href="#">
#            <span class="sr-only">
#             Close
#            </span>
#            <i aria-hidden="true" class="icon icon-cross">
#            </i>
#           </a>
#           <button class="ddc-btn">
#            <span class="sr-only">
#             Search
#            </span>
#            <i aria-hidden="true" class="icon icon-search">
#            </i>
#           </button>
#          </div>
#          <div class="search-browse link-no-visited link-no-bold">
#           <span>
#            Browse all medications:
#           </span>
#           <span class="alpha-list">
#            <a data-ga-action="Alpha" data-ga-category="Top Nav" data-ga-label="a" href="/alpha/a.html">
#             a
#            </a>
#            <a data-ga-action="Alpha" data-ga-category="Top Nav" data-ga-label="b" href="/alpha/b.html">
#             b
#            </a>
#            <a data-ga-action="Alpha" data-ga-category="Top Nav" data-ga-label="c" href="/alpha/c.html">
#             c
#            </a>
#            <a data-ga-action="Alpha" data-ga-category="Top Nav" data-ga-label="d" href="/alpha/d.html">
#             d
#            </a>
#            <a data-ga-action="Alpha" data-ga-category="Top Nav" data-ga-label="e" href="/alpha/e.html">
#             e
#            </a>
#            <a data-ga-action="Alpha" data-ga-category="Top Nav" data-ga-label="f" href="/alpha/f.html">
#             f
#            </a>
#            <a data-ga-action="Alpha" data-ga-category="Top Nav" data-ga-label="g" href="/alpha/g.html">
#             g
#            </a>
#            <a data-ga-action="Alpha" data-ga-category="Top Nav" data-ga-label="h" href="/alpha/h.html">
#             h
#            </a>
#            <a data-ga-action="Alpha" data-ga-category="Top Nav" data-ga-label="i" href="/alpha/i.html">
#             i
#            </a>
#            <a data-ga-action="Alpha" data-ga-category="Top Nav" data-ga-label="j" href="/alpha/j.html">
#             j
#            </a>
#            <a data-ga-action="Alpha" data-ga-category="Top Nav" data-ga-label="k" href="/alpha/k.html">
#             k
#            </a>
#            <a data-ga-action="Alpha" data-ga-category="Top Nav" data-ga-label="l" href="/alpha/l.html">
#             l
#            </a>
#            <a data-ga-action="Alpha" data-ga-category="Top Nav" data-ga-label="m" href="/alpha/m.html">
#             m
#            </a>
#            <a data-ga-action="Alpha" data-ga-category="Top Nav" data-ga-label="n" href="/alpha/n.html">
#             n
#            </a>
#            <a data-ga-action="Alpha" data-ga-category="Top Nav" data-ga-label="o" href="/alpha/o.html">
#             o
#            </a>
#            <a data-ga-action="Alpha" data-ga-category="Top Nav" data-ga-label="p" href="/alpha/p.html">
#             p
#            </a>
#            <a data-ga-action="Alpha" data-ga-category="Top Nav" data-ga-label="q" href="/alpha/q.html">
#             q
#            </a>
#            <a data-ga-action="Alpha" data-ga-category="Top Nav" data-ga-label="r" href="/alpha/r.html">
#             r
#            </a>
#            <a data-ga-action="Alpha" data-ga-category="Top Nav" data-ga-label="s" href="/alpha/s.html">
#             s
#            </a>
#            <a data-ga-action="Alpha" data-ga-category="Top Nav" data-ga-label="t" href="/alpha/t.html">
#             t
#            </a>
#            <a data-ga-action="Alpha" data-ga-category="Top Nav" data-ga-label="u" href="/alpha/u.html">
#             u
#            </a>
#            <a data-ga-action="Alpha" data-ga-category="Top Nav" data-ga-label="v" href="/alpha/v.html">
#             v
#            </a>
#            <a data-ga-action="Alpha" data-ga-category="Top Nav" data-ga-label="w" href="/alpha/w.html">
#             w
#            </a>
#            <a data-ga-action="Alpha" data-ga-category="Top Nav" data-ga-label="x" href="/alpha/x.html">
#             x
#            </a>
#            <a data-ga-action="Alpha" data-ga-category="Top Nav" data-ga-label="y" href="/alpha/y.html">
#             y
#            </a>
#            <a data-ga-action="Alpha" data-ga-category="Top Nav" data-ga-label="z" href="/alpha/z.html">
#             z
#            </a>
#            <a data-ga-action="Alpha" data-ga-category="Top Nav" data-ga-label="0-9" href="/alpha/0-9.html">
#             0-9
#            </a>
#           </span>
#           <div class="search-browse-options float-right">
#            <a data-ga-action="Advanced Search" data-ga-category="Top Nav" href="/search_advanced.html">
#             Advanced Search
#            </a>
#           </div>
#          </div>
#         </form>
#         <div class="ddc-nav-account">
#          <a class="ddc-btn ddc-btn-empty ddc-btn-sm ddc-btn-register" href="/account/register/" rel="nofollow">
#           Register
#          </a>
#          <a class="ddc-btn ddc-btn-secondary ddc-btn-sm" href="/account/login/" rel="nofollow">
#           Sign In
#          </a>
#         </div>
#         <div class="nav-block">
#          <a class="ddc-btn ddc-btn-secondary" data-ga-action="Hamburger" data-ga-category="Top Nav" data-nav-toggle="" href="#" role="button">
#           <span class="label-placeholder">
#            Menu
#           </span>
#           <svg aria-hidden="true" focusable="false" height="24" width="24" xmlns="http://www.w3.org/2000/svg">
#            <path d="M4 11h16a1 1 0 0 1 0 2H4a1 1 0 0 1 0-2zm0-6h16a1 1 0 0 1 0 2H4a1 1 0 1 1 0-2zm0 12h16a1 1 0 0 1 0 2H4a1 1 0 0 1 0-2z">
#            </path>
#           </svg>
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#      <nav class="ddc-nav">
#       <div class="ddc-nav-mobile-header">
#        <a class="close-panel text-muted" data-nav-toggle="" href="#" role="button">
#         <img alt="" aria-hidden="true" class="logo" src="/img/layout/ddc-logo-retina.png" srcset="/img/layout/ddc-logo-retina.png 2x">
#          <span class="ddc-text-size-small">
#           <i aria-hidden="true" class="icon icon-cross">
#           </i>
#           Close
#          </span>
#         </img>
#        </a>
#       </div>
#       <ul>
#        <li class="ddc-nav-item subnav-open link-no-visited" data-subnav="account">
#         <a rel="nofollow">
#          Account
#         </a>
#         <ul>
#          <li>
#           <a href="/account/login/" rel="nofollow">
#            Sign In
#           </a>
#          </li>
#          <li>
#           <a href="/account/register/" rel="nofollow">
#            Register Now
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li class="ddc-nav-item" data-subnav="az">
#         <a href="#">
#          Drugs A-Z
#         </a>
#         <ul>
#          <li>
#           <a href="/drug_information.html">
#            A-Z Drug Index
#           </a>
#          </li>
#          <li>
#           <a href="/medical_conditions.html">
#            Treatment Options
#           </a>
#          </li>
#          <li>
#           <a href="/drug-classes.html">
#            Drugs by Class
#           </a>
#          </li>
#          <li>
#           <a href="/compare/">
#            Compare Drugs
#           </a>
#          </li>
#          <li>
#           <a href="/availability/">
#            Generic Drugs
#           </a>
#          </li>
#          <li>
#           <a href="/otc/">
#            OTC Drugs
#           </a>
#          </li>
#          <li>
#           <a href="/international/">
#            International Drugs
#           </a>
#          </li>
#          <li>
#           <a href="/npc/">
#            Natural Products
#           </a>
#          </li>
#          <li>
#           <a href="/sfx/">
#            Drug Side Effects
#           </a>
#          </li>
#          <li>
#           <a href="/dosage/">
#            Dosage Guides
#           </a>
#          </li>
#          <li>
#           <a href="/pregnancy/">
#            Pregnancy Warnings
#           </a>
#          </li>
#          <li>
#           <a href="/breastfeeding/">
#            Breastfeeding Warnings
#           </a>
#          </li>
#          <li>
#           <a href="/price-guide/">
#            Pricing &amp; Coupons
#           </a>
#          </li>
#          <li>
#           <a href="/inactive/">
#            Inactive Ingredients
#           </a>
#          </li>
#          <li>
#           <a href="/mtm_esp/">
#            Info en Español
#           </a>
#          </li>
#          <li>
#           <a href="/vet/">
#            Veterinary Products
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li class="ddc-nav-item">
#         <a href="/pill_identification.html">
#          Pill Identifier
#         </a>
#        </li>
#        <li class="ddc-nav-item">
#         <a href="/drug_interactions.html">
#          Interactions Checker
#         </a>
#        </li>
#        <li class="ddc-nav-item" data-subnav="news">
#         <a href="/news.html">
#          News &amp; Alerts
#         </a>
#        </li>
#        <li class="ddc-nav-item" data-subnav="pro">
#         <a href="/professionals.html">
#          Pro Edition
#         </a>
#        </li>
#        <li class="ddc-nav-item" data-subnav="more">
#         <a href="#">
#          More
#         </a>
#        </li>
#       </ul>
#      </nav>
#     </header>
#     <div class="topbanner-wrap">
#      <div class="topbanner-container">
#       <div class="display-ad display-ad-static display-ad-970x250" id="display-ad-1">
#       </div>
#      </div>
#     </div>
#     <div class="container" id="container">
#      <div class="clear" id="contentWrap">
#       <div class="content" id="content">
#        <div class="contentHead">
#         <nav aria-label="breadcrumb">
#          <ol class="ddc-breadcrumb ddc-breadcrumb-1">
#           <li aria-current="page" class="ddc-breadcrumb-item active">
#            <span class="overflow">
#             Treatment Options
#            </span>
#           </li>
#          </ol>
#         </nav>
#         <div class="noVisit page-icons page-icons-header" id="page-icons-header">
#          <input id="page_url" type="hidden" value="aHR0cHM6Ly93d3cuZHJ1Z3MuY29tL21lZGljYWxfY29uZGl0aW9ucy5odG1s"/>
#          <input id="page_title" type="hidden" value="Medical+Treatment+Options+for+Diseases+%26amp%3B+Conditions+-+Drugs.com"/>
#          <a class="iconGoPrint" data-action="print" data-ga-label="Print Top" href="#print" role="button">
#           <i class="icon icon-print">
#           </i>
#           Print
#          </a>
#          <a class="iconBookmark" href="#bookmark" onclick="ga('send', 'social', 'DDC', 'Save or Share Top');" role="button">
#           <i class="icon icon-share">
#           </i>
#           Share
#          </a>
#         </div>
#        </div>
#        <!-- google_ad_section_start -->
#        <div class="contentBox">
#         <h1>
#          Treatment Options
#         </h1>
#         <p>
#          Find your disease or condition and discover what medication options are available for you.
#         </p>
#         <div id="search">
#          <form action="/search.php" class="form-search form-search-condition noprint clearAfter" method="get">
#           <div class="input-group-attached rf-input-group-attached">
#            <input name="sources[]" type="hidden" value="condition"/>
#            <label class="label-placeholder" for="livesearch-condition">
#             Search
#            </label>
#            <input autocomplete="off" class="livesearch placeholder input-text" data-livesearch="condition" data-required="1" id="livesearch-condition" name="searchterm" placeholder="Enter a condition, e.g. acne" type="text" value="">
#             <input class="ddc-btn ddc-btn-search" type="submit" value="Search"/>
#            </input>
#           </div>
#          </form>
#         </div>
#         <h2>
#          Browse alphabetically
#         </h2>
#         <ul class="ddc-paging">
#          <li>
#           <a href="/condition/a.html">
#            A
#           </a>
#          </li>
#          <li>
#           <a href="/condition/b.html">
#            B
#           </a>
#          </li>
#          <li>
#           <a href="/condition/c.html">
#            C
#           </a>
#          </li>
#          <li>
#           <a href="/condition/d.html">
#            D
#           </a>
#          </li>
#          <li>
#           <a href="/condition/e.html">
#            E
#           </a>
#          </li>
#          <li>
#           <a href="/condition/f.html">
#            F
#           </a>
#          </li>
#          <li>
#           <a href="/condition/g.html">
#            G
#           </a>
#          </li>
#          <li>
#           <a href="/condition/h.html">
#            H
#           </a>
#          </li>
#          <li>
#           <a href="/condition/i.html">
#            I
#           </a>
#          </li>
#          <li>
#           <a href="/condition/j.html">
#            J
#           </a>
#          </li>
#          <li>
#           <a href="/condition/k.html">
#            K
#           </a>
#          </li>
#          <li>
#           <a href="/condition/l.html">
#            L
#           </a>
#          </li>
#          <li>
#           <a href="/condition/m.html">
#            M
#           </a>
#          </li>
#          <li>
#           <a href="/condition/n.html">
#            N
#           </a>
#          </li>
#          <li>
#           <a href="/condition/o.html">
#            O
#           </a>
#          </li>
#          <li>
#           <a href="/condition/p.html">
#            P
#           </a>
#          </li>
#          <li>
#           <a href="/condition/q.html">
#            Q
#           </a>
#          </li>
#          <li>
#           <a href="/condition/r.html">
#            R
#           </a>
#          </li>
#          <li>
#           <a href="/condition/s.html">
#            S
#           </a>
#          </li>
#          <li>
#           <a href="/condition/t.html">
#            T
#           </a>
#          </li>
#          <li>
#           <a href="/condition/u.html">
#            U
#           </a>
#          </li>
#          <li>
#           <a href="/condition/v.html">
#            V
#           </a>
#          </li>
#          <li>
#           <a href="/condition/w.html">
#            W
#           </a>
#          </li>
#          <li>
#           <a href="/condition/x.html">
#            X
#           </a>
#          </li>
#          <li>
#           <a href="/condition/y.html">
#            Y
#           </a>
#          </li>
#          <li>
#           <a href="/condition/z.html">
#            Z
#           </a>
#          </li>
#         </ul>
#         <h2>
#          Common treatment options for:
#         </h2>
#         <div class="boxList boxListTopDrugs">
#          <ul class="ddc-list-column-4">
#           <li>
#            <a href="/condition/acne.html">
#             Acne
#            </a>
#           </li>
#           <li>
#            <a href="/condition/attention-deficit-disorder.html">
#             ADHD
#            </a>
#           </li>
#           <li>
#            <a href="/condition/hiv-infection.html">
#             AIDS/HIV
#            </a>
#           </li>
#           <li>
#            <a href="/condition/allergies.html">
#             Allergies
#            </a>
#           </li>
#           <li>
#            <a href="/condition/alzheimer-s-disease.html">
#             Alzheimer's
#            </a>
#           </li>
#           <li>
#            <a href="/condition/angina-pectoris.html">
#             Angina
#            </a>
#           </li>
#           <li>
#            <a href="/condition/anxiety.html">
#             Anxiety
#            </a>
#           </li>
#           <li>
#            <a href="/arthritis.html">
#             Arthritis
#            </a>
#           </li>
#           <li>
#            <a href="/condition/asthma.html">
#             Asthma
#            </a>
#           </li>
#           <li>
#            <a href="/condition/bipolar-disorder.html">
#             Bipolar Disorder
#            </a>
#           </li>
#           <li>
#            <a href="/condition/bronchitis.html">
#             Bronchitis
#            </a>
#           </li>
#           <li>
#            <a href="/condition/malignant-disease.html">
#             Cancer
#            </a>
#           </li>
#           <li>
#            <a href="/condition/hyperlipidemia.html">
#             Cholesterol
#            </a>
#           </li>
#           <li>
#            <a href="/condition/cold-symptoms.html">
#             Colds &amp; Flu
#            </a>
#           </li>
#           <li>
#            <a href="/condition/constipation.html">
#             Constipation
#            </a>
#           </li>
#           <li>
#            <a href="/condition/chronic-obstructive-pulmonary-disease.html">
#             COPD
#            </a>
#           </li>
#           <li>
#            <a href="/condition/covid-19.html">
#             Covid 19
#            </a>
#           </li>
#           <li>
#            <a href="/condition/depression.html">
#             Depression
#            </a>
#           </li>
#           <li>
#            <a href="/condition/diabetes-mellitus-type-i.html">
#             Diabetes (Type 1)
#            </a>
#           </li>
#           <li>
#            <a href="/condition/diabetes-mellitus-type-ii.html">
#             Diabetes (Type 2)
#            </a>
#           </li>
#           <li>
#            <a href="/condition/diarrhea.html">
#             Diarrhea
#            </a>
#           </li>
#           <li>
#            <a href="/condition/eczema.html">
#             Eczema
#            </a>
#           </li>
#           <li>
#            <a href="/condition/erectile-dysfunction.html">
#             Erectile Dysfunction
#            </a>
#           </li>
#           <li>
#            <a href="/fibromyalgia.html">
#             Fibromyalgia
#            </a>
#           </li>
#           <li>
#            <a href="/condition/gastrointestinal-surgery.html">
#             Gastrointestinal
#            </a>
#           </li>
#           <li>
#            <a href="/condition/gastroesophageal-reflux-disease.html">
#             GERD (Heartburn)
#            </a>
#           </li>
#           <li>
#            <a href="/condition/gout.html">
#             Gout
#            </a>
#           </li>
#           <li>
#            <a href="/condition/alopecia.html">
#             Hair Loss
#            </a>
#           </li>
#           <li>
#            <a href="/condition/allergic-rhinitis.html">
#             Hayfever
#            </a>
#           </li>
#           <li>
#            <a href="/condition/heart-disease.html">
#             Heart Disease
#            </a>
#           </li>
#           <li>
#            <a href="/condition/herpes-simplex.html">
#             Herpes
#            </a>
#           </li>
#           <li>
#            <a href="/condition/hypertension.html">
#             Hypertension
#            </a>
#           </li>
#           <li>
#            <a href="/condition/hypothyroidism.html">
#             Hypothyroidism
#            </a>
#           </li>
#           <li>
#            <a href="/condition/inflammatory-bowel-disease.html">
#             IBD (Bowel)
#            </a>
#           </li>
#           <li>
#            <a href="/condition/urinary-incontinence.html">
#             Incontinence
#            </a>
#           </li>
#           <li>
#            <a href="/condition/insomnia.html">
#             Insomnia
#            </a>
#           </li>
#           <li>
#            <a href="/condition/menopausal-disorders.html">
#             Menopause
#            </a>
#           </li>
#           <li>
#            <a href="/condition/history-psychiatric-disorder.html">
#             Mental Health
#            </a>
#           </li>
#           <li>
#            <a href="/condition/migraine.html">
#             Migraine
#            </a>
#           </li>
#           <li>
#            <a href="/condition/osteoarthritis.html">
#             Osteoarthritis
#            </a>
#           </li>
#           <li>
#            <a href="/condition/osteoporosis.html">
#             Osteoporosis
#            </a>
#           </li>
#           <li>
#            <a href="/condition/pain.html">
#             Pain
#            </a>
#           </li>
#           <li>
#            <a href="/condition/pneumonia.html">
#             Pneumonia
#            </a>
#           </li>
#           <li>
#            <a href="/condition/psoriasis.html">
#             Psoriasis
#            </a>
#           </li>
#           <li>
#            <a href="/condition/rheumatoid-arthritis.html">
#             Rheumatoid Arthritis
#            </a>
#           </li>
#           <li>
#            <a href="/condition/schizophrenia.html">
#             Schizophrenia
#            </a>
#           </li>
#           <li>
#            <a href="/condition/seizures.html">
#             Seizures
#            </a>
#           </li>
#           <li>
#            <a href="/sexual-health.html">
#             Sexual Health
#            </a>
#           </li>
#           <li>
#            <a href="/condition/ischemic-stroke.html">
#             Stroke
#            </a>
#           </li>
#           <li>
#            <a href="/condition/swine-flu.html">
#             Swine Flu
#            </a>
#           </li>
#           <li>
#            <a href="/condition/urinary-tract-infection.html">
#             UTI
#            </a>
#           </li>
#           <li>
#            <a href="/condition/obesity.html">
#             Weight Loss
#            </a>
#           </li>
#          </ul>
#         </div>
#         <p class="ddc-text-size-small">
#          See also:
#          <a href="/drug-classes.html">
#           Drugs by Classification
#          </a>
#          ,
#          <a href="/mcd/">
#           Mayo Clinic Disease Reference
#          </a>
#          ,
#          <a href="/health-guide/">
#           Harvard Health Guide
#          </a>
#         </p>
#         <h2>
#          Featured treatment centers
#         </h2>
#         <div class="snippet">
#          <h3>
#           <a href="/aids.html">
#            AIDS/HIV Center
#           </a>
#          </h3>
#          <p>
#           AIDS has become a global epidemic and more than 47 million people have been infected with HIV since the first reports of the disease more than twenty years ago. This center provides basic information on the difference between HIV infection and AIDS, details the
#           <a href="/aids-symptoms.html">
#            signs and symptoms of disease
#           </a>
#           , lists means of
#           <a href="/aids-preventative.html">
#            preventing transmission
#           </a>
#           of the virus and outlines the
#           <a href="/aids-symptoms.html">
#            complications
#           </a>
#           associated with AIDS/HIV as well as
#           <a href="/aids-hiv-treatment.html">
#            common drug treatments
#           </a>
#           .
#          </p>
#         </div>
#         <div class="snippet">
#          <h3>
#           <a href="/allergies.html">
#            Allergies and Hayfever Center
#           </a>
#          </h3>
#          <p>
#           Allergies and allergic disorders are among the most common of medical conditions, affecting more than 20 percent of all Americans. This center contains information relating to the most common allergies and outlines the types of drug treatments available, such as antihistamines, decongestants, nasal sprays, mast-cell stabilizing drugs and non-steroidal anti-inflammatory drugs.
#          </p>
#         </div>
#         <div class="snippet">
#          <h3>
#           <a href="/bipolar.html">
#            Bipolar Disorder Center
#           </a>
#          </h3>
#          <p>
#           Bipolar disorder is a lifelong condition that can affect both how you feel and how you act. It is a mood disorder thought to be caused by chemical imbalances in the brain that can result in extreme swings in mood – from manic highs to depressive lows.
#          </p>
#         </div>
#         <div class="snippet">
#          <h3>
#           <a href="/cancer.html">
#            Cancer Center
#           </a>
#          </h3>
#          <p>
#           "Cancer" is the term given to a large group of diseases that vary in type and location but have one thing in common: abnormal cells growing out of control. This center contains information on the various causes of cancer, methods of diagnosis and the variety of drugs and treatment options that are available. It also provides detailed information on
#           <a href="/cancer-breast.html">
#            breast
#           </a>
#           ,
#           <a href="/cancer-cervical.html">
#            cervical
#           </a>
#           ,
#           <a href="/cancer-lung.html">
#            lung
#           </a>
#           ,
#           <a href="/cancer-prostate.html">
#            prostate
#           </a>
#           and
#           <a href="/cancer-skin.html">
#            skin
#           </a>
#           cancers.
#          </p>
#         </div>
#         <div class="snippet">
#          <h3>
#           <a href="/cholesterol.html">
#            Cholesterol Center
#           </a>
#          </h3>
#          <p>
#           Cholesterol is a waxy, fat-like substance that occurs naturally in all parts of the body. Generally speaking, high levels of LDL (bad cholesterol) are associated with an increased risk of developing coronary heart disease, whereas high levels of HDL (good cholesterol) are associated with a decreased risk. Consult this center if you would like more information on the different types of cholesterol, details of how diet and exercise can help maintain desirable cholesterol levels and knowledge of drugs that can aid in achieving this goal.
#          </p>
#         </div>
#         <div class="snippet">
#          <h3>
#           <a href="/diabetes.html">
#            Diabetes Center
#           </a>
#          </h3>
#          <p>
#           Diabetes is a chronic metabolic disease characterized by high glucose (sugar) levels in the blood. Insulin, a hormone produced by the pancreas, regulates the amount of glucose in the blood. In patients with diabetes, the body either does not produce enough insulin, or does not adequately respond to the insulin it is producing, which causes blood sugar levels to be higher than normal. This center outlines the different types of diabetes, provides information on how diabetes is diagnosed and treated and lists complications that can occur in association with the disease. Sections include
#           <a href="/diabetes-overview.html">
#            overview
#           </a>
#           ,
#           <a href="/diabetes-prevention.html">
#            risk factors &amp; preventative measures
#           </a>
#           ,
#           <a href="/diabetes-complications.html">
#            symptoms &amp; complications
#           </a>
#           and
#           <a href="/diabetes-treatment.html">
#            drug treatment
#           </a>
#           .
#          </p>
#         </div>
#         <div class="snippet">
#          <h3>
#           <a href="/gastro.html">
#            Gastro Center
#           </a>
#          </h3>
#          <p>
#           Gastroesophageal Reflux Disease (GERD) is a condition resulting from stomach acid moving backward from the stomach into the esophagus (the tube that connects the mouth to the stomach). The acid causes heartburn and can eventually damage the lining of the esophagus causing inflammation and pain. This center lists drugs available for the treatment of GERD and also describes treatment options for Crohn's disease and Peptic ulcers.
#          </p>
#         </div>
#         <div class="snippet">
#          <h3>
#           <a href="/hair-loss.html">
#            Hair Loss
#           </a>
#          </h3>
#          <p>
#           Hair loss is related to the tendency of hair follicles to stop producing hair growth. This center describes the treatments available for reducing the rate of hair loss.
#          </p>
#         </div>
#         <div class="snippet">
#          <h3>
#           <a href="/menopause.html">
#            Menopause
#           </a>
#          </h3>
#          <p>
#           Menopause is the transition period in a woman's life when her ovaries stop producing eggs, her body produces less estrogen and progesterone, and menstruation becomes less frequent, eventually stopping altogether. This center describes the causes, symptoms and treatments available for menopause.
#          </p>
#         </div>
#         <div class="snippet">
#          <h3>
#           <a href="/mental-health.html">
#            Mental Health
#           </a>
#          </h3>
#          <p>
#           Depression is the most common psychological problem in the US.  This center contains information relating to the difference between Major and Minor Depression and provides links to common antidepressant drugs.
#          </p>
#         </div>
#         <div class="snippet">
#          <h3>
#           <a href="/quit-smoking.html">
#            Smoking Cessation
#           </a>
#          </h3>
#          <p>
#           About half of smokers die early of smoking-related illnesses and each year about 46% of them in the US try to quit smoking. This center compares the top drugs and provides useful information on smoking cessation.
#          </p>
#         </div>
#        </div>
#        <!-- google_ad_section_end -->
#       </div>
#       <div class="clearAfter" id="sidebar">
#        <div class="sideBox sideBoxAd300">
#         <div class="display-ad display-ad-static display-ad-300x250" id="display-ad-2">
#         </div>
#        </div>
#        <div class="sideBox sideBoxMiddleAd sideBoxFloatRight">
#         <div class="display-ad display-ad-static display-ad-160x600" id="display-ad-3">
#         </div>
#        </div>
#        <div class="sideBox sideBoxRecentlyApproved sideBoxFloatLeft">
#         <div class="sideBoxHead">
#          <div class="sideBoxTitle">
#           Recently Approved
#          </div>
#         </div>
#         <div class="sideBoxContent">
#          <ul>
#           <li>
#            <a class="display-block" href="/zepzelca.html">
#             Zepzelca
#            </a>
#            <p>
#             Zepzelca (lurbinectedin) is a selective oncogenic transcription inhibitor...
#            </p>
#           </li>
#           <li>
#            <a class="display-block" href="/history/lyumjev.html">
#             Lyumjev
#            </a>
#            <p>
#             Lyumjev (insulin lispro-aabc) is a rapid-acting human insulin analog indicated...
#            </p>
#           </li>
#           <li>
#            <a class="display-block" href="/history/semglee.html">
#             Semglee
#            </a>
#            <p>
#             Semglee (insulin glargine) is a long-acting human insulin analog indicated to...
#            </p>
#           </li>
#           <li>
#            <a class="display-block" href="/history/uplizna.html">
#             Uplizna
#            </a>
#            <p>
#             Uplizna (inebilizumab-cdon) is a CD19-directed cytolytic antibody indicated for...
#            </p>
#           </li>
#          </ul>
#          <p>
#           <a class="ddc-link-forward" href="/newdrugs.html">
#            More
#           </a>
#          </p>
#         </div>
#        </div>
#        <div class="sideBox sideBoxSubscribe">
#         <div class="sideBoxHead">
#          <div class="sideBoxTitle">
#           Subscribe to our newsletters
#          </div>
#         </div>
#         <div class="sideBoxContent">
#          <form action="/email-subscribe.php" method="post">
#           <div class="form-check">
#            <label class="form-check-label" for="subscribeFdaAlerts">
#             <input class="form-check-input" id="subscribeFdaAlerts" name="fdaalerts" type="checkbox" value="1"/>
#             <span>
#              FDA Safety Alerts
#             </span>
#            </label>
#           </div>
#           <div class="form-check">
#            <label class="form-check-label">
#             <input class="form-check-input" name="newsletter_option_daily" type="checkbox" value="1"/>
#             <span>
#              Daily MedNews
#             </span>
#            </label>
#           </div>
#           <div class="form-check">
#            <label class="form-check-label">
#             <input class="form-check-input" name="newsletter_option_weekly" type="checkbox" value="1"/>
#             <span>
#              Weekly Drug News Roundup
#             </span>
#            </label>
#           </div>
#           <div class="form-check">
#            <label class="form-check-label">
#             <input class="form-check-input" name="newsletter_option_monthly" type="checkbox" value="1"/>
#             <span>
#              Monthly Newsletter
#             </span>
#            </label>
#           </div>
#           <div class="form-check form-check-terms">
#            <label class="form-check-label">
#             <input class="form-check-input" name="terms" required="" type="checkbox" value="1"/>
#             <span class="form-hint">
#              I accept the Terms and Privacy Policy
#             </span>
#            </label>
#           </div>
#           <div class="input-group-attached">
#            <label class="label-placeholder">
#             Email address
#            </label>
#            <input autocomplete="email" class="placeholder input-text" id="subscribeEmail" name="email" placeholder="Email address" required="" type="email"/>
#            <input class="ddc-btn" type="submit" value="Subscribe"/>
#           </div>
#          </form>
#         </div>
#        </div>
#        <div class="sideBoxStackedAdWrap" id="sideBoxStackedAdWrap-1">
#         <div class="sideBox sideBoxFixedAd300 sideBoxStackedAd" id="sideBoxStackedAd-1">
#          <div class="display-ad display-ad-static display-ad-300x250" id="display-ad-4">
#          </div>
#         </div>
#        </div>
#        <div class="sideBoxStackedAdWrap" id="sideBoxStackedAdWrap-2">
#         <div class="sideBox sideBoxFixedAd300 sideBoxStackedAd" id="sideBoxStackedAd-2">
#          <div class="display-ad display-ad-static display-ad-300x250" id="display-ad-5">
#          </div>
#         </div>
#        </div>
#        <div class="sideBoxStackedAdWrap" id="sideBoxStackedAdWrap-3">
#         <div class="sideBox sideBoxFixedAd300 sideBoxStackedAd" id="sideBoxStackedAd-3">
#          <div class="display-ad display-ad-static display-ad-300x250" id="display-ad-6">
#          </div>
#         </div>
#        </div>
#        <div class="sideBoxStackedAdWrap" id="sideBoxStackedAdWrap-4">
#         <div class="sideBox sideBoxFixedAd300 sideBoxStackedAd" id="sideBoxStackedAd-4">
#          <div class="display-ad display-ad-static display-ad-300x250" id="display-ad-7">
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <!--Start Footer-->
#     <div class="footer-feature">
#      <div class="container">
#       <div class="promo-content" data-background-image="/img/apps/promo-uberapp.png" data-lazy-load="">
#        <h2 class="text-weight-normal">
#         Drugs.com
#         <span>
#          Mobile Apps
#         </span>
#        </h2>
#        <p>
#         The easiest way to lookup drug information, identify pills, check interactions and set up your own personal medication records. Available for Android and iOS devices.
#        </p>
#        <a class="ddc-btn ddc-btn-lg" href="/apps/" onclick="ga('send', { hitType: 'event', eventCategory: 'App Promo', eventAction: 'Footer', eventLabel: 'Explore Apps' });">
#         Explore Apps
#        </a>
#       </div>
#      </div>
#     </div>
#     <div class="footer clearAfter" id="footer">
#      <div class="container">
#       <div class="footer-sections">
#        <div class="brand-symbol">
#         <img alt="Drugs.com" aria-hidden="true" data-lazy-load="" data-src="/img/layout/ddc-logo-symbol.png" height="60" src="/img/pixel.gif" width="60"/>
#        </div>
#        <div class="footer-content-links">
#         <div class="footer-section">
#          <h4>
#           Support
#          </h4>
#          <ul class="ddc-list-unstyled mg-0">
#           <li>
#            <a href="/support/">
#             Help Center
#            </a>
#           </li>
#           <li>
#            <a href="/support/faq.html">
#             Frequent Questions
#            </a>
#           </li>
#           <li>
#            <a href="/sitemap.html">
#             Sitemap
#            </a>
#           </li>
#           <li>
#            <a href="/support/contact.html">
#             Contact Us
#            </a>
#           </li>
#          </ul>
#         </div>
#         <div class="footer-section">
#          <h4>
#           About
#          </h4>
#          <ul class="ddc-list-unstyled mg-0">
#           <li>
#            <a href="/support/about.html">
#             About Drugs.com
#            </a>
#           </li>
#           <li>
#            <a href="/support/advertising.html">
#             Advertising Policy
#            </a>
#           </li>
#           <li>
#            <a href="/support/citations.html">
#             Attribution &amp; Citations
#            </a>
#           </li>
#           <li>
#            <a href="//blog.drugs.com/">
#             Drugs.com Blog
#            </a>
#           </li>
#          </ul>
#         </div>
#         <div class="footer-section mg-0">
#          <h4>
#           Terms &amp; Privacy
#          </h4>
#          <ul class="ddc-list-unstyled mg-0">
#           <li>
#            <a href="/support/editorial_policy.html">
#             Editorial Policy
#            </a>
#           </li>
#           <li>
#            <a href="/support/privacy.html">
#             Privacy Policy
#            </a>
#           </li>
#           <li>
#            <a href="/support/terms.html">
#             Terms of Use
#            </a>
#           </li>
#          </ul>
#         </div>
#         <div class="footer-section footer-social">
#          <ul class="footer-social-list list-inline">
#           <li>
#            <a class="ddc-share-icon ddc-share-icon-facebook" href="//www.facebook.com/Drugscom" rel="noopener" target="_blank" title="Drugs.com on Facebook">
#             <span class="ddc-share-icon-label">
#              Facebook
#             </span>
#             <i aria-hidden="true" class="icon icon-facebook">
#             </i>
#            </a>
#           </li>
#           <li>
#            <a class="ddc-share-icon ddc-share-icon-twitter" href="//twitter.com/drugscom" rel="noopener" target="_blank" title="Drugs.com on Twitter">
#             <span class="ddc-share-icon-label">
#              Twitter
#             </span>
#             <i aria-hidden="true" class="icon icon-twitter">
#             </i>
#            </a>
#           </li>
#           <li>
#            <a class="ddc-share-icon ddc-share-icon-youtube" href="//www.youtube.com/user/drugscom" rel="noopener" target="_blank" title="Drugs.com on YouTube">
#             <span class="ddc-share-icon-label">
#              YouTube
#             </span>
#             <i aria-hidden="true" class="icon icon-youtube">
#             </i>
#            </a>
#           </li>
#           <li>
#            <a class="ddc-share-icon ddc-share-icon-rss" href="//www.drugs.com/rss.html" title="Drugs.com RSS Feeds">
#             <span class="ddc-share-icon-label">
#              RSS Feed
#             </span>
#             <i aria-hidden="true" class="icon icon-rss">
#             </i>
#            </a>
#           </li>
#          </ul>
#          <p>
#           <a href="/newsletters/">
#            Subscribe
#           </a>
#           to Drugs.com newsletters for the latest medication news, alerts, new drug approvals and more.
#          </p>
#         </div>
#        </div>
#       </div>
#       <div class="footer-description">
#        <p>
#         <strong>
#          Drugs.com
#         </strong>
#         provides accurate and independent information on more than 24,000 prescription drugs, over-the-counter medicines and natural products. This material is provided for educational purposes only and is not intended for medical advice, diagnosis or treatment. Data sources include IBM Watson Micromedex (updated 4 May 2020), Cerner Multum™ (updated 2 June 2020), Wolters Kluwer™ (updated 2 May 2020) and  others.
#        </p>
#       </div>
#       <div class="footer-info clearAfter">
#        <div class="footPrivacy">
#         <ul class="site-privacy ddc-list-unstyled mg-0">
#          <li class="privacy-logo logo-truste clearAfter">
#           <a href="//privacy.truste.com/privacy-seal/validation?rid=d18cba4a-afc4-4863-af81-8262bb120271" rel="noopener" target="_blank">
#            <img alt="TRUSTe" data-lazy-load="" data-src="//privacy-policy.truste.com/privacy-seal/seal?rid=d18cba4a-afc4-4863-af81-8262bb120271" src="/img/pixel.gif"/>
#           </a>
#          </li>
#          <li class="privacy-logo logo-adchoices clearAfter">
#           <a href="/support/privacy/advertising.html">
#            <p class="sr-only">
#             Third Party Advertising
#            </p>
#            <img alt="AdChoices" data-lazy-load="" data-src="/img/layout/logo-adchoices.png" height="38" src="/img/pixel.gif" width="116"/>
#           </a>
#          </li>
#          <li class="privacy-logo logo-honcode clearAfter">
#           <img alt="HonCode" data-lazy-load="" data-src="/img/layout/logo-honcode-2020.png" height="60" src="/img/pixel.gif" width="43"/>
#           <p>
#            We comply with the HONcode standard for trustworthy health information -
#            <a class="text-nowrap" href="//www.hon.ch/HONcode/Conduct.html?HONConduct756274" rel="noopener nofollow" target="_blank">
#             verify here
#            </a>
#           </p>
#          </li>
#          <li class="site-info">
#           <p class="mg-0">
#            Copyright © 2000-2020 Drugs.com.
#            <span>
#             All rights reserved.
#            </span>
#           </p>
#          </li>
#         </ul>
#        </div>
#       </div>
#      </div>
#     </div>
#     <!-- End Footer-->
#    </div>
#   </div>
#   <!-- Global JS var for configuration data/settings -->
#   <script>
#    SITECONFIG = {"agent":{"isMobile":false},"user":{"userid":0,"api":{"url":"/api/user/"},"skipConsent":true},"page":{"section":"condition","subsection":"","doc":"index","delayedCss":[],"delayedScripts":[],"image":{"lazyLoad":{"selector":"[data-lazy-load]","screens":1,"delay":2000}},"mailTo":{"delay":5000,"location":"/support/email-mailto.html"}},"form":{"recaptcha":{"sitekey":"6Ld-iSYTAAAAAOO0VTEwVl71HtvrFoSlPSibGr4g","callback":"DDC_RECAPTCHA_CALLBACK"}},"dwLog":{"a":"null","b":"null","c":"","d":"325","e":"","f":733,"h":0,"i":"default","k":"","l":"","m":"","n":"","o":"","p":0,"q":"drugs"},"drugs":[],"options":{"recordSelection":false,"classifyLists":{"wrapper":"#content","countHtmlItems":false,"numItems":{"short":10,"medium":25,"long":50},"charLimit":{"paragraph":30,"content":350}}},"dictionary":{},"share":{"url":"aHR0cHM6Ly93d3cuZHJ1Z3MuY29tL21lZGljYWxfY29uZGl0aW9ucy5odG1s","placeholder":".socialLinks","cookie":{"name":"socialsharebar","disable":"disable"},"mednotes":{"url":"/mednotes/api/modal"},"types":[{"title":"Facebook","label":"Share on Facebook","trackAction":"Like Pop","cssClass":"ddc-share-icon ddc-share-icon-facebook","labelClass":"ddc-share-icon-label","iconClass":"icon-facebook","baseUrl":"/bookmark/?track=facebook","width":600,"height":530},{"title":"Twitter","label":"Share on Twitter","trackAction":"Tweet Pop","cssClass":"ddc-share-icon ddc-share-icon-twitter","labelClass":"ddc-share-icon-label","iconClass":"icon-twitter","baseUrl":"/bookmark/?track=twitter","width":600,"height":530},{"title":"Email to a friend","label":"Email to a friend","trackAction":"Email Pop","cssClass":"ddc-share-icon ddc-share-icon-email","labelClass":"ddc-share-icon-label","iconClass":"icon-mail","mailUrl":"mailto:?body=https%3A%2F%2Fwww.drugs.com%2Fmedical_conditions.html","width":0,"height":0}]},"ads":{"section":"drugs","ugc":false,"display":{"confiant":false,"mobile":false,"stacked":true,"timeout":1000,"logUrl":"/api/logger/ads/","targeting":{"ugc":"0","c1":["4046"]},"units":[{"code":"display-ad-1","section":"/7146/drugs","lazy":false,"sizes":[[728,90],[970,250]],"targeting":{"uid":"d-leaderboard-1","mobile":0,"prebid":1,"size":"970x250","tier":"static","loading":"eager","position":1},"layout":{},"prebid":1},{"code":"display-ad-2","section":"/7146/drugs","lazy":false,"sizes":[[300,250]],"targeting":{"uid":"d-mrec-1","mobile":0,"prebid":1,"size":"300x250","tier":"static","loading":"eager","position":2},"layout":{"wrappingClass":"sideBoxStackedAdWrap","requiresContentHeight":true,"requiresSidebarFloat":true},"prebid":1},{"code":"display-ad-3","section":"/7146/drugs","lazy":false,"sizes":[[160,600]],"targeting":{"uid":"d-160x600-static-1","mobile":0,"prebid":1,"size":"160x600","tier":"static","loading":"eager","position":3},"layout":{"requiredFixedPosition":false,"wrappingClass":"sideBox"},"prebid":1},{"code":"display-ad-4","section":"/7146/drugs","lazy":true,"sizes":[[300,250]],"targeting":{"uid":"d-300x250-static-1","mobile":0,"prebid":1,"size":"300x250","tier":"static","loading":"lazy","position":4},"layout":{"wrappingClass":"sideBoxStackedAdWrap","requiresContentHeight":true,"requiresSidebarFloat":true},"prebid":1},{"code":"display-ad-5","section":"/7146/drugs","lazy":true,"sizes":[[300,250]],"targeting":{"uid":"d-300x250-static-2","mobile":0,"prebid":1,"size":"300x250","tier":"static","loading":"lazy","position":5},"layout":{"wrappingClass":"sideBoxStackedAdWrap","requiresContentHeight":true,"requiresSidebarFloat":true},"prebid":1},{"code":"display-ad-6","section":"/7146/drugs","lazy":true,"sizes":[[300,250]],"targeting":{"uid":"d-300x250-static-3","mobile":0,"prebid":1,"size":"300x250","tier":"static","loading":"lazy","position":6},"layout":{"wrappingClass":"sideBoxStackedAdWrap","requiresContentHeight":true,"percentageCutoff":70,"requiresSidebarFloat":true},"prebid":1},{"code":"display-ad-7","section":"/7146/drugs","lazy":true,"sizes":[[300,250]],"targeting":{"uid":"d-300x250-static-4","mobile":0,"prebid":1,"size":"300x250","ti ...
#   </script>
#   <script defer="" src="//www.google-analytics.com/analytics.js">
#   </script>
#   <script>
#    (function(i,r){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();})(window,'ga');
# ga('create', 'UA-78451-2', 'auto', {'siteSpeedSampleRate': 30, 'useAmpClientId': true});
# ga('require', 'linkid', 'linkid.js');
# ga('require', 'displayfeatures');
# ga('set', 'anonymizeIp', true);
# ga('set', {"dimension46":"no","dimension47":"no","dimension11":"No","dimension15":"No","dimension16":"Consumer","dimension17":"English","dimension25":";4046;","contentGroup3":"Short Page","dimension59":"No","dimension18":"Web","dimension43":"index\/follow"});
# ga('send', 'pageview', {});
#   </script>
#   <script defer="" src="//ads.rubiconproject.com/prebid/13482_drugs.js">
#   </script>
#   <script defer="" src="//securepubads.g.doubleclick.net/tag/js/gpt.js">
#   </script>
#   <script defer="" src="/js/vendor/jquery-3.5.0.min.js">
#   </script>
#   <script defer="" src="/bundle/js/polyfill.min.fdad3c95.js">
#   </script>
#   <script defer="" src="/bundle/js/launch-base.min.15ef4d67.js">
#   </script>
#   <script>
#    var _comscore = _comscore || [];
# _comscore.push({c1: '2', c2: '9355535'});
#   </script>
#   <script defer="" src="//sb.scorecardresearch.com/beacon.js">
#   </script>
#   <noscript>
#    <img alt="" src="https://sb.scorecardresearch.com/p?c1=2&amp;c2=9355535&amp;cv=2.0&amp;cj=1"/>
#   </noscript>
#  </body>
# </html>

# %%
condition_category_urls_raw = soup.find("ul", class_= "ddc-paging")
condition_category_urls_raw
# Out:
# <ul class="ddc-paging">
# <li><a href="/condition/a.html">A</a></li>
# <li><a href="/condition/b.html">B</a></li>
# <li><a href="/condition/c.html">C</a></li>
# <li><a href="/condition/d.html">D</a></li>
# <li><a href="/condition/e.html">E</a></li>
# <li><a href="/condition/f.html">F</a></li>
# <li><a href="/condition/g.html">G</a></li>
# <li><a href="/condition/h.html">H</a></li>
# <li><a href="/condition/i.html">I</a></li>
# <li><a href="/condition/j.html">J</a></li>
# <li><a href="/condition/k.html">K</a></li>
# <li><a href="/condition/l.html">L</a></li>
# <li><a href="/condition/m.html">M</a></li>
# <li><a href="/condition/n.html">N</a></li>
# <li><a href="/condition/o.html">O</a></li>
# <li><a href="/condition/p.html">P</a></li>
# <li><a href="/condition/q.html">Q</a></li>
# <li><a href="/condition/r.html">R</a></li>
# <li><a href="/condition/s.html">S</a></li>
# <li><a href="/condition/t.html">T</a></li>
# <li><a href="/condition/u.html">U</a></li>
# <li><a href="/condition/v.html">V</a></li>
# <li><a href="/condition/w.html">W</a></li>
# <li><a href="/condition/x.html">X</a></li>
# <li><a href="/condition/y.html">Y</a></li>
# <li><a href="/condition/z.html">Z</a></li>
# </ul>

# %%
soup = BeautifulSoup(str(condition_category_urls_raw), 'html.parser')
all_a = soup.select('a')
condition_category_urls = []
for a in all_a:
    condition_category_urls.append('https://www.drugs.com'+str(a['href']))
condition_category_urls
# Out:
# ['https://www.drugs.com/condition/a.html',
#  'https://www.drugs.com/condition/b.html',
#  'https://www.drugs.com/condition/c.html',
#  'https://www.drugs.com/condition/d.html',
#  'https://www.drugs.com/condition/e.html',
#  'https://www.drugs.com/condition/f.html',
#  'https://www.drugs.com/condition/g.html',
#  'https://www.drugs.com/condition/h.html',
#  'https://www.drugs.com/condition/i.html',
#  'https://www.drugs.com/condition/j.html',
#  'https://www.drugs.com/condition/k.html',
#  'https://www.drugs.com/condition/l.html',
#  'https://www.drugs.com/condition/m.html',
#  'https://www.drugs.com/condition/n.html',
#  'https://www.drugs.com/condition/o.html',
#  'https://www.drugs.com/condition/p.html',
#  'https://www.drugs.com/condition/q.html',
#  'https://www.drugs.com/condition/r.html',
#  'https://www.drugs.com/condition/s.html',
#  'https://www.drugs.com/condition/t.html',
#  'https://www.drugs.com/condition/u.html',
#  'https://www.drugs.com/condition/v.html',
#  'https://www.drugs.com/condition/w.html',
#  'https://www.drugs.com/condition/x.html',
#  'https://www.drugs.com/condition/y.html',
#  'https://www.drugs.com/condition/z.html']

# %% [markdown]
# ## Sub condition pages

# %%
def get_single_condition_url(_condition_urls, category_url ):
    req = requests.get(category_url)
    soup = BeautifulSoup(req.content, 'html.parser')
    condition_urls_raw = soup.find("ul", class_= "ddc-list-column-2")
    soup = BeautifulSoup(str(condition_urls_raw), 'html.parser')
    all_a = soup.select('a')
    for a in all_a:
        _condition_urls.append('https://www.drugs.com'+str(a['href']))

# %%
condition_urls = []
for url in condition_category_urls:
    get_single_condition_url(condition_urls, url)

# %%
import numpy as np 
# function to get unique values 
def _unique(lst): 
    x = np.array(lst) 
    return np.unique(x)

# %%
condition_urls = _unique(condition_urls)
print(len(condition_urls))
condition_urls.sort()
# Out:
# 2039

# %%
condition_urls[2030:]
# Out:
# array(['https://www.drugs.com/condition/x-linked-hypophosphatemia.html',
#        'https://www.drugs.com/condition/xerostomia.html',
#        'https://www.drugs.com/condition/yaws.html',
#        'https://www.drugs.com/condition/yellow-fever-prophylaxis.html',
#        'https://www.drugs.com/condition/zika.html',
#        'https://www.drugs.com/condition/zinc-deficiency.html',
#        'https://www.drugs.com/condition/zollinger-ellison-syndrome.html',
#        'https://www.drugs.com/diabetes.html',
#        'https://www.drugs.com/fibromyalgia.html'], dtype='<U122')

# %% [markdown]
# ### We see two outliers. Make another list for later looping through

# %%
condition_urls_1 = condition_urls[:2037]
condition_urls_2 = condition_urls[2037:]
condition_urls_2[1]
# Out:
# 'https://www.drugs.com/fibromyalgia.html'

# %% [markdown]
# ## Single Condition Page

# %%
import re
def extract_string(section):
    '''
    returns a list of names
    '''
    pattern = r"</b>\n\s*(.*?)\s*</p>"
    synoms = re.findall(pattern, str(section), flags=0)
    return synoms

# %%
def get_condition_name_from_url_1(url):
    '''
    returns the name of a condition from a url
    '''
    pattern = r"condition/(.*?)\s*.html"
    name = re.findall(pattern, url, flags=0)
    name = name[0]
    name = name.replace("-", " ")
    return name 

get_condition_name_from_url_1('https://www.drugs.com/condition/nonketotic-hyperosmolar-syndrome.html')
# Out:
# 'nonketotic hyperosmolar syndrome'

# %%
def get_condition_name_from_url_2(url):
    '''
    returns the name of a condition from a url
    '''
    pattern = r".com/(.*?)\s*.html"
    name = re.findall(pattern, url, flags=0)
    name = name[0]
    name = name.replace("-", " ")
    return name 

get_condition_name_from_url_2('https://www.drugs.com/fibromyalgia.html')
# Out:
# 'fibromyalgia'

# %%
def _clean_text(lst):
    # get rid of parentheses 
    lst = re.sub(r'\([^)]*\)', '', lst[0])
    # get rid of <>
    lst = re.sub(r'<.*?>', '', lst).split(",")
    # get rid of white spaces
    for i in range(len(lst)):
        lst[i] = lst[i].rstrip().lstrip()
    return lst
        
def get_subtitles(section):
    '''
    returns the list of generic names of a condition from a url
    '''
    generic_pattern = r'Generic Name:(.*?)(?=<b>|</p>)'
    generic_names = re.findall(generic_pattern, str(section), flags=0)
    if generic_names:
        generic_names = _clean_text(generic_names)
    
    brand_pattern = r'Brand Name:(.*?)(?=<b>|</p>)'
    brand_names = re.findall(brand_pattern, str(section), flags=0)
    if brand_names:
        brand_names = _clean_text(brand_names)

    return [generic_names, brand_names]

get_subtitles('''<p class="drug-subtitle"><b>Generic Name:</b> vasopressin (VAY soe PRES in), dkbdfhs, fsdhfskd<br/> <b>Brand Name:</b> <i>Vasostrict, Pitressin</i></p>''')
# Out:
# [['vasopressin', 'dkbdfhs', 'fsdhfskd'], ['Vasostrict', 'Pitressin']]

# %% [markdown]
# ```[<p class="drug-subtitle"><b>Generic Name:</b> vasopressin (VAY soe PRES in)<br/><b>Brand Name:</b> <i>Vasostrict, Pitressin</i></p>]```

# %%
def get_rx_otc(section):
    pattern = r">(.*?)</span>"
    result =  re.findall(pattern, str(section), flags=0)
    return result[0]

# %%
def get_drug_class(section):
    pattern = r"drug-class/(.*?).html"
    return re.findall(pattern, str(section), flags=0)

# %%
def get_pregnancy_CSA(section):
    pattern = r">\n*\s*(.*?)\s*\n*</span>"
    return re.findall(pattern, str(section), flags=0)

# %%
def get_href(section):
    pattern = r"href=\"(.*?)\""
    result = re.findall(pattern, str(section), flags=0)
    
    return "https://www.drugs.com"+result[0]

# %%
def is_rx(section):
    '''
    returns true or false
    '''
    pattern = r"<span aria-hidden=\"true\">(.*?)\s*</span>"
    return re.findall(pattern, str(section), flags=0)[0] == 'Rx'

# %%
def get_all_brands(section):
    pattern = r">(.*?)</span>"
    text = re.findall(pattern, str(section), flags=0)
    text = text[0].split(", ")
    return text

get_all_brands('''<span id="all_brands" style="display: none;">Ortho-Cyclen, Ortho Tri-Cyclen Lo, Tri-Sprintec, Tri-Previfem, Mili, Tri-Lo-Sprintec, Tri-Linyah, Tri-Estarylla, TriNessa Lo, Tri-Lo-Estarylla, Tri Femynor, VyLibra, Tri-VyLibra, Tri-Mili, Tri-VyLibra Lo, Tri-Lo-Mili</span>''')
# Out:
# ['Ortho-Cyclen',
#  'Ortho Tri-Cyclen Lo',
#  'Tri-Sprintec',
#  'Tri-Previfem',
#  'Mili',
#  'Tri-Lo-Sprintec',
#  'Tri-Linyah',
#  'Tri-Estarylla',
#  'TriNessa Lo',
#  'Tri-Lo-Estarylla',
#  'Tri Femynor',
#  'VyLibra',
#  'Tri-VyLibra',
#  'Tri-Mili',
#  'Tri-VyLibra Lo',
#  'Tri-Lo-Mili']

# %%
req = requests.get('https://www.drugs.com/condition/atrophic-vaginitis.html')
soup = BeautifulSoup(req.content, 'html.parser')

# %%
# takes one conditon
def get_drugs_for_condition(condition_url, url_type=1):
    disease_info = []
    
    condition_name = ""
    if url_type == 1:
        condition_name = get_condition_name_from_url_1(condition_url)
    else:
        condition_name = get_condition_name_from_url_2(condition_url)


    req = requests.get(condition_url)
    condition_soup = BeautifulSoup(req.content, 'html.parser')

    # get other names of the condition:
    other_name_raw = condition_soup.find("section", class_= "condition-table__synonyms condition-table__sub-section")
    synoms = extract_string(other_name_raw)
        
    disease_info = [[condition_name], [synoms]]

    # Each medication has three <tr> tags
    ### <tr class="condition-table__summary ddc-toggle-active">
    ### <tr class="condition-profile">
    ### <tr class="condition-table__responsive-spacer">
    # Medication name and Rx information are stored in "condition-table__summary ddc-toggle-active"
    # Generic names are stored in condition-profile

    drug_info = []
    
    drug_names = []
    rxs = []
    subtitles = []
    drug_classes = []
    pregnancy = []
    csa = []
    # Find condit/ion-table__summary for all medications under a condition
    body = condition_soup.findAll("tbody")
    if body:
        body = body[0]
        
        drug_name_section = body.findChildren("a", class_="condition-table__drug-name__link", recursive=True) # recursive == True: recursively find children of children 
        if drug_name_section: 
            for n in drug_name_section:
                drug_names.append(n.renderContents().decode("utf-8"))
                # get the link, go to page
                drug_link = get_href(n)
                req = requests.get(drug_link)
                drug_soup = BeautifulSoup(req.content, 'html.parser')
                
                drug_subtitle_section = drug_soup.findAll('p', class_="drug-subtitle")
                drug_subtitles = get_subtitles(drug_subtitle_section)
                
                all_brands_section = drug_soup.findAll('span', id="all_brands")
                if all_brands_section:
                    if drug_subtitles[1]:
                        # get rid of the ... show tag
                        full_brands = []
                        for i in range(len(drug_subtitles[1])):
                            if "..." not in drug_subtitles[1][i]:
                                full_brands.append(drug_subtitles[1][i])
                        # add remaining brands
                        remaining_brands = get_all_brands(all_brands_section)
                        full_brands += remaining_brands
                        # replace 
                        drug_subtitles[1] = full_brands
                    
                if drug_subtitles:
                    subtitles.append(drug_subtitles)
                else:
                    subtitles.append([])
                

                more_resource =  drug_soup.findAll('ul', class_="more-resources-list more-resources-list-general")
                if more_resource:
                    drug_classes.append(get_drug_class(str(more_resource)))
                else:
                    drug_classes.append([])

            # rx
            is_rx_section = body.findChildren("td", class_="condition-table__rx-otc", recursive=True)
            for r in is_rx_section:
                rxs.append(get_rx_otc(r))
            
#             # generic names
#             generic_name_section = body.findChildren("p", class_="condition-table__generic-name", recursive=True)
#             for gn in generic_name_section:
#                 drug_generic_names.append(get_generic_name(gn))
#             
#             # drug classes 
#             drug_class_section = body.findChildren("p", class_="condition-table__drug-classes", recursive=True)     
#             for dc in drug_class_section:
#                 drug_classes.append(get_drug_class(dc))

# generic names and drug classes cannot be extracted from the disease page since sometimes they are missing.
            
            # pregnancy class
            pregnancy_section = body.findChildren("td", class_="condition-table__pregnancy", recursive=True)     
            for ps in pregnancy_section:
                ps = get_pregnancy_CSA(ps)
                if ps:
                    pregnancy.append(ps[0])
                else: 
                    pregnancy.append([])
            
            # CSA class
            CSA_section = body.findChildren("td", class_="condition-table__csa", recursive=True)     
            for c in CSA_section:
                c = get_pregnancy_CSA(c)
                if c:
                    csa.append(c[0])
                else:
                    csa.append([])
                    
            #print(len(rxs), len(drug_names), len(subtitles), len(drug_classes), len(pregnancy), len(csa))
            for i in range(len(drug_names)):
                generic_names = []
                drug_brand = []
                
                # take care of empty lists
                if subtitles[i]:
                    generic_names = subtitles[i][0]
                    drug_brand = subtitles[i][1]
                
                drug_info.append([rxs[i], drug_names[i], generic_names, drug_classes[i], drug_brand, pregnancy[i], csa[i]])

    disease_info.append(drug_info)
    return disease_info

# %%
get_drugs_for_condition(condition_urls_1[0])
# Out:
# [['abdominal adhesions'], [['Adhesions, Gastrointestinal']], []]

# %%
output_lst = []
i = 0
for url in condition_urls_1[:50]:
    #print(i/len(condition_urls_1))
    print(url)
    output_lst.append(get_drugs_for_condition(url))
    i += 1

for url in condition_urls_2:
    output_lst.append(get_drugs_for_condition(url, 2))

output_lst[:10]
# Out:
# https://www.drugs.com/condition/abdominal-adhesions.html
# https://www.drugs.com/condition/abdominal-distension-prior-to-abdominal-x-ray.html
# https://www.drugs.com/condition/abdominal-distension.html
# https://www.drugs.com/condition/abdominal-radiological-procedure.html
# https://www.drugs.com/condition/abdominopelvic-fistulas.html
# https://www.drugs.com/condition/abnormal-electrocardiogram.html
# https://www.drugs.com/condition/abnormal-glucose-tolerance.html
# https://www.drugs.com/condition/abnormal-uterine-bleeding.html
# https://www.drugs.com/condition/abortion.html
# https://www.drugs.com/condition/acanthosis-nigricans.html
# https://www.drugs.com/condition/acetaminophen-overdose.html
# https://www.drugs.com/condition/achlorhydria.html
# https://www.drugs.com/condition/acidosis.html
# https://www.drugs.com/condition/acne-rosacea.html
# https://www.drugs.com/condition/acne.html
# https://www.drugs.com/condition/acromegaly.html
# https://www.drugs.com/condition/actinic-keratosis.html
# https://www.drugs.com/condition/actinomycosis.html
# https://www.drugs.com/condition/acute-alcohol-intoxication.html
# https://www.drugs.com/condition/acute-cholecystitis.html
# https://www.drugs.com/condition/acute-coronary-syndrome-prophylaxis.html
# https://www.drugs.com/condition/acute-coronary-syndrome.html
# https://www.drugs.com/condition/acute-disseminated-encephalomyelitis.html
# https://www.drugs.com/condition/acute-gout.html
# https://www.drugs.com/condition/acute-lymphoblastic-leukemia.html
# https://www.drugs.com/condition/acute-lymphocytic-leukemia.html
# https://www.drugs.com/condition/acute-meibomianitis.html
# https://www.drugs.com/condition/acute-mountain-sickness.html
# https://www.drugs.com/condition/acute-myeloblastic-leukemia.html
# https://www.drugs.com/condition/acute-myeloid-leukemia.html
# https://www.drugs.com/condition/acute-nonlymphocytic-leukemia.html
# https://www.drugs.com/condition/acute-otitis-externa.html
# https://www.drugs.com/condition/acute-promyelocytic-leukemia.html
# https://www.drugs.com/condition/acute-surgical-abdomen.html
# https://www.drugs.com/condition/adams-stokes-syndrome.html
# https://www.drugs.com/condition/addison-s-disease.html
# https://www.drugs.com/condition/adenomyosis.html
# https://www.drugs.com/condition/adenosine-deaminase-deficiency.html
# https://www.drugs.com/condition/adenovirus-prophylaxis.html
# https://www.drugs.com/condition/adhesive-arachnoiditis.html
# https://www.drugs.com/condition/adjunct-to-antibiotic-therapy.html
# https://www.drugs.com/condition/adrenal-cortical-carcinoma.html
# https://www.drugs.com/condition/adrenal-gland-disorders.html
# https://www.drugs.com/condition/adrenal-hemorrhage.html
# https://www.drugs.com/condition/adrenal-insufficiency.html
# https://www.drugs.com/condition/adrenal-tuberculosis.html
# https://www.drugs.com/condition/adrenal-tumor.html
# https://www.drugs.com/condition/adrenocortical-insufficiency.html
# https://www.drugs.com/condition/adrenogenital-syndrome.html
# https://www.drugs.com/condition/adult-human-growth-hormone-deficiency.html
# [[['abdominal adhesions'], [['Adhesions, Gastrointestinal']], []],
#  [['abdominal distension prior to abdominal x ray'],
#   [[]],
#   [['Rx',
#     'vasopressin',
#     ['vasopressin'],
#     ['antidiuretic-hormones'],
#     ['Vasostrict', 'Pitressin'],
#     'C',
#     'N'],
#    ['Rx',
#     'Vasostrict',
#     ['vasopressin'],
#     ['antidiuretic-hormones'],
#     ['Vasostrict'],
#     'C',
#     'N']]],
#  [['abdominal distension'],
#   [['Abdominal bloating; Bloating; Meteorism']],
#   [['Rx',
#     'bethanechol',
#     ['bethanechol'],
#     ['miscellaneous-genitourinary-tract-agents'],
#     ['Duvoid', 'Urecholine'],
#     'C',
#     'N'],
#    ['Rx',
#     'Urecholine',
#     ['bethanechol'],
#     ['miscellaneous-genitourinary-tract-agents'],
#     ['Duvoid', 'Urecholine'],
#     'C',
#     'N'],
#    ['Rx',
#     'Duvoid',
#     ['bethanechol'],
#     ['miscellaneous-genitourinary-tract-agents'],
#     ['Duvoid', 'Urecholine'],
#     'C',
#     'N'],
#    ['OTC',
#     'pamabrom',
#     ['pamabrom'],
#     ['miscellaneous-diuretics'],
#     ['Aqua-Ban',
#      'Diurex Aquagels',
#      'Diurex Water Capsules',
#      'Aqua-Ban with Pamabrom'],
#     'N',
#     'N'],
#    ['OTC',
#     'Aqua-Ban',
#     ['pamabrom'],
#     ['miscellaneous-diuretics'],
#     ['Aqua-Ban', 'Diurex Aquagels', 'Diurex Water Capsules'],
#     'N',
#     'N']]],
#  [['abdominal radiological procedure'],
#   [['Abdominal Radiological Procedures']],
#   [['Rx',
#     'vasopressin',
#     ['vasopressin'],
#     ['antidiuretic-hormones'],
#     ['Vasostrict', 'Pitressin'],
#     'C',
#     'N']]],
#  [['abdominopelvic fistulas'], [[]], []],
#  [['abnormal electrocardiogram'], [[]], []],
#  [['abnormal glucose tolerance'], [[]], []],
#  [['abnormal uterine bleeding'],
#   [['Bleeding, dysfunctional uterine; DUB; Dysfunctional uterine bleeding']],
#   [['Rx',
#     'medroxyprogesterone',
#     ['medroxyprogesterone'],
#     ['contraceptives'],
#     [],
#     'X',
#     'N'],
#    ['Rx', 'Mirena', [], ['contraceptives'], [], 'X', 'N'],
#    ['Rx',
#     'Provera',
#     ['medroxyprogesterone'],
#     ['contraceptives'],
#     ['Provera'],
#     'X',
#     'N'],
#    ['Rx',
#     'norethindrone',
#     ['norethindrone'],
#     ['contraceptives'],
#     ['Aygestin',
#      'Camila',
#      'Errin',
#      'Jolivette',
#      'Nora-Be',
#      'Ortho Micronor',
#      'Heather',
#      'Jencycla',
#      'Norlyroc',
#      'Deblitane',
#      'Sharobel',
#      'Lyza',
#      'Norlyda',
#      'Tulana',
#      'Incassia',
#      'Nor-QD',
#      'Heather',
#      'Jencycla',
#      'Norlyroc',
#      'Deblitane',
#      'Sharobel',
#      'Lyza',
#      'Norlyda',
#      'Tulana',
#      'Incassia'],
#     'X',
#     'N'],
#    ['Rx',
#     'Depo-Provera',
#     ['medroxyprogesterone'],
#     ['contraceptives'],
#     [],
#     'X',
#     'N'],
#    ['Rx',
#     'megestrol',
#     ['megestrol'],
#     ['hormones-antineoplastics'],
#     ['Megace ES', 'Megace'],
#     'X',
#     'N'],
#    ['Rx',
#     'Sprintec',
#     ['ethinyl estradiol and norgestimate'],
#     ['contraceptives'],
#     ['Estarylla',
#      'Femynor',
#      'Mono-Linyah',
#      'Mononessa',
#      'Ortho Tri-Cyclen',
#      'Previfem',
#      'Sprintec',
#      'Tri-Lo-Marzia',
#      'TriNessa'],
#     'X',
#     'N'],
#    ['Rx/OTC',
#     'levonorgestrel',
#     ['levonorgestrel emergency contraceptive'],
#     ['contraceptives'],
#     [],
#     'X',
#     'N'],
#    ['Rx',
#     'Aviane',
#     ['ethinyl estradiol and levonorgestrel'],
#     ['contraceptives'],
#     [],
#     'X',
#     'N'],
#    ['Rx',
#     'Aygestin',
#     ['norethindrone'],
#     ['contraceptives'],
#     ['Aygestin', 'Camila', 'Errin', 'Jolivette', 'Nora-Be', 'Ortho Micronor'],
#     'X',
#     'N'],
#    ['Rx',
#     'ethinyl estradiol / levonorgestrel',
#     ['ethinyl estradiol and levonorgestrel'],
#     ['contraceptives'],
#     ['Amethyst',
#      'Aviane',
#      'Balcoltra',
#      'Falmina',
#      'Levlen',
#      'Lillow',
#      'Orsythia',
#      'Vienva'],
#     'X',
#     'N'],
#    ['Rx', 'Premarin', ['conjugated estrogens'], ['estrogens'], [], 'X', 'N'],
#    ['Rx',
#     'Seasonique',
#     ['ethinyl estradiol and levonorgestrel'],
#     ['contraceptives'],
#     [],
#     'X',
#     'N'],
#    ['Rx',
#     'Jolivette',
#     ['norethindrone'],
#     ['contraceptives'],
#     ['Aygestin', 'Camila', 'Errin', 'Jolivette', 'Nora-Be', 'Ortho Micronor'],
#     'X',
#     'N'],
#    ['Rx',
#     'Camila',
#     ['norethindrone'],
#     ['contraceptives'],
#     ['Aygestin', 'Camila', 'Errin', 'Jolivette', 'Nora-Be', 'Ortho Micronor'],
#     'X',
#     'N'],
#    ['Rx',
#     'ethinyl estradiol / norgestimate',
#     ['ethinyl estradiol and norgestimate'],
#     ['contraceptives'],
#     ['Estarylla',
#      'Femynor',
#      'Mono-Linyah',
#      'Mononessa',
#      'Ortho Tri-Cyclen',
#      'Previfem',
#      'Sprintec',
#      'Tri-Lo-Marzia',
#      'TriNessa',
#      'Ortho Tri-Cyclen Lo',
#      'Tri-Sprintec',
#      'Tri-Previfem',
#      'Mili',
#      'Tri-Lo-Sprintec',
#      'Tri-Linyah',
#      'Tri-Estarylla',
#      'TriNessa Lo',
#      'Tri-Lo-Estarylla',
#      'Tri Femynor',
#      'VyLibra',
#      'Tri-VyLibra',
#      'Tri-Mili',
#      'Tri-VyLibra Lo',
#      'Tri-Lo-Mili',
#      'Ortho-Cyclen',
#      'Ortho Tri-Cyclen Lo',
#      'Tri-Sprintec',
#      'Tri-Previfem',
#      'Mili',
#      'Tri-Lo-Sprintec',
#      'Tri-Linyah',
#      'Tri-Estarylla',
#      'TriNessa Lo',
#      'Tri-Lo-Estarylla',
#      'Tri Femynor',
#      'VyLibra',
#      'Tri-VyLibra',
#      'Tri-Mili',
#      'Tri-VyLibra Lo',
#      'Tri-Lo-Mili'],
#     'X',
#     'N'],
#    ['Rx',
#     'Heather',
#     ['Norethindrone'],
#     ['contraceptives'],
#     ['Camila',
#      'Deblitane',
#      'Errin',
#      'Heather',
#      'Jencycla',
#      'Lyza',
#      'Nor-QD',
#      'Nora-BE',
#      'Norlyroc',
#      'Ortho Micronor',
#      'Sharobel',
#      'Jolivette',
#      'Lyza',
#      'Nor-QD',
#      'Nora-BE',
#      'Norlyroc',
#      'Ortho Micronor',
#      'Sharobel'],
#     'X',
#     'N'],
#    ['Rx',
#     'Nora-Be',
#     ['norethindrone'],
#     ['contraceptives'],
#     ['Aygestin', 'Camila', 'Errin', 'Jolivette', 'Nora-Be', 'Ortho Micronor'],
#     'X',
#     'N'],
#    ['Rx',
#     'Ortho Micronor',
#     ['norethindrone'],
#     ['contraceptives'],
#     ['Aygestin', 'Camila', 'Errin', 'Jolivette', 'Nora-Be', 'Ortho Micronor'],
#     'X',
#     'N'],
#    ['Rx',
#     'Cryselle',
#     ['ethinyl estradiol and norgestrel'],
#     ['contraceptives'],
#     ['Cryselle 28', 'Low-Ogestrel', 'Ogestrel-28'],
#     'X',
#     'N'],
#    ['Rx',
#     'Depo-Provera Contraceptive',
#     ['medroxyprogesterone'],
#     ['contraceptives'],
#     ['Depo-Provera', 'Depo-Provera Contraceptive', 'depo-subQ provera 104'],
#     'X',
#     'N'],
#    ['Rx',
#     'Errin',
#     ['norethindrone'],
#     ['contraceptives'],
#     ['Aygestin', 'Camila', 'Errin', 'Jolivette', 'Nora-Be', 'Ortho Micronor'],
#     'X',
#     'N'],
#    ['Rx',
#     'ethinyl estradiol / norethindrone',
#     ['ethinyl estradiol and norethindrone'],
#     ['contraceptives'],
#     ['femhrt 0.5 mg/2.5 mcg', 'Fyavolv', 'Jevantique Lo', 'Jinteli'],
#     'X',
#     'N'],
#    ['Rx', 'Lutera', [], ['contraceptives'], [], 'X', 'N'],
#    ['Rx',
#     'Deblitane',
#     ['Norethindrone'],
#     ['contraceptives'],
#     ['Camila',
#      'Deblitane',
#      'Errin',
#      'Heather',
#      'Jencycla',
#      'Lyza',
#      'Nor-QD',
#      'Nora-BE',
#      'Norlyroc',
#      'Ortho Micronor',
#      'Sharobel',
#      'Jolivette',
#      'Lyza',
#      'Nor-QD',
#      'Nora-BE',
#      'Norlyroc',
#      'Ortho Micronor',
#      'Sharobel'],
#     'X',
#     'N']]],
#  [['abortion'],
#   [['Complete Abortion']],
#   [['Rx',
#     'misoprostol',
#     ['misoprostol'],
#     ['miscellaneous-gi-agents'],
#     ['Cytotec'],
#     'X',
#     'N'],
#    ['Rx',
#     'Cytotec',
#     ['misoprostol'],
#     ['miscellaneous-gi-agents'],
#     ['Cytotec'],
#     'X',
#     'N'],
#    ['Rx',
#     'mifepristone',
#     ['mifepristone'],
#     ['progesterone-receptor-modulators'],
#     ['Korlym'],
#     'X',
#     'N'],
#    ['Rx',
#     'oxytocin',
#     ['oxytocin'],
#     ['uterotonic-agents'],
#     ['Pitocin', 'Syntocinon'],
#     'X',
#     'N'],
#    ['Rx',
#     'Pitocin',
#     ['oxytocin'],
#     ['uterotonic-agents'],
#     ['Pitocin'],
#     'X',
#     'N'],
#    ['Rx',
#     'Mifeprex',
#     ['mifepristone'],
#     ['progesterone-receptor-modulators'],
#     ['Mifeprex'],
#     'X',
#     'N'],
#    ['Rx',
#     'Hemabate',
#     ['carboprost'],
#     ['uterotonic-agents'],
#     ['Hemabate'],
#     'C',
#     'N'],
#    ['Rx',
#     'carboprost',
#     ['carboprost'],
#     ['uterotonic-agents'],
#     ['Hemabate'],
#     'C',
#     'N'],
#    ['Rx',
#     'Cervidil',
#     ['dinoprostone topical'],
#     ['uterotonic-agents'],
#     ['Cervidil', 'Prepidil', 'Prostin E2'],
#     'C',
#     'N'],
#    ['Rx',
#     'Prostin E2',
#     ['dinoprostone topical'],
#     ['uterotonic-agents'],
#     ['Cervidil', 'Prepidil', 'Prostin E2'],
#     'C',
#     'N'],
#    ['Rx',
#     'dinoprostone',
#     ['dinoprostone topical'],
#     ['uterotonic-agents'],
#     ['Cervidil', 'Prepidil', 'Prostin E2'],
#     'C',
#     'N'],
#    ['Rx',
#     'Prepidil',
#     ['dinoprostone topical'],
#     ['uterotonic-agents'],
#     ['Cervidil', 'Prepidil', 'Prostin E2'],
#     'C',
#     'N']]],
#  [['acanthosis nigricans'], [[]], []]]

# %%
output_lst_copy = output_lst
output_lst_copy
# Out:
# [[['abdominal adhesions'], [['Adhesions, Gastrointestinal']], []],
#  [['abdominal distension prior to abdominal x ray'],
#   [[]],
#   [['Rx',
#     'vasopressin',
#     ['vasopressin'],
#     ['antidiuretic-hormones'],
#     ['Vasostrict', 'Pitressin'],
#     'C',
#     'N'],
#    ['Rx',
#     'Vasostrict',
#     ['vasopressin'],
#     ['antidiuretic-hormones'],
#     ['Vasostrict'],
#     'C',
#     'N']]],
#  [['abdominal distension'],
#   [['Abdominal bloating; Bloating; Meteorism']],
#   [['Rx',
#     'bethanechol',
#     ['bethanechol'],
#     ['miscellaneous-genitourinary-tract-agents'],
#     ['Duvoid', 'Urecholine'],
#     'C',
#     'N'],
#    ['Rx',
#     'Urecholine',
#     ['bethanechol'],
#     ['miscellaneous-genitourinary-tract-agents'],
#     ['Duvoid', 'Urecholine'],
#     'C',
#     'N'],
#    ['Rx',
#     'Duvoid',
#     ['bethanechol'],
#     ['miscellaneous-genitourinary-tract-agents'],
#     ['Duvoid', 'Urecholine'],
#     'C',
#     'N'],
#    ['OTC',
#     'pamabrom',
#     ['pamabrom'],
#     ['miscellaneous-diuretics'],
#     ['Aqua-Ban',
#      'Diurex Aquagels',
#      'Diurex Water Capsules',
#      'Aqua-Ban with Pamabrom'],
#     'N',
#     'N'],
#    ['OTC',
#     'Aqua-Ban',
#     ['pamabrom'],
#     ['miscellaneous-diuretics'],
#     ['Aqua-Ban', 'Diurex Aquagels', 'Diurex Water Capsules'],
#     'N',
#     'N']]],
#  [['abdominal radiological procedure'],
#   [['Abdominal Radiological Procedures']],
#   [['Rx',
#     'vasopressin',
#     ['vasopressin'],
#     ['antidiuretic-hormones'],
#     ['Vasostrict', 'Pitressin'],
#     'C',
#     'N']]],
#  [['abdominopelvic fistulas'], [[]], []],
#  [['abnormal electrocardiogram'], [[]], []],
#  [['abnormal glucose tolerance'], [[]], []],
#  [['abnormal uterine bleeding'],
#   [['Bleeding, dysfunctional uterine; DUB; Dysfunctional uterine bleeding']],
#   [['Rx',
#     'medroxyprogesterone',
#     ['medroxyprogesterone'],
#     ['contraceptives'],
#     [],
#     'X',
#     'N'],
#    ['Rx', 'Mirena', [], ['contraceptives'], [], 'X', 'N'],
#    ['Rx',
#     'Provera',
#     ['medroxyprogesterone'],
#     ['contraceptives'],
#     ['Provera'],
#     'X',
#     'N'],
#    ['Rx',
#     'norethindrone',
#     ['norethindrone'],
#     ['contraceptives'],
#     ['Aygestin',
#      'Camila',
#      'Errin',
#      'Jolivette',
#      'Nora-Be',
#      'Ortho Micronor',
#      'Heather',
#      'Jencycla',
#      'Norlyroc',
#      'Deblitane',
#      'Sharobel',
#      'Lyza',
#      'Norlyda',
#      'Tulana',
#      'Incassia',
#      'Nor-QD',
#      'Heather',
#      'Jencycla',
#      'Norlyroc',
#      'Deblitane',
#      'Sharobel',
#      'Lyza',
#      'Norlyda',
#      'Tulana',
#      'Incassia'],
#     'X',
#     'N'],
#    ['Rx',
#     'Depo-Provera',
#     ['medroxyprogesterone'],
#     ['contraceptives'],
#     [],
#     'X',
#     'N'],
#    ['Rx',
#     'megestrol',
#     ['megestrol'],
#     ['hormones-antineoplastics'],
#     ['Megace ES', 'Megace'],
#     'X',
#     'N'],
#    ['Rx',
#     'Sprintec',
#     ['ethinyl estradiol and norgestimate'],
#     ['contraceptives'],
#     ['Estarylla',
#      'Femynor',
#      'Mono-Linyah',
#      'Mononessa',
#      'Ortho Tri-Cyclen',
#      'Previfem',
#      'Sprintec',
#      'Tri-Lo-Marzia',
#      'TriNessa'],
#     'X',
#     'N'],
#    ['Rx/OTC',
#     'levonorgestrel',
#     ['levonorgestrel emergency contraceptive'],
#     ['contraceptives'],
#     [],
#     'X',
#     'N'],
#    ['Rx',
#     'Aviane',
#     ['ethinyl estradiol and levonorgestrel'],
#     ['contraceptives'],
#     [],
#     'X',
#     'N'],
#    ['Rx',
#     'Aygestin',
#     ['norethindrone'],
#     ['contraceptives'],
#     ['Aygestin', 'Camila', 'Errin', 'Jolivette', 'Nora-Be', 'Ortho Micronor'],
#     'X',
#     'N'],
#    ['Rx',
#     'ethinyl estradiol / levonorgestrel',
#     ['ethinyl estradiol and levonorgestrel'],
#     ['contraceptives'],
#     ['Amethyst',
#      'Aviane',
#      'Balcoltra',
#      'Falmina',
#      'Levlen',
#      'Lillow',
#      'Orsythia',
#      'Vienva'],
#     'X',
#     'N'],
#    ['Rx', 'Premarin', ['conjugated estrogens'], ['estrogens'], [], 'X', 'N'],
#    ['Rx',
#     'Seasonique',
#     ['ethinyl estradiol and levonorgestrel'],
#     ['contraceptives'],
#     [],
#     'X',
#     'N'],
#    ['Rx',
#     'Jolivette',
#     ['norethindrone'],
#     ['contraceptives'],
#     ['Aygestin', 'Camila', 'Errin', 'Jolivette', 'Nora-Be', 'Ortho Micronor'],
#     'X',
#     'N'],
#    ['Rx',
#     'Camila',
#     ['norethindrone'],
#     ['contraceptives'],
#     ['Aygestin', 'Camila', 'Errin', 'Jolivette', 'Nora-Be', 'Ortho Micronor'],
#     'X',
#     'N'],
#    ['Rx',
#     'ethinyl estradiol / norgestimate',
#     ['ethinyl estradiol and norgestimate'],
#     ['contraceptives'],
#     ['Estarylla',
#      'Femynor',
#      'Mono-Linyah',
#      'Mononessa',
#      'Ortho Tri-Cyclen',
#      'Previfem',
#      'Sprintec',
#      'Tri-Lo-Marzia',
#      'TriNessa',
#      'Ortho Tri-Cyclen Lo',
#      'Tri-Sprintec',
#      'Tri-Previfem',
#      'Mili',
#      'Tri-Lo-Sprintec',
#      'Tri-Linyah',
#      'Tri-Estarylla',
#      'TriNessa Lo',
#      'Tri-Lo-Estarylla',
#      'Tri Femynor',
#      'VyLibra',
#      'Tri-VyLibra',
#      'Tri-Mili',
#      'Tri-VyLibra Lo',
#      'Tri-Lo-Mili',
#      'Ortho-Cyclen',
#      'Ortho Tri-Cyclen Lo',
#      'Tri-Sprintec',
#      'Tri-Previfem',
#      'Mili',
#      'Tri-Lo-Sprintec',
#      'Tri-Linyah',
#      'Tri-Estarylla',
#      'TriNessa Lo',
#      'Tri-Lo-Estarylla',
#      'Tri Femynor',
#      'VyLibra',
#      'Tri-VyLibra',
#      'Tri-Mili',
#      'Tri-VyLibra Lo',
#      'Tri-Lo-Mili'],
#     'X',
#     'N'],
#    ['Rx',
#     'Heather',
#     ['Norethindrone'],
#     ['contraceptives'],
#     ['Camila',
#      'Deblitane',
#      'Errin',
#      'Heather',
#      'Jencycla',
#      'Lyza',
#      'Nor-QD',
#      'Nora-BE',
#      'Norlyroc',
#      'Ortho Micronor',
#      'Sharobel',
#      'Jolivette',
#      'Lyza',
#      'Nor-QD',
#      'Nora-BE',
#      'Norlyroc',
#      'Ortho Micronor',
#      'Sharobel'],
#     'X',
#     'N'],
#    ['Rx',
#     'Nora-Be',
#     ['norethindrone'],
#     ['contraceptives'],
#     ['Aygestin', 'Camila', 'Errin', 'Jolivette', 'Nora-Be', 'Ortho Micronor'],
#     'X',
#     'N'],
#    ['Rx',
#     'Ortho Micronor',
#     ['norethindrone'],
#     ['contraceptives'],
#     ['Aygestin', 'Camila', 'Errin', 'Jolivette', 'Nora-Be', 'Ortho Micronor'],
#     'X',
#     'N'],
#    ['Rx',
#     'Cryselle',
#     ['ethinyl estradiol and norgestrel'],
#     ['contraceptives'],
#     ['Cryselle 28', 'Low-Ogestrel', 'Ogestrel-28'],
#     'X',
#     'N'],
#    ['Rx',
#     'Depo-Provera Contraceptive',
#     ['medroxyprogesterone'],
#     ['contraceptives'],
#     ['Depo-Provera', 'Depo-Provera Contraceptive', 'depo-subQ provera 104'],
#     'X',
#     'N'],
#    ['Rx',
#     'Errin',
#     ['norethindrone'],
#     ['contraceptives'],
#     ['Aygestin', 'Camila', 'Errin', 'Jolivette', 'Nora-Be', 'Ortho Micronor'],
#     'X',
#     'N'],
#    ['Rx',
#     'ethinyl estradiol / norethindrone',
#     ['ethinyl estradiol and norethindrone'],
#     ['contraceptives'],
#     ['femhrt 0.5 mg/2.5 mcg', 'Fyavolv', 'Jevantique Lo', 'Jinteli'],
#     'X',
#     'N'],
#    ['Rx', 'Lutera', [], ['contraceptives'], [], 'X', 'N'],
#    ['Rx',
#     'Deblitane',
#     ['Norethindrone'],
#     ['contraceptives'],
#     ['Camila',
#      'Deblitane',
#      'Errin',
#      'Heather',
#      'Jencycla',
#      'Lyza',
#      'Nor-QD',
#      'Nora-BE',
#      'Norlyroc',
#      'Ortho Micronor',
#      'Sharobel',
#      'Jolivette',
#      'Lyza',
#      'Nor-QD',
#      'Nora-BE',
#      'Norlyroc',
#      'Ortho Micronor',
#      'Sharobel'],
#     'X',
#     'N']]],
#  [['abortion'],
#   [['Complete Abortion']],
#   [['Rx',
#     'misoprostol',
#     ['misoprostol'],
#     ['miscellaneous-gi-agents'],
#     ['Cytotec'],
#     'X',
#     'N'],
#    ['Rx',
#     'Cytotec',
#     ['misoprostol'],
#     ['miscellaneous-gi-agents'],
#     ['Cytotec'],
#     'X',
#     'N'],
#    ['Rx',
#     'mifepristone',
#     ['mifepristone'],
#     ['progesterone-receptor-modulators'],
#     ['Korlym'],
#     'X',
#     'N'],
#    ['Rx',
#     'oxytocin',
#     ['oxytocin'],
#     ['uterotonic-agents'],
#     ['Pitocin', 'Syntocinon'],
#     'X',
#     'N'],
#    ['Rx',
#     'Pitocin',
#     ['oxytocin'],
#     ['uterotonic-agents'],
#     ['Pitocin'],
#     'X',
#     'N'],
#    ['Rx',
#     'Mifeprex',
#     ['mifepristone'],
#     ['progesterone-receptor-modulators'],
#     ['Mifeprex'],
#     'X',
#     'N'],
#    ['Rx',
#     'Hemabate',
#     ['carboprost'],
#     ['uterotonic-agents'],
#     ['Hemabate'],
#     'C',
#     'N'],
#    ['Rx',
#     'carboprost',
#     ['carboprost'],
#     ['uterotonic-agents'],
#     ['Hemabate'],
#     'C',
#     'N'],
#    ['Rx',
#     'Cervidil',
#     ['dinoprostone topical'],
#     ['uterotonic-agents'],
#     ['Cervidil', 'Prepidil', 'Prostin E2'],
#     'C',
#     'N'],
#    ['Rx',
#     'Prostin E2',
#     ['dinoprostone topical'],
#     ['uterotonic-agents'],
#     ['Cervidil', 'Prepidil', 'Prostin E2'],
#     'C',
#     'N'],
#    ['Rx',
#     'dinoprostone',
#     ['dinoprostone topical'],
#     ['uterotonic-agents'],
#     ['Cervidil', 'Prepidil', 'Prostin E2'],
#     'C',
#     'N'],
#    ['Rx',
#     'Prepidil',
#     ['dinoprostone topical'],
#     ['uterotonic-agents'],
#     ['Cervidil', 'Prepidil', 'Prostin E2'],
#     'C',
#     'N']]],
#  [['acanthosis nigricans'], [[]], []],
#  [['acetaminophen overdose'],
#   [['Acetaminophen Toxicity']],
#   [['Rx/OTC',
#     'acetylcysteine',
#     ['acetylcysteine'],
#     ['antidotes'],
#     ['NAC', 'N-A-C Sustain'],
#     'B',
#     'N'],
#    ['Rx', 'Acetadote', [], ['antidotes'], [], 'B', 'N']]],
#  [['achlorhydria'], [[]], []],
#  [['acidosis'],
#   [['Acidosis, lactic; Acidosis, respiratory']],
#   [['Rx/OTC',
#     'sodium bicarbonate',
#     ['sodium bicarbonate'],
#     ['antacids'],
#     ['Neut'],
#     'C',
#     'N']]],
#  [['acne rosacea'],
#   [['Acne rosacea']],
#   [['Rx',
#     'doxycycline',
#     ['doxycycline'],
#     ['miscellaneous-antimalarials'],
#     [],
#     'D',
#     'N'],
#    ['Rx',
#     'metronidazole',
#     ['metronidazole topical'],
#     ['topical-anti-rosacea-agents'],
#     ['MetroCream',
#      'MetroGel',
#      'MetroGel Pump',
#      'MetroLotion',
#      'Noritate',
#      'Rosadan'],
#     'B',
#     'N'],
#    ['Rx',
#     'MetroGel',
#     ['metronidazole topical'],
#     ['topical-anti-rosacea-agents'],
#     ['MetroCream',
#      'MetroGel',
#      'MetroGel Pump',
#      'MetroLotion',
#      'Noritate',
#      'Rosadan'],
#     'B',
#     'N'],
#    ['Rx',
#     'Finacea',
#     ['azelaic acid topical'],
#     ['topical-acne-agents'],
#     [],
#     'B',
#     'N'],
#    ['Rx',
#     'Oracea',
#     ['doxycycline'],
#     ['miscellaneous-antimalarials'],
#     [],
#     'D',
#     'N'],
#    ['Rx', 'minocycline', ['minocycline'], ['tetracyclines'], [], 'D', 'N'],
#    ['Rx', 'Soolantra', [], ['topical-anti-infectives'], [], 'C', 'N'],
#    ['Rx',
#     'Doryx',
#     ['Doxycycline Delayed-Release Tablets'],
#     ['miscellaneous-antimalarials'],
#     ['Doryx'],
#     'D',
#     'N'],
#    ['Rx',
#     'MetroCream',
#     ['metronidazole topical'],
#     ['topical-anti-rosacea-agents'],
#     ['MetroCream',
#      'MetroGel',
#      'MetroGel Pump',
#      'MetroLotion',
#      'Noritate',
#      'Rosadan'],
#     'B',
#     'N'],
#    ['Rx',
#     'Mirvaso',
#     ['brimonidine topical'],
#     ['topical-anti-rosacea-agents'],
#     [],
#     'B',
#     'N'],
#    ['Rx',
#     'Azelex',
#     ['azelaic acid topical'],
#     ['topical-acne-agents'],
#     ['Azelex', 'Finacea', 'Finacea Plus'],
#     'B',
#     'N'],
#    ['Rx',
#     'azelaic acid',
#     ['azelaic acid topical'],
#     ['topical-acne-agents'],
#     ['Azelex', 'Finacea', 'Finacea Plus', 'Finevin'],
#     'B',
#     'N'],
#    ['Rx',
#     'Doxy 100',
#     ['Doxycycline Injection'],
#     ['miscellaneous-antimalarials'],
#     ['Doxy 100'],
#     'D',
#     'N'],
#    ['Rx', 'Solodyn', ['minocycline'], ['tetracyclines'], [], 'D', 'N'],
#    ['Rx',
#     'Monodox',
#     ['Doxycycline Tablets and Capsules'],
#     ['miscellaneous-antimalarials'],
#     ['Acticlate',
#      'Adox Pak 2/100',
#      'Adoxa',
#      'Adoxa Pak 1/100',
#      'Adoxa Pak 1/150',
#      'Monodox',
#      'Morgidox',
#      'Oraxyl',
#      'TargaDOX',
#      'Vibramycin',
#      'Avidoxy',
#      'Monodox',
#      'Morgidox',
#      'Oraxyl',
#      'TargaDOX',
#      'Vibramycin'],
#     'D',
#     'N'],
#    ['Rx',
#     'Noritate',
#     ['metronidazole topical'],
#     ['topical-anti-rosacea-agents'],
#     ['MetroCream',
#      'MetroGel',
#      'MetroGel Pump',
#      'MetroLotion',
#      'Noritate',
#      'Rosadan'],
#     'B',
#     'N'],
#    ['Rx',
#     'sulfacetamide sodium / sulfur',
#     ['sulfacetamide sodium and sulfur topical'],
#     ['topical-antibiotics'],
#     ['Avar',
#      'BP 10-Wash',
#      'Clarifoam EF',
#      'Garimide',
#      'Plexion',
#      'Prascion Cleanser',
#      'Rosanil Cleanser',
#      'Rosula',
#      'Sulfacleans 8/4',
#      'Sumadan',
#      'Sumaxin',
#      'Suphera',
#      'Virti-Sulf',
#      'Zencia Wash',
#      'Sulfacet-R',
#      'Zetacet',
#      'Plexion Cleanser',
#      'Plexion TS',
#      'Rosula Cleanser',
#      'Nicosyn',
#      'Avar Cleanser',
#      'Clenia Foaming Wash',
#      'Clenia Emollient Cream',
#      'Avar Gel',
#      'Avar Green',
#      'Rosac',
#      'Avar-E Emollient',
#      'Avar-E Green',
#      'Rosaderm Cleanser',
#      'Zetacet Wash',
#      'Plexion SCT',
#      'Plexion Cleansing Cloths',
#      'Sulfatol',
#      'Sulfatol Cleanser',
#      'Prascion FC Cloths',
#      'Prascion RA',
#      'Rosula Clarifying Wash',
#      'Prascion',
#      'Rosac Wash',
#      'Topisulf',
#      'Sulfatol C',
#      'SulZee Wash',
#      'Sulfatol SS',
#      'Sumaxin Wash',
#      'Avar LS Cleanser',
#      'Avar-e LS',
#      'SE 10-5 SS',
#      'Avar-E',
#      'Sumaxin TS',
#      'Sumadan Wash',
#      'Sumaxin CP',
#      'Avar LS',
#      'Sumadan XLT',
#      'Rosula Wash',
#      'Novacet',
#      'Sulfacet-R',
#      'Zetacet',
#      'Plexion Cleanser',
#      'Plexion TS',
#      'Rosula Cleanser',
#      'Nicosyn',
#      'Avar Cleanser',
#      'Clenia Foaming Wash',
#      'Clenia Emollient Cream',
#      'Avar Gel',
#      'Avar Green',
#      'Rosac',
#      'Avar-E Emollient',
#      'Avar-E Green',
#      'Rosaderm Cleanser',
#      'Zetacet Wash',
#      'Plexion SCT',
#      'Plexion Cleansing Cloths',
#      'Sulfatol (obsolete)',
#      'Sulfatol Cleanser (obsolete)',
#      'Prascion FC Cloths',
#      'Prascion RA',
#      'Rosula Clarifying Wash (obsolete)',
#      'Prascion',
#      'Rosac Wash',
#      'Topisulf',
#      'Sulfatol C',
#      'SulZee Wash',
#      'Sulfatol SS',
#      'Sumaxin Wash',
#      'Avar LS Cleanser',
#      'Avar-e LS',
#      'SE 10-5 SS',
#      'Avar-E',
#      'Sumaxin TS',
#      'Sumadan Wash',
#      'Sumaxin CP',
#      'Avar LS',
#      'Sumadan XLT',
#      'Rosula Wash'],
#     'C',
#     'N'],
#    ['Rx',
#     'Minocin',
#     ['minocycline'],
#     ['tetracyclines'],
#     ['Dynacin', 'Minocin', 'Minocin PAC', 'Solodyn', 'Ximino'],
#     'D',
#     'N'],
#    ['Rx',
#     'isotretinoin',
#     ['isotretinoin'],
#     ['miscellaneous-antineoplastics'],
#     ['Absorica',
#      'Amnesteem',
#      'Claravis',
#      'Myorisan',
#      'Sotret',
#      'Zenatane',
#      'Accutane',
#      'Absorica LD'],
#     'X',
#     'N'],
#    ['Rx',
#     'ivermectin',
#     ['Ivermectin Cream'],
#     ['topical-anti-infectives'],
#     ['Soolantra'],
#     'C',
#     'N'],
#    ['Rx',
#     'MetroLotion',
#     ['metronidazole topical'],
#     ['topical-anti-rosacea-agents'],
#     ['MetroCream',
#      'MetroGel',
#      'MetroGel Pump',
#      'MetroLotion',
#      'Noritate',
#      'Rosadan'],
#     'B',
#     'N'],
#    ['Rx',
#     'Vibramycin',
#     ['Doxycycline Suspension'],
#     ['miscellaneous-antimalarials'],
#     ['Vibramycin'],
#     'D',
#     'N'],
#    ['Rx',
#     'brimonidine',
#     ['brimonidine topical'],
#     ['topical-anti-rosacea-agents'],
#     ['Mirvaso', 'Mirvaso Pump'],
#     'B',
#     'N'],
#    ['Rx', 'Doryx MPC', ['doxycycline'], [], [], 'D', 'N'],
#    ['Rx',
#     'Morgidox',
#     ['Doxycycline Tablets and Capsules'],
#     ['miscellaneous-antimalarials'],
#     ['Acticlate',
#      'Adox Pak 2/100',
#      'Adoxa',
#      'Adoxa Pak 1/100',
#      'Adoxa Pak 1/150',
#      'Monodox',
#      'Morgidox',
#      'Oraxyl',
#      'TargaDOX',
#      'Vibramycin',
#      'Avidoxy',
#      'Monodox',
#      'Morgidox',
#      'Oraxyl',
#      'TargaDOX',
#      'Vibramycin'],
#     'D',
#     'N']]],
#  [['acne'],
#   [['Acne Vulgaris; Blackheads; Breakouts; Cystic acne; Pimples; Whiteheads; Zits']],
#   [['Rx',
#     'doxycycline',
#     ['doxycycline'],
#     ['miscellaneous-antimalarials'],
#     [],
#     'D',
#     'N'],
#    ['Rx',
#     'spironolactone',
#     ['spironolactone'],
#     ['aldosterone-receptor-antagonists'],
#     [],
#     'C',
#     'N'],
#    ['Rx', 'minocycline', ['minocycline'], ['tetracyclines'], [], 'D', 'N'],
#    ['Rx',
#     'Aldactone',
#     ['spironolactone'],
#     ['aldosterone-receptor-antagonists'],
#     [],
#     'C',
#     'N'],
#    ['Rx',
#     'clindamycin',
#     ['clindamycin topical'],
#     ['topical-acne-agents'],
#     ['Cleocin T', 'Clindacin ETZ', 'Clindacin P', 'Clindagel', 'Evoclin'],
#     'B',
#     'N'],
#    ['Rx',
#     'tretinoin',
#     ['tretinoin topical'],
#     ['topical-acne-agents'],
#     ['Altreno',
#      'Atralin',
#      'Avita',
#      'Refissa',
#      'Renova',
#      'Retin-A',
#      'Tretinoin Emollient Topical'],
#     'C',
#     'N'],
#    ['Rx',
#     'Bactrim',
#     ['sulfamethoxazole and trimethoprim'],
#     ['sulfonamides'],
#     [],
#     'D',
#     'N'],
#    ['Rx',
#     'isotretinoin',
#     ['isotretinoin'],
#     ['miscellaneous-antineoplastics'],
#     ['Absorica',
#      'Amnesteem',
#      'Claravis',
#      'Myorisan',
#      'Sotret',
#      'Zenatane',
#      'Accutane',
#      'Absorica LD'],
#     'X',
#     'N'],
#    ['Rx', 'Retin-A', ['Retin-A'], ['topical-acne-agents'], [], 'C', 'N'],
#    ['Rx',
#     'Epiduo',
#     ['adapalene and benzoyl peroxide'],
#     ['topical-acne-agents'],
#     [],
#     'C',
#     'N'],
#    ['Rx',
#     'Aczone',
#     ['dapsone topical'],
#     ['topical-acne-agents'],
#     [],
#     'C',
#     'N'],
#    ['Rx/OTC',
#     'Differin',
#     ['adapalene topical'],
#     ['topical-acne-agents'],
#     [],
#     'C',
#     'N'],
#    ['Rx/OTC',
#     'benzoyl peroxide',
#     ['benzoyl peroxide topical'],
#     ['topical-acne-agents'],
#     ['Acne-Clear',
#      'Benzac AC',
#      'BenzePrO',
#      'Benziq',
#      'Brevoxyl Acne Wash Kit',
#      'Clearskin',
#      'Fostex Wash 10%',
#      'NeoBenz Micro',
#      'Neutrogena Acne Mask',
#      'Oscion',
#      'Oxy Daily Wash',
#      'Oxy-10',
#      'Pacnex',
#      'PanOxyl',
#      'Persa-Gel',
#      'Riax',
#      'SoluCLENZ Rx',
#      'Triaz',
#      'Desquam-X 10',
#      'Benzashave 5',
#      'Benzashave 10',
#      'Panoxyl AQ 2.5',
#      'Desquam-E',
#      'Benzac W',
#      'Brevoxyl',
#      'Panoxyl AQ 5',
#      'Panoxyl 5',
#      'Desquam-X 5',
#      'Persa-Gel W',
#      'Benzagel-5',
#      'Clearplex',
#      'Panoxyl 10',
#      'Panoxyl AQ 10',
#      'Benzagel-10',
#      'Peroxin A 10',
#      'Desquam-X Wash',
#      'Triaz Cleanser',
#      'Benoxyl 5',
#      'Acne Treatment',
#      'Ben-Aqua',
#      'Del-Aqua',
#      'Peroxin A',
#      'Zeroxin',
#      'Acne-10',
#      'Benoxyl 10',
#      'Fostex Bar 10%',
#      'Fostex Gel 10%',
#      'Clear By Design',
#      'Loroxide',
#      'Vanoxide',
#      'Oxy Vanishing Gel',
#      'Neutrogena On Spot Acne Treatment',
#      'Seba-Gel',
#      'Brevoxyl Creamy Wash',
#      'Clinac BPO',
#      'Benzagel Wash',
#      'Ethexderm',
#      'Oxy 10 Balance',
#      'Zaclir',
#      'Oxy Balance',
#      'Benziq LS',
#      'Benziq Wash',
#      'ZoDerm Redi-Pads',
#      'Panoxyl Aqua Gel',
#      'Oscion Cleanser',
#      'Inova',
#      'NeoBenz Micro SD',
#      'Lavoclen-4 Creamy Wash',
#      'Lavoclen-8 Creamy Wash',
#      'Oxy Daily Wash Chill Factor',
#      'Oxy Spot Treatment',
#      'PanOxyl Maximum Strength Foaming Acne Wash',
#      'Lavoclen-4',
#      'Lavoclen-8',
#      'Breze',
#      'Brevoxyl-4 Creamy Wash Complete Pack',
#      'Brevoxyl-8 Creamy Wash Complete Pack',
#      'NeoBenz Micro Wash',
#      'NeoBenz Micro Wash Plus Pack',
#      'Triaz Foaming Cloths',
#      'Triaz Pads',
#      'BenzEFoam',
#      'Pacnex MX Wash',
#      'NeoBenz Micro Cream Plus Pack',
#      'Benzac AC Wash',
#      'BPO Foaming Cloths',
#      'Pacnex HP',
#      'Pacnex LP',
#      'BenzEFoam Ultra',
#      'BP Cleansing Lotion',
#      'BP Wash',
#      'OC8',
#      'Delos',
#      'BPO',
#      'PR Benzoyl Peroxide Wash',
#      'Differin Daily Deep Cleanser',
#      'Benzac',
#      'Desquam-X 10',
#      'Benzashave 5',
#      'Benzashave 10',
#      'Panoxyl AQ 2.5',
#      'Desquam-E',
#      'Benzac W',
#      'Brevoxyl',
#      'Panoxyl AQ 5',
#      'Panoxyl 5',
#      'Desquam-X 5',
#      'Persa-Gel W',
#      'Benzagel-5',
#      'Clearplex',
#      'Panoxyl 10',
#      'Panoxyl AQ 10',
#      'Benzagel-10',
#      'Peroxin A 10',
#      'Desquam-X Wash',
#      'Triaz Cleanser',
#      'Benoxyl 5',
#      'Acne Treatment',
#      'Ben-Aqua',
#      'Del-Aqua',
#      'Peroxin A',
#      'Zeroxin',
#      'Acne-10',
#      'Benoxyl 10',
#      'Fostex Bar 10%',
#      'Fostex Gel 10%',
#      'Clear By Design',
#      'Loroxide',
#      'Vanoxide',
#      'Oxy Vanishing Gel',
#      'Neutrogena On Spot Acne Treatment',
#      'Seba-Gel',
#      'Brevoxyl Creamy Wash',
#      'Clinac BPO',
#      'Benzagel Wash',
#      'Ethexderm',
#      'Oxy 10 Balance',
#      'Zaclir',
#      'Oxy Balance',
#      'Benziq LS',
#      'Benziq Wash',
#      'ZoDerm Redi-Pads (obsolete)',
#      'Panoxyl Aqua Gel',
#      'Oscion Cleanser',
#      'Inova',
#      'NeoBenz Micro SD',
#      'Lavoclen-4 Creamy Wash',
#      'Lavoclen-8 Creamy Wash',
#      'Oxy Daily Wash Chill Factor',
#      'Oxy Spot Treatment',
#      'PanOxyl Maximum Strength Foaming Acne Wash',
#      'Lavoclen-4',
#      'Lavoclen-8',
#      'Breze',
#      'Brevoxyl-4 Creamy Wash Complete Pack',
#      'Brevoxyl-8 Creamy Wash Complete Pack',
#      'NeoBenz Micro Wash',
#      'NeoBenz Micro Wash Plus Pack',
#      'Triaz Foaming Cloths',
#      'Triaz Pads',
#      'BenzEFoam',
#      'Pacnex MX Wash',
#      'NeoBenz Micro Cream Plus Pack',
#      'Benzac AC Wash',
#      'BPO Foaming Cloths',
#      'Pacnex HP',
#      'Pacnex LP',
#      'BenzEFoam Ultra',
#      'BP Cleansing Lotion',
#      'BP Wash',
#      'OC8',
#      'Delos',
#      'BPO',
#      'PR Benzoyl Peroxide Wash',
#      'Differin Daily Deep Cleanser'],
#     'C',
#     'N'],
#    ['Rx', 'Solodyn', ['minocycline'], ['tetracyclines'], [], 'D', 'N'],
#    ['Rx',
#     'Doryx',
#     ['Doxycycline Delayed-Release Tablets'],
#     ['miscellaneous-antimalarials'],
#     ['Doryx'],
#     'D',
#     'N'],
#    ['Rx/OTC',
#     'adapalene',
#     ['adapalene topical'],
#     ['topical-acne-agents'],
#     ['Differin', 'Plixda'],
#     'C',
#     'N'],
#    ['Rx',
#     'Septra',
#     ['sulfamethoxazole and trimethoprim'],
#     ['sulfonamides'],
#     [],
#     'D',
#     'N'],
#    ['Rx', 'tetracycline', ['tetracycline'], ['tetracyclines'], [], 'D', 'N'],
#    ['Rx',
#     'sulfamethoxazole / trimethoprim',
#     ['sulfamethoxazole and trimethoprim'],
#     ['sulfonamides'],
#     ['Bactrim',
#      'Bactrim DS',
#      'Bactrim I.V.',
#      'Septra I.V.',
#      'SMZ-TMP DS',
#      'Sulfatrim Pediatric',
#      'Sulfatrim',
#      'Bethaprim',
#      'Cotrim',
#      'Uroplus',
#      'Uroplus DS',
#      'Cotrim DS',
#      'Bactrim Pediatric',
#      'Bethaprim Pediatric',
#      'Sulfatrim Suspension',
#      'Cotrim Pediatric',
#      'Septra DS',
#      'Septra',
#      'Sulfatrim',
#      'Bethaprim',
#      'Cotrim',
#      'Uroplus',
#      'Uroplus DS',
#      'Cotrim DS',
#      'Bactrim Pediatric',
#      'Bethaprim Pediatric',
#      'Sulfatrim Suspension',
#      'Cotrim Pediatric',
#      'Septra DS'],
#     'D',
#     'N'],
#    ['Rx',
#     'Tazorac',
#     ['tazarotene topical'],
#     ['topical-acne-agents'],
#     ['Arazlo', 'Avage', 'Fabior', 'Tazorac'],
#     'X',
#     'N'],
#    ['Rx',
#     'cephalexin',
#     ['cephalexin'],
#     ['first-generation-cephalosporins'],
#     [],
#     'B',
#     'N'],
#    ['Rx',
#     'Vibramycin',
#     ['Doxycycline Suspension'],
#     ['miscellaneous-antimalarials'],
#     ['Vibramycin'],
#     'D',
#     'N'],
#    ['Rx',
#     'Acticlate',
#     ['Doxycycline Tablets and Capsules'],
#     ['tetracyclines'],
#     ['Acticlate',
#      'Adox Pak 2/100',
#      'Adoxa',
#      'Adoxa Pak 1/100',
#      'Adoxa Pak 1/150',
#      'Monodox',
#      'Morgidox',
#      'Oraxyl',
#      'TargaDOX',
#      'Vibramycin',
#      'Avidoxy',
#      'Monodox',
#      'Morgidox',
#      'Oraxyl',
#      'TargaDOX',
#      'Vibramycin'],
#     'D',
#     'N'],
#    ['Rx',
#     'Bactrim DS',
#     ['Sulfamethoxazole and Trimethoprim Tablets'],
#     ['sulfonamides'],
#     ['Bactrim', 'Bactrim DS'],
#     'D',
#     'N'],
#    ['Rx',
#     'Benzaclin',
#     ['benzoyl peroxide and clindamycin topical'],
#     ['topical-acne-agents'],
#     [],
#     'C',
#     'N']]],
#  [['acromegaly'],
#   [[]],
#   [['Rx',
#     'Sandostatin LAR Depot',
#     ['octreotide'],
#     ['somatostatin-and-somatostatin-analogs'],
#     ['SandoSTATIN', 'SandoSTATIN LAR Depot'],
#     'B',
#     'N'],
#    ['Rx',
#     'Somavert',
#     ['pegvisomant'],
#     ['growth-hormone-receptor-blockers'],
#     [],
#     'B',
#     'N'],
#    ['Rx',
#     'bromocriptine',
#     ['bromocriptine'],
#     ['dopaminergic-antiparkinsonism-agents'],
#     ['Parlodel'],
#     'B',
#     'N'],
#    ['Rx',
#     'Somatuline Depot',
#     ['lanreotide'],
#     ['somatostatin-and-somatostatin-analogs'],
#     [],
#     'C',
#     'N'],
#    ['Rx',
#     'Parlodel',
#     ['bromocriptine'],
#     ['dopaminergic-antiparkinsonism-agents'],
#     ['Parlodel'],
#     'B',
#     'N'],
#    ['Rx',
#     'Sandostatin',
#     ['octreotide'],
#     ['somatostatin-and-somatostatin-analogs'],
#     [],
#     'B',
#     'N'],
#    ['Rx',
#     'octreotide',
#     ['octreotide'],
#     ['somatostatin-and-somatostatin-analogs'],
#     ['SandoSTATIN', 'SandoSTATIN LAR Depot', 'Benfyzia'],
#     'B',
#     'N'],
#    ['Rx',
#     'pegvisomant',
#     ['pegvisomant'],
#     ['growth-hormone-receptor-blockers'],
#     ['Somavert'],
#     'B',
#     'N'],
#    ['Rx',
#     'lanreotide',
#     ['lanreotide'],
#     ['somatostatin-and-somatostatin-analogs'],
#     ['Somatuline Depot'],
#     'C',
#     'N'],
#    ['Rx',
#     'pasireotide',
#     ['pasireotide'],
#     ['somatostatin-and-somatostatin-analogs'],
#     ['Signifor', 'Signifor LAR'],
#     'C',
#     'N'],
#    ['Rx',
#     'Signifor LAR',
#     ['pasireotide'],
#     ['somatostatin-and-somatostatin-analogs'],
#     ['Signifor', 'Signifor LAR'],
#     'C',
#     'N']]],
#  [['actinic keratosis'],
#   [[]],
#   [['Rx',
#     'fluorouracil',
#     ['fluorouracil topical'],
#     ['topical-antineoplastics'],
#     ['Carac', 'Efudex', 'Fluoroplex', 'Tolak', 'Efudex Occlusion Pack'],
#     'X',
#     'N'],
#    ['Rx',
#     'Efudex',
#     ['fluorouracil topical'],
#     ['topical-antineoplastics'],
#     ['Carac', 'Efudex', 'Fluoroplex', 'Tolak'],
#     'X',
#     'N'],
#    ['Rx',
#     'Picato',
#     ['ingenol topical'],
#     ['topical-antineoplastics'],
#     [],
#     'C',
#     'N'],
#    ['Rx',
#     'Carac',
#     ['fluorouracil topical'],
#     ['topical-antineoplastics'],
#     ['Carac', 'Efudex', 'Fluoroplex', 'Tolak'],
#     'X',
#     'N'],
#    ['Rx',
#     'Tolak',
#     ['fluorouracil topical'],
#     ['topical-antineoplastics'],
#     ['Carac', 'Efudex', 'Fluoroplex', 'Tolak'],
#     'X',
#     'N'],
#    ['Rx',
#     'Fluoroplex',
#     ['fluorouracil topical'],
#     ['topical-antineoplastics'],
#     ['Carac', 'Efudex', 'Fluoroplex', 'Tolak'],
#     'X',
#     'N'],
#    ['Rx',
#     'aminolevulinic acid',
#     ['aminolevulinic acid'],
#     ['topical-photochemotherapeutics'],
#     ['Ameluz', 'Levulan Kerastick'],
#     'C',
#     'N'],
#    ['Rx',
#     'ingenol',
#     ['ingenol topical'],
#     ['topical-antineoplastics'],
#     ['Picato'],
#     'C',
#     'N'],
#    ['Rx',
#     'Ameluz',
#     ['aminolevulinic acid'],
#     ['topical-photochemotherapeutics'],
#     ['Ameluz', 'Levulan Kerastick'],
#     'C',
#     'N']]],
#  [['actinomycosis'],
#   [['Lumpy Jaw']],
#   [['Rx', 'amoxicillin', ['amoxicillin'], ['aminopenicillins'], [], 'B', 'N'],
#    ['Rx',
#     'doxycycline',
#     ['doxycycline'],
#     ['miscellaneous-antimalarials'],
#     [],
#     'D',
#     'N'],
#    ['Rx', 'Amoxil', ['amoxicillin'], ['aminopenicillins'], [], 'B', 'N'],
#    ['Rx', 'minocycline', ['minocycline'], ['tetracyclines'], [], 'D', 'N'],
#    ['Rx',
#     'Doxy 100',
#     ['Doxycycline Injection'],
#     ['miscellaneous-antimalarials'],
#     ['Doxy 100'],
#     'D',
#     'N'],
#    ['Rx',
#     'Vibramycin',
#     ['Doxycycline Suspension'],
#     ['miscellaneous-antimalarials'],
#     ['Vibramycin'],
#     'D',
#     'N'],
#    ['Rx',
#     'Doryx',
#     ['Doxycycline Delayed-Release Tablets'],
#     ['miscellaneous-antimalarials'],
#     ['Doryx'],
#     'D',
#     'N'],
#    ['Rx',
#     'Monodox',
#     ['Doxycycline Tablets and Capsules'],
#     ['miscellaneous-antimalarials'],
#     ['Acticlate',
#      'Adox Pak 2/100',
#      'Adoxa',
#      'Adoxa Pak 1/100',
#      'Adoxa Pak 1/150',
#      'Monodox',
#      'Morgidox',
#      'Oraxyl',
#      'TargaDOX',
#      'Vibramycin',
#      'Avidoxy',
#      'Monodox',
#      'Morgidox',
#      'Oraxyl',
#      'TargaDOX',
#      'Vibramycin'],
#     'D',
#     'N'],
#    ['Rx', 'Apo-Amoxi', ['amoxicillin'], ['aminopenicillins'], [], 'B', 'N'],
#    ['Rx',
#     'Minocin',
#     ['minocycline'],
#     ['tetracyclines'],
#     ['Dynacin', 'Minocin', 'Minocin PAC', 'Solodyn', 'Ximino'],
#     'D',
#     'N'],
#    ['Rx', 'Doryx MPC', ['doxycycline'], [], [], 'D', 'N'],
#    ['Rx',
#     'Morgidox',
#     ['Doxycycline Tablets and Capsules'],
#     ['miscellaneous-antimalarials'],
#     ['Acticlate',
#      'Adox Pak 2/100',
#      'Adoxa',
#      'Adoxa Pak 1/100',
#      'Adoxa Pak 1/150',
#      'Monodox',
#      'Morgidox',
#      'Oraxyl',
#      'TargaDOX',
#      'Vibramycin',
#      'Avidoxy',
#      'Monodox',
#      'Morgidox',
#      'Oraxyl',
#      'TargaDOX',
#      'Vibramycin'],
#     'D',
#     'N'],
#    ['Rx',
#     'Oraxyl',
#     ['Doxycycline Tablets and Capsules'],
#     ['miscellaneous-antimalarials'],
#     ['Acticlate',
#      'Adox Pak 2/100',
#      'Adoxa',
#      'Adoxa Pak 1/100',
#      'Adoxa Pak 1/150',
#      'Monodox',
#      'Morgidox',
#      'Oraxyl',
#      'TargaDOX',
#      'Vibramycin',
#      'Avidoxy',
#      'Monodox',
#      'Morgidox',
#      'Oraxyl',
#      'TargaDOX',
#      'Vibramycin'],
#     'D',
#     'N'],
#    ['Rx',
#     'penicillin g sodium',
#     ['penicillin G sodium'],
#     ['natural-penicillins'],
#     [''],
#     'B',
#     'N'],
#    ['Rx',
#     'Ximino',
#     ['minocycline'],
#     ['tetracyclines'],
#     ['Dynacin', 'Minocin', 'Minocin PAC', 'Solodyn', 'Ximino'],
#     'D',
#     'N'],
#    ['Rx',
#     'Dynacin',
#     ['minocycline'],
#     ['tetracyclines'],
#     ['Dynacin', 'Minocin', 'Minocin PAC', 'Solodyn', 'Ximino'],
#     'D',
#     'N'],
#    ['Rx',
#     'penicillin g potassium',
#     ['penicillin G potassium'],
#     ['natural-penicillins'],
#     ['Pfizerpen'],
#     'B',
#     'N'],
#    ['Rx',
#     'Pfizerpen',
#     ['penicillin G potassium'],
#     ['natural-penicillins'],
#     ['Pfizerpen'],
#     'B',
#     'N']]],
#  [['acute alcohol intoxication'], [['Alcohol Poisoning']], []],
#  [['acute cholecystitis'], [[]], []],
#  [['acute coronary syndrome prophylaxis'],
#   [[]],
#   [['Rx',
#     'clopidogrel',
#     ['clopidogrel'],
#     ['platelet-aggregation-inhibitors'],
#     ['Plavix'],
#     'B',
#     'N'],
#    ['Rx',
#     'Plavix',
#     ['clopidogrel'],
#     ['platelet-aggregation-inhibitors'],
#     [],
#     'B',
#     'N']]],
#  [['acute coronary syndrome'],
#   [[]],
#   [['Rx',
#     'Plavix',
#     ['clopidogrel'],
#     ['platelet-aggregation-inhibitors'],
#     [],
#     'B',
#     'N'],
#    ['Rx',
#     'clopidogrel',
#     ['clopidogrel'],
#     ['platelet-aggregation-inhibitors'],
#     ['Plavix'],
#     'B',
#     'N'],
#    ['Rx',
#     'Effient',
#     ['prasugrel'],
#     ['platelet-aggregation-inhibitors'],
#     [],
#     'B',
#     'N'],
#    ['Rx',
#     'Brilinta',
#     ['ticagrelor'],
#     ['platelet-aggregation-inhibitors'],
#     [],
#     'C',
#     'N'],
#    ['Rx',
#     'ticagrelor',
#     ['ticagrelor'],
#     ['platelet-aggregation-inhibitors'],
#     ['Brilinta', 'Brilinta'],
#     'C',
#     'N'],
#    ['Rx',
#     'prasugrel',
#     ['prasugrel'],
#     ['platelet-aggregation-inhibitors'],
#     ['Effient'],
#     'B',
#     'N'],
#    ['Rx',
#     'enoxaparin',
#     ['enoxaparin'],
#     ['heparins'],
#     ['Lovenox', 'Lovenox HP', 'Clexane', 'Clexane Forte'],
#     'B',
#     'N'],
#    ['Rx', 'Lovenox', ['enoxaparin'], ['heparins'], [], 'B', 'N'],
#    ['Rx',
#     'Integrilin',
#     ['eptifibatide'],
#     ['glycoprotein-platelet-inhibitors'],
#     [],
#     'B',
#     'N'],
#    ['Rx',
#     'Aggrastat',
#     ['tirofiban'],
#     ['glycoprotein-platelet-inhibitors'],
#     ['Aggrastat'],
#     'B',
#     'N'],
#    ['Rx',
#     'eptifibatide',
#     ['eptifibatide'],
#     ['glycoprotein-platelet-inhibitors'],
#     ['Integrilin'],
#     'B',
#     'N'],
#    ['Rx',
#     'tirofiban',
#     ['tirofiban'],
#     ['glycoprotein-platelet-inhibitors'],
#     ['Aggrastat'],
#     'B',
#     'N']]],
#  [['acute disseminated encephalomyelitis'], [[]], []],
#  [['acute gout'],
#   [[]],
#   [['Rx',
#     'colchicine',
#     ['colchicine'],
#     ['antigout-agents'],
#     ['Colcrys', 'Mitigare', 'Gloperba'],
#     'C',
#     'N'],
#    ['Rx',
#     'indomethacin',
#     ['indomethacin'],
#     ['nonsteroidal-anti-inflammatory-agents'],
#     ['Indocin', 'Indocin SR', 'Tivorbex'],
#     'C',
#     'N'],
#    ['Rx', 'Colcrys', ['colchicine'], ['antigout-agents'], [], 'C', 'N'],
#    ['Rx',
#     'Indocin',
#     ['indomethacin'],
#     ['nonsteroidal-anti-inflammatory-agents'],
#     ['Indocin', 'Indocin SR', 'Tivorbex'],
#     'C',
#     'N'],
#    ['Rx/OTC',
#     'naproxen',
#     ['naproxen'],
#     ['nonsteroidal-anti-inflammatory-agents'],
#     [],
#     'C',
#     'N'],
#    ['Rx/OTC',
#     'ibuprofen',
#     [],
#     ['nonsteroidal-anti-inflammatory-agents'],
#     [],
#     'C',
#     'N'],
#    ['Rx/OTC',
#     'Advil',
#     ['ibuprofen'],
#     ['nonsteroidal-anti-inflammatory-agents'],
#     [],
#     'C',
#     'N'],
#    ['Rx/OTC',
#     'Aleve',
#     ['naproxen'],
#     ['nonsteroidal-anti-inflammatory-agents'],
#     [],
#     'C',
#     'N'],
#    ['Rx',
#     'methylprednisolone',
#     ['methylprednisolone'],
#     ['glucocorticoids'],
#     [],
#     'C',
#     'N'],
#    ['Rx',
#     'MethylPREDNISolone Dose Pack',
#     ['methylprednisolone'],
#     ['glucocorticoids'],
#     ['Medrol', 'Medrol Dosepak', 'MethylPREDNISolone Dose Pack'],
#     'C',
#     'N'],
#    ['Rx/OTC',
#     'Naprosyn',
#     ['naproxen'],
#     ['nonsteroidal-anti-inflammatory-agents'],
#     [],
#     'C',
#     'N'],
#    ['Rx/OTC',
#     'Advil Liqui-Gels',
#     ['Ibuprofen Capsules'],
#     ['nonsteroidal-anti-inflammatory-agents'],
#     ['Advil Liqui-Gels'],
#     'C',
#     'N'],
#    ['Rx/OTC',
#     'Motrin',
#     ['ibuprofen'],
#     ['nonsteroidal-anti-inflammatory-agents'],
#     [],
#     'C',
#     'N'],
#    ['Rx/OTC',
#     'A-G Profen',
#     ['ibuprofen'],
#     ['nonsteroidal-anti-inflammatory-agents'],
#     [],
#     'C',
#     'N'],
#    ['Rx/OTC',
#     'Actiprofen',
#     ['ibuprofen'],
#     ['nonsteroidal-anti-inflammatory-agents'],
#     [],
#     'C',
#     'N'],
#    ['Rx/OTC',
#     'Addaprin',
#     ['ibuprofen'],
#     ['nonsteroidal-anti-inflammatory-agents'],
#     [],
#     'C',
#     'N'],
#    ['Rx/OTC',
#     'Anaprox',
#     ['naproxen'],
#     ['nonsteroidal-anti-inflammatory-agents'],
#     [],
#     'C',
#     'N'],
#    ['Rx',
#     'Clinoril',
#     ['sulindac'],
#     ['nonsteroidal-anti-inflammatory-agents'],
#     ['Clinoril'],
#     'C',
#     'N'],
#    ['Rx/OTC',
#     'Genpril',
#     ['ibuprofen'],
#     ['nonsteroidal-anti-inflammatory-agents'],
#     ['Advil',
#      'Genpril',
#      'IBU',
#      'Midol IB',
#      'Motrin IB',
#      'Proprinal',
#      "Smart Sense Children's Ibuprofen"],
#     'C',
#     'N'],
#    ['Rx/OTC',
#     'IBU-200',
#     ['ibuprofen'],
#     ['nonsteroidal-anti-inflammatory-agents'],
#     [],
#     'C',
#     'N'],
#    ['Rx/OTC',
#     'Midol IB',
#     ['ibuprofen'],
#     ['nonsteroidal-anti-inflammatory-agents'],
#     ['Advil',
#      'Genpril',
#      'IBU',
#      'Midol IB',
#      'Motrin IB',
#      'Proprinal',
#      "Smart Sense Children's Ibuprofen"],
#     'C',
#     'N'],
#    ['Rx/OTC',
#     'Motrin IB',
#     ['ibuprofen'],
#     ['nonsteroidal-anti-inflammatory-agents'],
#     ['Advil',
#      'Genpril',
#      'IBU',
#      'Midol IB',
#      'Motrin IB',
#      'Proprinal',
#      "Smart Sense Children's Ibuprofen"],
#     'C',
#     'N'],
#    ['Rx/OTC',
#     'Nuprin',
#     ['ibuprofen'],
#     ['nonsteroidal-anti-inflammatory-agents'],
#     [],
#     'C',
#     'N'],
#    ['Rx/OTC',
#     'Proprinal',
#     ['ibuprofen'],
#     ['nonsteroidal-anti-inflammatory-agents'],
#     ['Advil',
#      'Genpril',
#      'IBU',
#      'Midol IB',
#      'Motrin IB',
#      'Proprinal',
#      "Smart Sense Children's Ibuprofen"],
#     'C',
#     'N'],
#    ['Rx/OTC',
#     'Aflaxen',
#     ['naproxen'],
#     ['nonsteroidal-anti-inflammatory-agents'],
#     [],
#     'C',
#     'N']]],
#  [['acute lymphoblastic leukemia'],
#   [[]],
#   [['Rx', 'methotrexate', ['methotrexate'], ['antimetabolites'], [], 'X', 'N'],
#    ['Rx',
#     'Gleevec',
#     ['imatinib'],
#     ['bcr-abl-tyrosine-kinase-inhibitors'],
#     [],
#     'D',
#     'N'],
#    ['Rx',
#     'mercaptopurine',
#     ['mercaptopurine'],
#     ['antimetabolites'],
#     ['Purixan', 'Purinethol'],
#     'D',
#     'N'],
#    ['Rx',
#     'Sprycel',
#     ['dasatinib'],
#     ['bcr-abl-tyrosine-kinase-inhibitors'],
#     [],
#     'D',
#     'N'],
#    ['Rx',
#     'Blincyto',
#     ['blinatumomab'],
#     ['miscellaneous-antineoplastics'],
#     ['Blincyto'],
#     'C',
#     'N'],
#    ['Rx',
#     'Adriamycin',
#     ['doxorubicin'],
#     ['antibiotics-antineoplastics'],
#     ['Adriamycin'],
#     'D',
#     'N'],
#    ['Rx',
#     'dasatinib',
#     ['dasatinib'],
#     ['bcr-abl-tyrosine-kinase-inhibitors'],
#     ['Sprycel'],
#     'D',
#     'N'],
#    ['Rx',
#     'pegaspargase',
#     ['pegaspargase'],
#     ['miscellaneous-antineoplastics'],
#     ['Oncaspar'],
#     'C',
#     'N'],
#    ['Rx',
#     'Trexall',
#     ['methotrexate'],
#     ['antimetabolites'],
#     ['Trexall', 'Xatmep'],
#     'X',
#     'N'],
#    ['Rx',
#     'Iclusig',
#     ['ponatinib'],
#     ['bcr-abl-tyrosine-kinase-inhibitors'],
#     [],
#     'D',
#     'N'],
#    ['Rx',
#     'doxorubicin',
#     ['doxorubicin'],
#     ['antibiotics-antineoplastics'],
#     ['Adriamycin', 'Adriamycin RDF', 'Rubex', 'Adriamycin PFS'],
#     'D',
#     'N'],
#    ['Rx',
#     'imatinib',
#     ['imatinib'],
#     ['bcr-abl-tyrosine-kinase-inhibitors'],
#     ['Gleevec'],
#     'D',
#     'N'],
#    ['Rx',
#     'Purinethol',
#     ['Mercaptopurine Tablets'],
#     ['antimetabolites'],
#     ['Purinethol'],
#     'D',
#     'N'],
#    ['Rx',
#     'Oncaspar',
#     ['pegaspargase'],
#     ['miscellaneous-antineoplastics'],
#     ['Oncaspar'],
#     'C',
#     'N'],
#    ['Rx',
#     'asparaginase erwinia chrysanthemi',
#     ['asparaginase Erwinia chrysanthemi'],
#     ['miscellaneous-antineoplastics'],
#     ['Erwinaze'],
#     'C',
#     'N'],
#    ['Rx',
#     'vincristine liposome',
#     ['vincristine liposome'],
#     ['mitotic-inhibitors'],
#     ['Marqibo'],
#     'D',
#     'N'],
#    ['Rx',
#     'Xatmep',
#     ['methotrexate'],
#     ['antimetabolites'],
#     ['Trexall', 'Xatmep'],
#     'X',
#     'N'],
#    ['Rx',
#     'blinatumomab',
#     ['blinatumomab'],
#     ['miscellaneous-antineoplastics'],
#     ['Blincyto'],
#     'C',
#     'N'],
#    ['Rx',
#     'Marqibo',
#     ['vincristine liposome'],
#     ['mitotic-inhibitors'],
#     [],
#     'D',
#     'N'],
#    ['Rx',
#     'ponatinib',
#     ['ponatinib'],
#     ['bcr-abl-tyrosine-kinase-inhibitors'],
#     ['Iclusig'],
#     'D',
#     'N'],
#    ['Rx',
#     'Erwinaze',
#     ['asparaginase Erwinia chrysanthemi'],
#     ['miscellaneous-antineoplastics'],
#     [],
#     'C',
#     'N'],
#    ['Rx', 'Arranon', ['nelarabine'], ['antimetabolites'], [], 'D', 'N'],
#    ['Rx',
#     'Besponsa',
#     ['inotuzumab ozogamicin'],
#     ['miscellaneous-antineoplastics'],
#     ['Besponsa'],
#     [],
#     'N'],
#    ['Rx',
#     'clofarabine',
#     ['clofarabine'],
#     ['antimetabolites'],
#     ['Clolar'],
#     'D',
#     'N'],
#    ['Rx', 'Clolar', ['clofarabine'], ['antimetabolites'], [], 'D', 'N']]],
#  [['acute lymphocytic leukemia'],
#   [['Acute childhood leukemia; ALL Leukemia; Cancer, Acute Childhood Leukemia; Cancer, Acute Lymphocytic Leukemia; Leukemia, Acute Childhood; Leukemia, Acute Lymphocytic']],
#   [['Rx', 'prednisone', ['prednisone'], ['glucocorticoids'], [], 'C', 'N'],
#    ['Rx',
#     'vincristine',
#     ['vincristine'],
#     ['mitotic-inhibitors'],
#     ['Oncovin', 'Vincasar PFS'],
#     'D',
#     'N'],
#    ['Rx',
#     'cyclophosphamide',
#     ['cyclophosphamide'],
#     ['alkylating-agents'],
#     ['Cytoxan', 'Neosar', 'Cytoxan Lyophilized'],
#     'D',
#     'N'],
#    ['Rx', 'methotrexate', ['methotrexate'], ['antimetabolites'], [], 'X', 'N'],
#    ['Rx',
#     'asparaginase escherichia coli',
#     ['Asparaginase'],
#     ['miscellaneous-antineoplastics'],
#     [],
#     'C',
#     'N'],
#    ['Rx',
#     'Trexall',
#     ['methotrexate'],
#     ['antimetabolites'],
#     ['Trexall', 'Xatmep'],
#     'X',
#     'N'],
#    ['Rx',
#     'daunorubicin',
#     ['daunorubicin'],
#     ['antibiotics-antineoplastics'],
#     ['Cerubidine'],
#     'D',
#     'N'],
#    ['Rx', 'Elspar', [], ['miscellaneous-antineoplastics'], [], 'C', 'N'],
#    ['Rx',
#     'Cerubidine',
#     ['daunorubicin'],
#     ['antibiotics-antineoplastics'],
#     ['Cerubidine'],
#     'D',
#     'N'],
#    ['Rx',
#     'asparaginase erwinia chrysanthemi',
#     ['asparaginase Erwinia chrysanthemi'],
#     ['miscellaneous-antineoplastics'],
#     ['Erwinaze'],
#     'C',
#     'N'],
#    ['Rx',
#     'Erwinaze',
#     ['asparaginase Erwinia chrysanthemi'],
#     ['miscellaneous-antineoplastics'],
#     [],
#     'C',
#     'N'],
#    ['Rx',
#     'teniposide',
#     ['teniposide'],
#     ['mitotic-inhibitors'],
#     ['Vumon'],
#     'D',
#     'N']]],
#  [['acute meibomianitis'], [['Chalazion; Meibomian gland lipogranuloma']], []],
#  [['acute mountain sickness'],
#   [[]],
#   [['Rx',
#     'Diamox',
#     ['acetazolamide'],
#     ['carbonic-anhydrase-inhibitor-anticonvulsants'],
#     ['Diamox', 'Diamox Sequels'],
#     'C',
#     'N'],
#    ['Rx',
#     'acetazolamide',
#     ['acetazolamide'],
#     ['carbonic-anhydrase-inhibitor-anticonvulsants'],
#     ['Diamox', 'Diamox Sequels'],
#     'C',
#     'N'],
#    ['Rx',
#     'dexamethasone',
#     ['dexamethasone'],
#     ['glucocorticoids'],
#     [],
#     'C',
#     'N'],
#    ['Rx',
#     'Dexamethasone Intensol',
#     ['dexamethasone'],
#     ['glucocorticoids'],
#     ['Baycadron',
#      'Dexamethasone Intensol',
#      'DexPak 10 Day Taperpak',
#      'DexPak 13 DayTaperpak',
#      'DexPak 6 DayTaperpak'],
#     'C',
#     'N'],
#    ['Rx',
#     'Dexpak Taperpak',
#     ['dexamethasone'],
#     ['glucocorticoids'],
#     ['Baycadron',
#      'Dexamethasone Intensol',
#      'DexPak 10 Day Taperpak',
#      'DexPak 13 DayTaperpak',
#      'DexPak 6 DayTaperpak'],
#     'C',
#     'N'],
#    ['Rx',
#     'Diamox Sequels',
#     ['acetazolamide'],
#     ['carbonic-anhydrase-inhibitor-anticonvulsants'],
#     ['Diamox', 'Diamox Sequels'],
#     'C',
#     'N'],
#    ['Rx',
#     'De-Sone LA',
#     ['dexamethasone'],
#     ['glucocorticoids'],
#     ['De-Sone LA',
#      'Dexacen-4',
#      'Dexasone',
#      'Dexasone LA',
#      'Solurex',
#      'Solurex LA'],
#     'C',
#     'N'],
#    ['Rx', 'Dxevo', [], ['glucocorticoids'], [], 'C', 'N'],
#    ['Rx', 'HiDex', [], ['glucocorticoids'], [], 'C', 'N']]],
#  [['acute myeloblastic leukemia'],
#   [[]],
#   [['Rx',
#     'doxorubicin',
#     ['doxorubicin'],
#     ['antibiotics-antineoplastics'],
#     ['Adriamycin', 'Adriamycin RDF', 'Rubex', 'Adriamycin PFS'],
#     'D',
#     'N'],
#    ['Rx',
#     'Adriamycin',
#     ['doxorubicin'],
#     ['antibiotics-antineoplastics'],
#     ['Adriamycin'],
#     'D',
#     'N']]],
#  [['acute myeloid leukemia'],
#   [['Acute Granulocytic Leukemia; Acute Myelogenous Leukemia; AML; Cancer, Acute Granulocytic Leukemia; Cancer, Acute Myelogenous Leukemia; Cancer, Acute Myeloid Leukemia; Leukemia, Acute Granulocytic; Leukemia, Acute Myelogenous; Leukemia, Acute Myeloid']],
#   [['Rx',
#     'cytarabine',
#     ['cytarabine'],
#     ['antimetabolites'],
#     ['Cytosar-U', 'Tarabine PFS', 'Cytosar'],
#     'D',
#     'N'],
#    ['Rx',
#     'Idhifa',
#     ['enasidenib'],
#     ['miscellaneous-antineoplastics'],
#     [],
#     [],
#     'N'],
#    ['Rx',
#     'vincristine',
#     ['vincristine'],
#     ['mitotic-inhibitors'],
#     ['Oncovin', 'Vincasar PFS'],
#     'D',
#     'N'],
#    ['Rx',
#     'daunorubicin',
#     ['daunorubicin'],
#     ['antibiotics-antineoplastics'],
#     ['Cerubidine'],
#     'D',
#     'N'],
#    ['Rx',
#     'idarubicin',
#     ['idarubicin'],
#     ['antibiotics-antineoplastics'],
#     ['Idamycin PFS', 'Idamycin'],
#     'D',
#     'N'],
#    ['Rx',
#     'Tibsovo',
#     ['ivosidenib'],
#     ['miscellaneous-antineoplastics'],
#     [],
#     [],
#     'N'],
#    ['Rx',
#     'decitabine',
#     ['decitabine'],
#     ['antimetabolites'],
#     ['Dacogen'],
#     'D',
#     'N'],
#    ['Rx',
#     'Cerubidine',
#     ['daunorubicin'],
#     ['antibiotics-antineoplastics'],
#     ['Cerubidine'],
#     'D',
#     'N'],
#    ['Rx',
#     'Venclexta',
#     ['venetoclax'],
#     ['miscellaneous-antineoplastics'],
#     [],
#     [],
#     'N'],
#    ['Rx',
#     'venetoclax',
#     ['venetoclax'],
#     ['miscellaneous-antineoplastics'],
#     ['Venclexta', 'Venclexta Starting Pack'],
#     [],
#     'N'],
#    ['Rx',
#     'Vyxeos',
#     ['cytarabine and daunorubicin  )'],
#     ['antineoplastic-combinations'],
#     ['Vyxeos'],
#     [],
#     'N'],
#    ['Rx',
#     'Mylotarg',
#     ['gemtuzumab ozogamicin'],
#     ['cd33-monoclonal-antibodies'],
#     ['Mylotarg'],
#     'D',
#     'N'],
#    ['Rx',
#     'gemtuzumab',
#     ['gemtuzumab ozogamicin'],
#     ['cd33-monoclonal-antibodies'],
#     ['Mylotarg'],
#     'D',
#     'N'],
#    ['Rx',
#     'midostaurin',
#     ['midostaurin'],
#     ['multikinase-inhibitors'],
#     ['Rydapt'],
#     [],
#     'N'],
#    ['Rx', 'Rydapt', ['midostaurin'], ['multikinase-inhibitors'], [], [], 'N'],
#    ['Rx',
#     'enasidenib',
#     ['enasidenib'],
#     ['miscellaneous-antineoplastics'],
#     ['Idhifa'],
#     [],
#     'N'],
#    ['Rx',
#     'cytarabine liposomal / daunorubicin liposomal',
#     ['cytarabine and daunorubicin  )'],
#     ['antineoplastic-combinations'],
#     ['Vyxeos'],
#     [],
#     'N'],
#    ['Rx',
#     'Xospata',
#     ['gilteritinib'],
#     ['multikinase-inhibitors'],
#     [],
#     [],
#     'N'],
#    ['Rx',
#     'Daurismo',
#     ['glasdegib'],
#     ['hedgehog-pathway-inhibitors'],
#     [],
#     [],
#     'N'],
#    ['Rx',
#     'gilteritinib',
#     ['gilteritinib'],
#     ['multikinase-inhibitors'],
#     ['Xospata'],
#     [],
#     'N'],
#    ['Rx',
#     'glasdegib',
#     ['glasdegib'],
#     ['hedgehog-pathway-inhibitors'],
#     ['Daurismo'],
#     [],
#     'N'],
#    ['Rx',
#     'Idamycin PFS',
#     ['idarubicin'],
#     ['antibiotics-antineoplastics'],
#     ['Idamycin PFS'],
#     'D',
#     'N'],
#    ['Rx',
#     'ivosidenib',
#     ['ivosidenib'],
#     ['miscellaneous-antineoplastics'],
#     ['Tibsovo'],
#     [],
#     'N']]],
#  [['acute nonlymphocytic leukemia'],
#   [[]],
#   [['Rx',
#     'Tabloid',
#     ['thioguanine'],
#     ['antimetabolites'],
#     ['Tabloid'],
#     'D',
#     'N'],
#    ['Rx',
#     'isotretinoin',
#     ['isotretinoin'],
#     ['miscellaneous-antineoplastics'],
#     ['Absorica',
#      'Amnesteem',
#      'Claravis',
#      'Myorisan',
#      'Sotret',
#      'Zenatane',
#      'Accutane',
#      'Absorica LD'],
#     'X',
#     'N'],
#    ['Rx', 'methotrexate', ['methotrexate'], ['antimetabolites'], [], 'X', 'N'],
#    ['Rx',
#     'thioguanine',
#     ['thioguanine'],
#     ['antimetabolites'],
#     ['Tabloid'],
#     'D',
#     'N'],
#    ['Rx',
#     'mitoxantrone',
#     ['mitoxantrone'],
#     ['antibiotics-antineoplastics'],
#     ['Novantrone'],
#     'D',
#     'N'],
#    ['Rx',
#     'Claravis',
#     ['isotretinoin'],
#     ['miscellaneous-antineoplastics'],
#     ['Absorica', 'Amnesteem', 'Claravis', 'Myorisan', 'Sotret', 'Zenatane'],
#     'X',
#     'N'],
#    ['Rx',
#     'cyclophosphamide',
#     ['cyclophosphamide'],
#     ['alkylating-agents'],
#     ['Cytoxan', 'Neosar', 'Cytoxan Lyophilized'],
#     'D',
#     'N'],
#    ['Rx',
#     'Cerubidine',
#     ['daunorubicin'],
#     ['antibiotics-antineoplastics'],
#     ['Cerubidine'],
#     'D',
#     'N'],
#    ['Rx',
#     'daunorubicin',
#     ['daunorubicin'],
#     ['antibiotics-antineoplastics'],
#     ['Cerubidine'],
#     'D',
#     'N'],
#    ['Rx',
#     'cytarabine',
#     ['cytarabine'],
#     ['antimetabolites'],
#     ['Cytosar-U', 'Tarabine PFS', 'Cytosar'],
#     'D',
#     'N'],
#    ['Rx',
#     'Amnesteem',
#     ['isotretinoin'],
#     ['miscellaneous-antineoplastics'],
#     ['Absorica', 'Amnesteem', 'Claravis', 'Myorisan', 'Sotret', 'Zenatane'],
#     'X',
#     'N'],
#    ['Rx',
#     'Sotret',
#     ['isotretinoin'],
#     ['miscellaneous-antineoplastics'],
#     ['Absorica', 'Amnesteem', 'Claravis', 'Myorisan', 'Sotret', 'Zenatane'],
#     'X',
#     'N'],
#    ['Rx',
#     'Myorisan',
#     ['isotretinoin'],
#     ['miscellaneous-antineoplastics'],
#     ['Absorica', 'Amnesteem', 'Claravis', 'Myorisan', 'Sotret', 'Zenatane'],
#     'X',
#     'N']]],
#  [['acute otitis externa'],
#   [["Ear Infection, acute outer; Otitis Externa, acute; Swimmer's Ear, acute"]],
#   [['Rx',
#     'ofloxacin',
#     ['ofloxacin otic'],
#     ['otic-anti-infectives'],
#     ['Floxin Otic', 'Floxin Otic Singles'],
#     'C',
#     'N'],
#    ['Rx',
#     'Cipro HC',
#     ['ciprofloxacin and hydrocortisone'],
#     ['otic-steroids-with-anti-infectives'],
#     ['Cipro HC'],
#     'C',
#     'N'],
#    ['Rx',
#     'ciprofloxacin',
#     ['ciprofloxacin otic'],
#     ['otic-anti-infectives'],
#     ['Cetraxal', 'Otiprio'],
#     'C',
#     'N'],
#    ['Rx',
#     'ciprofloxacin / hydrocortisone',
#     ['ciprofloxacin and hydrocortisone'],
#     ['otic-steroids-with-anti-infectives'],
#     ['Cipro HC'],
#     'C',
#     'N'],
#    ['Rx',
#     'Floxin Otic',
#     ['ofloxacin otic'],
#     ['otic-anti-infectives'],
#     [],
#     'C',
#     'N'],
#    ['Rx',
#     'dexamethasone',
#     ['dexamethasone  )'],
#     ['ophthalmic-steroids'],
#     ['Dextenza', 'Dexycu', 'Ozurdex'],
#     'C',
#     'N'],
#    ['Rx',
#     'Cortisporin-TC',
#     ['colistin', 'hydrocortisone', 'neomycin', 'and thonzonium  )'],
#     ['otic-steroids-with-anti-infectives'],
#     ['Coly-Mycin S', 'Cortisporin-TC'],
#     'N',
#     'N'],
#    ['Rx',
#     'Cetraxal',
#     ['ciprofloxacin otic'],
#     ['otic-anti-infectives'],
#     [],
#     'C',
#     'N'],
#    ['Rx',
#     'Maxidex',
#     ['dexamethasone'],
#     ['ophthalmic-steroids'],
#     ['Maxidex'],
#     'C',
#     'N'],
#    ['Rx',
#     'colistin sulfate / hydrocortisone / neomycin / thonzonium bromide',
#     ['colistin', 'hydrocortisone', 'neomycin', 'and thonzonium  )'],
#     ['otic-steroids-with-anti-infectives'],
#     ['Coly-Mycin S', 'Cortisporin-TC', 'Coly Mycin S'],
#     'N',
#     'N'],
#    ['Rx',
#     'Otiprio',
#     ['ciprofloxacin otic'],
#     ['otic-anti-infectives'],
#     ['Cetraxal', 'Otiprio'],
#     'C',
#     'N'],
#    ['Rx',
#     'Coly-Mycin S',
#     ['colistin', 'hydrocortisone', 'neomycin', 'and thonzonium  )'],
#     ['otic-steroids-with-anti-infectives'],
#     ['Coly-Mycin S', 'Cortisporin-TC'],
#     'N',
#     'N']]],
#  [['acute promyelocytic leukemia'],
#   [['Cancer, Acute Promyelocytic Leukemia; Leukemia, Acute Promyelocytic']],
#   [['Rx',
#     'tretinoin',
#     ['tretinoin'],
#     ['miscellaneous-antineoplastics'],
#     ['Vesanoid'],
#     'D',
#     'N'],
#    ['Rx',
#     'Trisenox',
#     ['arsenic trioxide'],
#     ['miscellaneous-antineoplastics'],
#     ['Trisenox'],
#     'D',
#     'N'],
#    ['Rx',
#     'arsenic trioxide',
#     ['arsenic trioxide'],
#     ['miscellaneous-antineoplastics'],
#     ['Trisenox'],
#     'D',
#     'N']]],
#  [['acute surgical abdomen'], [[]], []],
#  [['adams stokes syndrome'],
#   [[]],
#   [['Rx/OTC',
#     'Adrenalin',
#     ['epinephrine injection'],
#     ['adrenergic-bronchodilators'],
#     ['Adrenalin',
#      'Auvi-Q',
#      'Epinephrinesnap-EMS',
#      'Epinephrinesnap-V',
#      'EpiPen 2-Pak',
#      'EpiPen JR 2-Pak',
#      'EPIsnap',
#      'Symjepi'],
#     'C',
#     'N'],
#    ['Rx/OTC',
#     'epinephrine',
#     ['epinephrine injection'],
#     ['adrenergic-bronchodilators'],
#     ['Adrenalin',
#      'Auvi-Q',
#      'Epinephrinesnap-EMS',
#      'Epinephrinesnap-V',
#      'EpiPen 2-Pak',
#      'EpiPen JR 2-Pak',
#      'EPIsnap',
#      'Symjepi'],
#     'C',
#     'N'],
#    ['Rx', 'ephedrine', [], ['decongestants'], [], 'C', 'N'],
#    ['Rx',
#     'isoproterenol',
#     ['Isoproterenol'],
#     ['adrenergic-bronchodilators'],
#     ['Isuprel'],
#     'C',
#     'N'],
#    ['Rx/OTC',
#     'Adrenaclick',
#     ['epinephrine'],
#     ['adrenergic-bronchodilators'],
#     [],
#     'C',
#     'N'],
#    ['Rx',
#     'Isuprel',
#     ['Isoproterenol'],
#     ['adrenergic-bronchodilators'],
#     ['Isuprel'],
#     'C',
#     'N'],
#    ['Rx/OTC',
#     'Adrenalin Chloride',
#     ['epinephrine'],
#     ['adrenergic-bronchodilators'],
#     [],
#     'C',
#     'N']]],
#  [['addison s disease'],
#   [['Primary Adrenocortical Insufficiency']],
#   [['Rx',
#     'hydrocortisone',
#     ['hydrocortisone'],
#     ['glucocorticoids'],
#     ['Cortef'],
#     'C',
#     'N'],
#    ['Rx',
#     'fludrocortisone',
#     ['fludrocortisone'],
#     ['mineralocorticoids'],
#     ['Florinef Acetate'],
#     'C',
#     'N'],
#    ['Rx', 'Florinef', [], ['mineralocorticoids'], [], 'C', 'N'],
#    ['Rx',
#     'Cortef',
#     ['hydrocortisone'],
#     ['glucocorticoids'],
#     ['Cortef'],
#     'C',
#     'N'],
#    ['Rx',
#     'dexamethasone',
#     ['dexamethasone'],
#     ['glucocorticoids'],
#     [],
#     'C',
#     'N'],
#    ['Rx',
#     'Florinef Acetate',
#     ['fludrocortisone'],
#     ['mineralocorticoids'],
#     ['Florinef Acetate'],
#     'C',
#     'N'],
#    ['Rx',
#     'Solu-Cortef',
#     ['hydrocortisone'],
#     ['glucocorticoids'],
#     ['Solu-CORTEF'],
#     'C',
#     'N'],
#    ['Rx',
#     'Dexamethasone Intensol',
#     ['dexamethasone'],
#     ['glucocorticoids'],
#     ['Baycadron',
#      'Dexamethasone Intensol',
#      'DexPak 10 Day Taperpak',
#      'DexPak 13 DayTaperpak',
#      'DexPak 6 DayTaperpak'],
#     'C',
#     'N'],
#    ['Rx',
#     'Dexpak Taperpak',
#     ['dexamethasone'],
#     ['glucocorticoids'],
#     ['Baycadron',
#      'Dexamethasone Intensol',
#      'DexPak 10 Day Taperpak',
#      'DexPak 13 DayTaperpak',
#      'DexPak 6 DayTaperpak'],
#     'C',
#     'N'],
#    ['Rx',
#     'De-Sone LA',
#     ['dexamethasone'],
#     ['glucocorticoids'],
#     ['De-Sone LA',
#      'Dexacen-4',
#      'Dexasone',
#      'Dexasone LA',
#      'Solurex',
#      'Solurex LA'],
#     'C',
#     'N'],
#    ['Rx',
#     'ZoDex',
#     ['Dexamethasone Tablets'],
#     ['glucocorticoids'],
#     ['ZoDex'],
#     'C',
#     'N'],
#    ['Rx', 'Dxevo', [], ['glucocorticoids'], [], 'C', 'N']]],
#  [['adenomyosis'], [['Uterine Endometriosis']], []],
#  [['adenosine deaminase deficiency'],
#   [['ADA Deficiency']],
#   [['Rx',
#     'Revcovi',
#     ['elapegademase'],
#     ['other-immunostimulants'],
#     ['Revcovi'],
#     [],
#     'N'],
#    ['Rx',
#     'pegademase bovine',
#     ['pegademase bovine'],
#     ['other-immunostimulants'],
#     ['Adagen'],
#     'C',
#     'N'],
#    ['Rx',
#     'elapegademase',
#     ['elapegademase'],
#     ['other-immunostimulants'],
#     ['Revcovi'],
#     [],
#     'N']]],
#  [['adenovirus prophylaxis'],
#   [[]],
#   [['Rx', 'adenovirus vaccine', [], ['viral-vaccines'], [], [], 'N']]],
#  [['adhesive arachnoiditis'], [[]], []],
#  [['adjunct to antibiotic therapy'],
#   [[]],
#   [['Rx',
#     'probenecid',
#     ['probenecid'],
#     ['antigout-agents'],
#     ['Benemid'],
#     'N',
#     'N']]],
#  [['adrenal cortical carcinoma'],
#   [[]],
#   [['Rx',
#     'mitotane',
#     ['mitotane'],
#     ['miscellaneous-antineoplastics'],
#     ['Lysodren'],
#     'D',
#     'N'],
#    ['Rx',
#     'Lysodren',
#     ['mitotane'],
#     ['miscellaneous-antineoplastics'],
#     ['Lysodren'],
#     'D',
#     'N']]],
#  [['adrenal gland disorders'], [[]], []],
#  [['adrenal hemorrhage'], [[]], []],
#  [['adrenal insufficiency'],
#   [['Adrenal crisis, acute; Adrenal failure; Adrenal insufficiency, exogenous']],
#   [['Rx',
#     'dexamethasone',
#     ['dexamethasone'],
#     ['glucocorticoids'],
#     [],
#     'C',
#     'N'],
#    ['Rx',
#     'cortisone',
#     ['cortisone'],
#     ['glucocorticoids'],
#     ['Cortone Acetate'],
#     'N',
#     'N'],
#    ['Rx',
#     'Dexamethasone Intensol',
#     ['dexamethasone'],
#     ['glucocorticoids'],
#     ['Baycadron',
#      'Dexamethasone Intensol',
#      'DexPak 10 Day Taperpak',
#      'DexPak 13 DayTaperpak',
#      'DexPak 6 DayTaperpak'],
#     'C',
#     'N'],
#    ['Rx',
#     'Cortone Acetate',
#     ['cortisone'],
#     ['glucocorticoids'],
#     ['Cortone Acetate'],
#     'N',
#     'N'],
#    ['Rx',
#     'Dexpak Taperpak',
#     ['dexamethasone'],
#     ['glucocorticoids'],
#     ['Baycadron',
#      'Dexamethasone Intensol',
#      'DexPak 10 Day Taperpak',
#      'DexPak 13 DayTaperpak',
#      'DexPak 6 DayTaperpak'],
#     'C',
#     'N'],
#    ['Rx',
#     'De-Sone LA',
#     ['dexamethasone'],
#     ['glucocorticoids'],
#     ['De-Sone LA',
#      'Dexacen-4',
#      'Dexasone',
#      'Dexasone LA',
#      'Solurex',
#      'Solurex LA'],
#     'C',
#     'N'],
#    ['Rx',
#     'ZoDex',
#     ['Dexamethasone Tablets'],
#     ['glucocorticoids'],
#     ['ZoDex'],
#     'C',
#     'N'],
#    ['Rx', 'Dxevo', [], ['glucocorticoids'], [], 'C', 'N']]],
#  [['adrenal tuberculosis'], [[]], []],
#  [['adrenal tumor'], [[]], []],
#  [['adrenocortical insufficiency'],
#   [[]],
#   [['Rx',
#     'hydrocortisone',
#     ['hydrocortisone'],
#     ['glucocorticoids'],
#     ['Cortef'],
#     'C',
#     'N'],
#    ['Rx',
#     'Cortef',
#     ['hydrocortisone'],
#     ['glucocorticoids'],
#     ['Cortef'],
#     'C',
#     'N'],
#    ['Rx', 'prednisone', ['prednisone'], ['glucocorticoids'], [], 'C', 'N'],
#    ['Rx',
#     'dexamethasone',
#     ['dexamethasone'],
#     ['glucocorticoids'],
#     [],
#     'C',
#     'N'],
#    ['Rx',
#     'Solu-Cortef',
#     ['hydrocortisone'],
#     ['glucocorticoids'],
#     ['Solu-CORTEF'],
#     'C',
#     'N'],
#    ['Rx',
#     'triamcinolone',
#     ['triamcinolone'],
#     ['glucocorticoids'],
#     [],
#     'C',
#     'N'],
#    ['Rx',
#     'Cortrosyn',
#     ['cosyntropin'],
#     ['corticotropin'],
#     ['Cortrosyn'],
#     'C',
#     'N'],
#    ['Rx',
#     'Dexamethasone Intensol',
#     ['dexamethasone'],
#     ['glucocorticoids'],
#     ['Baycadron',
#      'Dexamethasone Intensol',
#      'DexPak 10 Day Taperpak',
#      'DexPak 13 DayTaperpak',
#      'DexPak 6 DayTaperpak'],
#     'C',
#     'N'],
#    ['Rx',
#     'Kenalog-40',
#     ['triamcinolone'],
#     ['glucocorticoids'],
#     ['Kenalog-40', 'Zilretta'],
#     'C',
#     'N'],
#    ['Rx',
#     'cosyntropin',
#     ['cosyntropin'],
#     ['corticotropin'],
#     ['Cortrosyn'],
#     'C',
#     'N'],
#    ['Rx',
#     'De-Sone LA',
#     ['dexamethasone'],
#     ['glucocorticoids'],
#     ['De-Sone LA',
#      'Dexacen-4',
#      'Dexasone',
#      'Dexasone LA',
#      'Solurex',
#      'Solurex LA'],
#     'C',
#     'N'],
#    ['Rx',
#     'Dexpak Taperpak',
#     ['dexamethasone'],
#     ['glucocorticoids'],
#     ['Baycadron',
#      'Dexamethasone Intensol',
#      'DexPak 10 Day Taperpak',
#      'DexPak 13 DayTaperpak',
#      'DexPak 6 DayTaperpak'],
#     'C',
#     'N'],
#    ['Rx', 'Dxevo', [], ['glucocorticoids'], [], 'C', 'N']]],
#  [['adrenogenital syndrome'],
#   [['21-hydroxylase deficiency; Congenital Adrenal Hyperplasia']],
#   [['Rx',
#     'fludrocortisone',
#     ['fludrocortisone'],
#     ['mineralocorticoids'],
#     ['Florinef Acetate'],
#     'C',
#     'N'],
#    ['Rx', 'Florinef', [], ['mineralocorticoids'], [], 'C', 'N'],
#    ['Rx', 'prednisone', ['prednisone'], ['glucocorticoids'], [], 'C', 'N'],
#    ['Rx',
#     'dexamethasone',
#     ['dexamethasone'],
#     ['glucocorticoids'],
#     [],
#     'C',
#     'N'],
#    ['Rx',
#     'methylprednisolone',
#     ['methylprednisolone'],
#     ['glucocorticoids'],
#     [],
#     'C',
#     'N'],
#    ['Rx',
#     'Florinef Acetate',
#     ['fludrocortisone'],
#     ['mineralocorticoids'],
#     ['Florinef Acetate'],
#     'C',
#     'N'],
#    ['Rx',
#     'Depo-Medrol',
#     ['methylprednisolone'],
#     ['glucocorticoids'],
#     ['A-Methapred', 'DEPO-Medrol', 'SOLU-Medrol'],
#     'C',
#     'N'],
#    ['Rx',
#     'Dexamethasone Intensol',
#     ['dexamethasone'],
#     ['glucocorticoids'],
#     ['Baycadron',
#      'Dexamethasone Intensol',
#      'DexPak 10 Day Taperpak',
#      'DexPak 13 DayTaperpak',
#      'DexPak 6 DayTaperpak'],
#     'C',
#     'N'],
#    ['Rx',
#     'MethylPREDNISolone Dose Pack',
#     ['methylprednisolone'],
#     ['glucocorticoids'],
#     ['Medrol', 'Medrol Dosepak', 'MethylPREDNISolone Dose Pack'],
#     'C',
#     'N'],
#    ['Rx',
#     'Medrol Dosepak',
#     ['methylprednisolone'],
#     ['glucocorticoids'],
#     ['Medrol', 'Medrol Dosepak', 'MethylPREDNISolone Dose Pack'],
#     'C',
#     'N'],
#    ['Rx',
#     'Solu-Medrol',
#     ['methylprednisolone'],
#     ['glucocorticoids'],
#     ['A-Methapred', 'DEPO-Medrol', 'SOLU-Medrol'],
#     'C',
#     'N'],
#    ['Rx',
#     'Medrol',
#     ['methylprednisolone'],
#     ['glucocorticoids'],
#     ['Medrol', 'Medrol Dosepak', 'MethylPREDNISolone Dose Pack'],
#     'C',
#     'N'],
#    ['Rx',
#     'De-Sone LA',
#     ['dexamethasone'],
#     ['glucocorticoids'],
#     ['De-Sone LA',
#      'Dexacen-4',
#      'Dexasone',
#      'Dexasone LA',
#      'Solurex',
#      'Solurex LA'],
#     'C',
#     'N'],
#    ['Rx',
#     'Dexpak Taperpak',
#     ['dexamethasone'],
#     ['glucocorticoids'],
#     ['Baycadron',
#      'Dexamethasone Intensol',
#      'DexPak 10 Day Taperpak',
#      'DexPak 13 DayTaperpak',
#      'DexPak 6 DayTaperpak'],
#     'C',
#     'N'],
#    ['Rx',
#     'ZoDex',
#     ['Dexamethasone Tablets'],
#     ['glucocorticoids'],
#     ['ZoDex'],
#     'C',
#     'N'],
#    ['Rx', 'Dxevo', [], ['glucocorticoids'], [], 'C', 'N']]],
#  [['adult human growth hormone deficiency'],
#   [[]],
#   [['Rx',
#     'somatropin',
#     ['somatropin'],
#     ['growth-hormones'],
#     ['Genotropin',
#      'Humatrope',
#      'Norditropin FlexPro Pen',
#      'Nutropin AQ NuSpin 10',
#      'Omnitrope',
#      'Saizen',
#      'Serostim',
#      'Zomacton',
#      'Zorbtive',
#      'Norditropin',
#      'Nutropin AQ',
#      'Nutropin Depot',
#      'Norditropin Cartridge',
#      'Genotropin Miniquick',
#      'Tev-tropin',
#      'Norditropin Nordiflex Pen',
#      'Saizen Click-Easy',
#      'Omnitrope Pen 5 Cartridge',
#      'HumatroPen',
#      'Omnitrope Pen 10 Cartridge',
#      'Nutropin AQ Pen 20 Cartridge',
#      'Nutropin AQ Pen 10 Cartridge',
#      'Nutropin AQ NuSpin 5',
#      'Nutropin AQ NuSpin 20',
#      'Saizen Kit',
#      'Nutropin',
#      'Norditropin',
#      'Nutropin AQ',
#      'Nutropin Depot',
#      'Norditropin Cartridge',
#      'Genotropin Miniquick',
#      'Tev-tropin',
#      'Norditropin Nordiflex Pen',
#      'Saizen Click-Easy',
#      'Omnitrope Pen 5 Cartridge',
#      'HumatroPen',
#      'Omnitrope Pen 10 Cartridge',
#      'Nutropin AQ Pen 20 Cartridge',
#      'Nutropin AQ Pen 10 Cartridge',
#      'Nutropin AQ NuSpin 5',
#      'Nutropin AQ NuSpin 20',
#      'Saizen Kit'],
#     'C',
#     'N'],
#    ['Rx',
#     'Genotropin',
#     ['somatropin'],
#     ['growth-hormones'],
#     ['Genotropin',
#      'Humatrope',
#      'Norditropin FlexPro Pen',
#      'Nutropin AQ NuSpin 10',
#      'Omnitrope',
#      'Saizen',
#      'Serostim',
#      'Zomacton',
#      'Zorbtive'],
#     'C',
#     'N'],
#    ['Rx',
#     'Saizen',
#     ['somatropin'],
#     ['growth-hormones'],
#     ['Genotropin',
#      'Humatrope',
#      'Norditropin FlexPro Pen',
#      'Nutropin AQ NuSpin 10',
#      'Omnitrope',
#      'Saizen',
#      'Serostim',
#      'Zomacton',
#      'Zorbtive'],
#     'C',
#     'N'],
#    ['Rx',
#     'Humatrope',
#     ['somatropin'],
#     ['growth-hormones'],
#     ['Genotropin',
#      'Humatrope',
#      'Norditropin FlexPro Pen',
#      'Nutropin AQ NuSpin 10',
#      'Omnitrope',
#      'Saizen',
#      'Serostim',
#      'Zomacton',
#      'Zorbtive'],
#     'C',
#     'N'],
#    ['Rx',
#     'Norditropin FlexPro',
#     ['somatropin'],
#     ['growth-hormones'],
#     ['Genotropin',
#      'Humatrope',
#      'Norditropin FlexPro Pen',
#      'Nutropin AQ NuSpin 10',
#      'Omnitrope',
#      'Saizen',
#      'Serostim',
#      'Zomacton',
#      'Zorbtive'],
#     'C',
#     'N'],
#    ['Rx',
#     'Nutropin AQ',
#     ['somatropin'],
#     ['growth-hormones'],
#     ['Genotropin',
#      'Humatrope',
#      'Norditropin FlexPro Pen',
#      'Nutropin AQ NuSpin 10',
#      'Omnitrope',
#      'Saizen',
#      'Serostim',
#      'Zomacton',
#      'Zorbtive'],
#     'C',
#     'N'],
#    ['Rx', 'Omnitrope', ['somatropin'], ['growth-hormones'], [], 'C', 'N'],
#    ['Rx',
#     'Nutropin',
#     ['somatropin', 'mammalian derived'],
#     ['growth-hormones'],
#     [],
#     'C',
#     'N'],
#    ['Rx',
#     'Zomacton',
#     ['somatropin'],
#     ['growth-hormones'],
#     ['Genotropin',
#      'Humatrope',
#      'Norditropin FlexPro Pen',
#      'Nutropin AQ NuSpin 10',
#      'Omnitrope',
#      'Saizen',
#      'Serostim',
#      'Zomacton',
#      'Zorbtive'],
#     'C',
#     'N']]],
#  [['diabetes'], [[]], []],
#  [['fibromyalgia'], [[]], []]]

# %%
for i in range(len(output_lst_copy)-1):
    if len(output_lst_copy[i][2])!= 0:
        print(len(output_lst_copy[i][2]))
        output_lst_copy[i][0] = output_lst_copy[i][0]*len(output_lst_copy[i][2])
        output_lst_copy[i][1] = output_lst_copy[i][1]*len(output_lst_copy[i][2])
    
output_lst_copy
# Out:
# 2
# 5
# 1
# 25
# 12
# 2
# 1
# 25
# 25
# 11
# 9
# 18
# 2
# 12
# 25
# 25
# 12
# 9
# 2
# 23
# 13
# 12
# 3
# 7
# 12
# 3
# 1
# 1
# 2
# 8
# 13
# 16
# 9
# [[['abdominal adhesions'], [['Adhesions, Gastrointestinal']], []],
#  [['abdominal distension prior to abdominal x ray',
#    'abdominal distension prior to abdominal x ray'],
#   [[], []],
#   [['Rx',
#     'vasopressin',
#     ['vasopressin'],
#     ['antidiuretic-hormones'],
#     ['Vasostrict', 'Pitressin'],
#     'C',
#     'N'],
#    ['Rx',
#     'Vasostrict',
#     ['vasopressin'],
#     ['antidiuretic-hormones'],
#     ['Vasostrict'],
#     'C',
#     'N']]],
#  [['abdominal distension',
#    'abdominal distension',
#    'abdominal distension',
#    'abdominal distension',
#    'abdominal distension'],
#   [['Abdominal bloating; Bloating; Meteorism'],
#    ['Abdominal bloating; Bloating; Meteorism'],
#    ['Abdominal bloating; Bloating; Meteorism'],
#    ['Abdominal bloating; Bloating; Meteorism'],
#    ['Abdominal bloating; Bloating; Meteorism']],
#   [['Rx',
#     'bethanechol',
#     ['bethanechol'],
#     ['miscellaneous-genitourinary-tract-agents'],
#     ['Duvoid', 'Urecholine'],
#     'C',
#     'N'],
#    ['Rx',
#     'Urecholine',
#     ['bethanechol'],
#     ['miscellaneous-genitourinary-tract-agents'],
#     ['Duvoid', 'Urecholine'],
#     'C',
#     'N'],
#    ['Rx',
#     'Duvoid',
#     ['bethanechol'],
#     ['miscellaneous-genitourinary-tract-agents'],
#     ['Duvoid', 'Urecholine'],
#     'C',
#     'N'],
#    ['OTC',
#     'pamabrom',
#     ['pamabrom'],
#     ['miscellaneous-diuretics'],
#     ['Aqua-Ban',
#      'Diurex Aquagels',
#      'Diurex Water Capsules',
#      'Aqua-Ban with Pamabrom'],
#     'N',
#     'N'],
#    ['OTC',
#     'Aqua-Ban',
#     ['pamabrom'],
#     ['miscellaneous-diuretics'],
#     ['Aqua-Ban', 'Diurex Aquagels', 'Diurex Water Capsules'],
#     'N',
#     'N']]],
#  [['abdominal radiological procedure'],
#   [['Abdominal Radiological Procedures']],
#   [['Rx',
#     'vasopressin',
#     ['vasopressin'],
#     ['antidiuretic-hormones'],
#     ['Vasostrict', 'Pitressin'],
#     'C',
#     'N']]],
#  [['abdominopelvic fistulas'], [[]], []],
#  [['abnormal electrocardiogram'], [[]], []],
#  [['abnormal glucose tolerance'], [[]], []],
#  [['abnormal uterine bleeding',
#    'abnormal uterine bleeding',
#    'abnormal uterine bleeding',
#    'abnormal uterine bleeding',
#    'abnormal uterine bleeding',
#    'abnormal uterine bleeding',
#    'abnormal uterine bleeding',
#    'abnormal uterine bleeding',
#    'abnormal uterine bleeding',
#    'abnormal uterine bleeding',
#    'abnormal uterine bleeding',
#    'abnormal uterine bleeding',
#    'abnormal uterine bleeding',
#    'abnormal uterine bleeding',
#    'abnormal uterine bleeding',
#    'abnormal uterine bleeding',
#    'abnormal uterine bleeding',
#    'abnormal uterine bleeding',
#    'abnormal uterine bleeding',
#    'abnormal uterine bleeding',
#    'abnormal uterine bleeding',
#    'abnormal uterine bleeding',
#    'abnormal uterine bleeding',
#    'abnormal uterine bleeding',
#    'abnormal uterine bleeding'],
#   [['Bleeding, dysfunctional uterine; DUB; Dysfunctional uterine bleeding'],
#    ['Bleeding, dysfunctional uterine; DUB; Dysfunctional uterine bleeding'],
#    ['Bleeding, dysfunctional uterine; DUB; Dysfunctional uterine bleeding'],
#    ['Bleeding, dysfunctional uterine; DUB; Dysfunctional uterine bleeding'],
#    ['Bleeding, dysfunctional uterine; DUB; Dysfunctional uterine bleeding'],
#    ['Bleeding, dysfunctional uterine; DUB; Dysfunctional uterine bleeding'],
#    ['Bleeding, dysfunctional uterine; DUB; Dysfunctional uterine bleeding'],
#    ['Bleeding, dysfunctional uterine; DUB; Dysfunctional uterine bleeding'],
#    ['Bleeding, dysfunctional uterine; DUB; Dysfunctional uterine bleeding'],
#    ['Bleeding, dysfunctional uterine; DUB; Dysfunctional uterine bleeding'],
#    ['Bleeding, dysfunctional uterine; DUB; Dysfunctional uterine bleeding'],
#    ['Bleeding, dysfunctional uterine; DUB; Dysfunctional uterine bleeding'],
#    ['Bleeding, dysfunctional uterine; DUB; Dysfunctional uterine bleeding'],
#    ['Bleeding, dysfunctional uterine; DUB; Dysfunctional uterine bleeding'],
#    ['Bleeding, dysfunctional uterine; DUB; Dysfunctional uterine bleeding'],
#    ['Bleeding, dysfunctional uterine; DUB; Dysfunctional uterine bleeding'],
#    ['Bleeding, dysfunctional uterine; DUB; Dysfunctional uterine bleeding'],
#    ['Bleeding, dysfunctional uterine; DUB; Dysfunctional uterine bleeding'],
#    ['Bleeding, dysfunctional uterine; DUB; Dysfunctional uterine bleeding'],
#    ['Bleeding, dysfunctional uterine; DUB; Dysfunctional uterine bleeding'],
#    ['Bleeding, dysfunctional uterine; DUB; Dysfunctional uterine bleeding'],
#    ['Bleeding, dysfunctional uterine; DUB; Dysfunctional uterine bleeding'],
#    ['Bleeding, dysfunctional uterine; DUB; Dysfunctional uterine bleeding'],
#    ['Bleeding, dysfunctional uterine; DUB; Dysfunctional uterine bleeding'],
#    ['Bleeding, dysfunctional uterine; DUB; Dysfunctional uterine bleeding']],
#   [['Rx',
#     'medroxyprogesterone',
#     ['medroxyprogesterone'],
#     ['contraceptives'],
#     [],
#     'X',
#     'N'],
#    ['Rx', 'Mirena', [], ['contraceptives'], [], 'X', 'N'],
#    ['Rx',
#     'Provera',
#     ['medroxyprogesterone'],
#     ['contraceptives'],
#     ['Provera'],
#     'X',
#     'N'],
#    ['Rx',
#     'norethindrone',
#     ['norethindrone'],
#     ['contraceptives'],
#     ['Aygestin',
#      'Camila',
#      'Errin',
#      'Jolivette',
#      'Nora-Be',
#      'Ortho Micronor',
#      'Heather',
#      'Jencycla',
#      'Norlyroc',
#      'Deblitane',
#      'Sharobel',
#      'Lyza',
#      'Norlyda',
#      'Tulana',
#      'Incassia',
#      'Nor-QD',
#      'Heather',
#      'Jencycla',
#      'Norlyroc',
#      'Deblitane',
#      'Sharobel',
#      'Lyza',
#      'Norlyda',
#      'Tulana',
#      'Incassia'],
#     'X',
#     'N'],
#    ['Rx',
#     'Depo-Provera',
#     ['medroxyprogesterone'],
#     ['contraceptives'],
#     [],
#     'X',
#     'N'],
#    ['Rx',
#     'megestrol',
#     ['megestrol'],
#     ['hormones-antineoplastics'],
#     ['Megace ES', 'Megace'],
#     'X',
#     'N'],
#    ['Rx',
#     'Sprintec',
#     ['ethinyl estradiol and norgestimate'],
#     ['contraceptives'],
#     ['Estarylla',
#      'Femynor',
#      'Mono-Linyah',
#      'Mononessa',
#      'Ortho Tri-Cyclen',
#      'Previfem',
#      'Sprintec',
#      'Tri-Lo-Marzia',
#      'TriNessa'],
#     'X',
#     'N'],
#    ['Rx/OTC',
#     'levonorgestrel',
#     ['levonorgestrel emergency contraceptive'],
#     ['contraceptives'],
#     [],
#     'X',
#     'N'],
#    ['Rx',
#     'Aviane',
#     ['ethinyl estradiol and levonorgestrel'],
#     ['contraceptives'],
#     [],
#     'X',
#     'N'],
#    ['Rx',
#     'Aygestin',
#     ['norethindrone'],
#     ['contraceptives'],
#     ['Aygestin', 'Camila', 'Errin', 'Jolivette', 'Nora-Be', 'Ortho Micronor'],
#     'X',
#     'N'],
#    ['Rx',
#     'ethinyl estradiol / levonorgestrel',
#     ['ethinyl estradiol and levonorgestrel'],
#     ['contraceptives'],
#     ['Amethyst',
#      'Aviane',
#      'Balcoltra',
#      'Falmina',
#      'Levlen',
#      'Lillow',
#      'Orsythia',
#      'Vienva'],
#     'X',
#     'N'],
#    ['Rx', 'Premarin', ['conjugated estrogens'], ['estrogens'], [], 'X', 'N'],
#    ['Rx',
#     'Seasonique',
#     ['ethinyl estradiol and levonorgestrel'],
#     ['contraceptives'],
#     [],
#     'X',
#     'N'],
#    ['Rx',
#     'Jolivette',
#     ['norethindrone'],
#     ['contraceptives'],
#     ['Aygestin', 'Camila', 'Errin', 'Jolivette', 'Nora-Be', 'Ortho Micronor'],
#     'X',
#     'N'],
#    ['Rx',
#     'Camila',
#     ['norethindrone'],
#     ['contraceptives'],
#     ['Aygestin', 'Camila', 'Errin', 'Jolivette', 'Nora-Be', 'Ortho Micronor'],
#     'X',
#     'N'],
#    ['Rx',
#     'ethinyl estradiol / norgestimate',
#     ['ethinyl estradiol and norgestimate'],
#     ['contraceptives'],
#     ['Estarylla',
#      'Femynor',
#      'Mono-Linyah',
#      'Mononessa',
#      'Ortho Tri-Cyclen',
#      'Previfem',
#      'Sprintec',
#      'Tri-Lo-Marzia',
#      'TriNessa',
#      'Ortho Tri-Cyclen Lo',
#      'Tri-Sprintec',
#      'Tri-Previfem',
#      'Mili',
#      'Tri-Lo-Sprintec',
#      'Tri-Linyah',
#      'Tri-Estarylla',
#      'TriNessa Lo',
#      'Tri-Lo-Estarylla',
#      'Tri Femynor',
#      'VyLibra',
#      'Tri-VyLibra',
#      'Tri-Mili',
#      'Tri-VyLibra Lo',
#      'Tri-Lo-Mili',
#      'Ortho-Cyclen',
#      'Ortho Tri-Cyclen Lo',
#      'Tri-Sprintec',
#      'Tri-Previfem',
#      'Mili',
#      'Tri-Lo-Sprintec',
#      'Tri-Linyah',
#      'Tri-Estarylla',
#      'TriNessa Lo',
#      'Tri-Lo-Estarylla',
#      'Tri Femynor',
#      'VyLibra',
#      'Tri-VyLibra',
#      'Tri-Mili',
#      'Tri-VyLibra Lo',
#      'Tri-Lo-Mili'],
#     'X',
#     'N'],
#    ['Rx',
#     'Heather',
#     ['Norethindrone'],
#     ['contraceptives'],
#     ['Camila',
#      'Deblitane',
#      'Errin',
#      'Heather',
#      'Jencycla',
#      'Lyza',
#      'Nor-QD',
#      'Nora-BE',
#      'Norlyroc',
#      'Ortho Micronor',
#      'Sharobel',
#      'Jolivette',
#      'Lyza',
#      'Nor-QD',
#      'Nora-BE',
#      'Norlyroc',
#      'Ortho Micronor',
#      'Sharobel'],
#     'X',
#     'N'],
#    ['Rx',
#     'Nora-Be',
#     ['norethindrone'],
#     ['contraceptives'],
#     ['Aygestin', 'Camila', 'Errin', 'Jolivette', 'Nora-Be', 'Ortho Micronor'],
#     'X',
#     'N'],
#    ['Rx',
#     'Ortho Micronor',
#     ['norethindrone'],
#     ['contraceptives'],
#     ['Aygestin', 'Camila', 'Errin', 'Jolivette', 'Nora-Be', 'Ortho Micronor'],
#     'X',
#     'N'],
#    ['Rx',
#     'Cryselle',
#     ['ethinyl estradiol and norgestrel'],
#     ['contraceptives'],
#     ['Cryselle 28', 'Low-Ogestrel', 'Ogestrel-28'],
#     'X',
#     'N'],
#    ['Rx',
#     'Depo-Provera Contraceptive',
#     ['medroxyprogesterone'],
#     ['contraceptives'],
#     ['Depo-Provera', 'Depo-Provera Contraceptive', 'depo-subQ provera 104'],
#     'X',
#     'N'],
#    ['Rx',
#     'Errin',
#     ['norethindrone'],
#     ['contraceptives'],
#     ['Aygestin', 'Camila', 'Errin', 'Jolivette', 'Nora-Be', 'Ortho Micronor'],
#     'X',
#     'N'],
#    ['Rx',
#     'ethinyl estradiol / norethindrone',
#     ['ethinyl estradiol and norethindrone'],
#     ['contraceptives'],
#     ['femhrt 0.5 mg/2.5 mcg', 'Fyavolv', 'Jevantique Lo', 'Jinteli'],
#     'X',
#     'N'],
#    ['Rx', 'Lutera', [], ['contraceptives'], [], 'X', 'N'],
#    ['Rx',
#     'Deblitane',
#     ['Norethindrone'],
#     ['contraceptives'],
#     ['Camila',
#      'Deblitane',
#      'Errin',
#      'Heather',
#      'Jencycla',
#      'Lyza',
#      'Nor-QD',
#      'Nora-BE',
#      'Norlyroc',
#      'Ortho Micronor',
#      'Sharobel',
#      'Jolivette',
#      'Lyza',
#      'Nor-QD',
#      'Nora-BE',
#      'Norlyroc',
#      'Ortho Micronor',
#      'Sharobel'],
#     'X',
#     'N']]],
#  [['abortion',
#    'abortion',
#    'abortion',
#    'abortion',
#    'abortion',
#    'abortion',
#    'abortion',
#    'abortion',
#    'abortion',
#    'abortion',
#    'abortion',
#    'abortion'],
#   [['Complete Abortion'],
#    ['Complete Abortion'],
#    ['Complete Abortion'],
#    ['Complete Abortion'],
#    ['Complete Abortion'],
#    ['Complete Abortion'],
#    ['Complete Abortion'],
#    ['Complete Abortion'],
#    ['Complete Abortion'],
#    ['Complete Abortion'],
#    ['Complete Abortion'],
#    ['Complete Abortion']],
#   [['Rx',
#     'misoprostol',
#     ['misoprostol'],
#     ['miscellaneous-gi-agents'],
#     ['Cytotec'],
#     'X',
#     'N'],
#    ['Rx',
#     'Cytotec',
#     ['misoprostol'],
#     ['miscellaneous-gi-agents'],
#     ['Cytotec'],
#     'X',
#     'N'],
#    ['Rx',
#     'mifepristone',
#     ['mifepristone'],
#     ['progesterone-receptor-modulators'],
#     ['Korlym'],
#     'X',
#     'N'],
#    ['Rx',
#     'oxytocin',
#     ['oxytocin'],
#     ['uterotonic-agents'],
#     ['Pitocin', 'Syntocinon'],
#     'X',
#     'N'],
#    ['Rx',
#     'Pitocin',
#     ['oxytocin'],
#     ['uterotonic-agents'],
#     ['Pitocin'],
#     'X',
#     'N'],
#    ['Rx',
#     'Mifeprex',
#     ['mifepristone'],
#     ['progesterone-receptor-modulators'],
#     ['Mifeprex'],
#     'X',
#     'N'],
#    ['Rx',
#     'Hemabate',
#     ['carboprost'],
#     ['uterotonic-agents'],
#     ['Hemabate'],
#     'C',
#     'N'],
#    ['Rx',
#     'carboprost',
#     ['carboprost'],
#     ['uterotonic-agents'],
#     ['Hemabate'],
#     'C',
#     'N'],
#    ['Rx',
#     'Cervidil',
#     ['dinoprostone topical'],
#     ['uterotonic-agents'],
#     ['Cervidil', 'Prepidil', 'Prostin E2'],
#     'C',
#     'N'],
#    ['Rx',
#     'Prostin E2',
#     ['dinoprostone topical'],
#     ['uterotonic-agents'],
#     ['Cervidil', 'Prepidil', 'Prostin E2'],
#     'C',
#     'N'],
#    ['Rx',
#     'dinoprostone',
#     ['dinoprostone topical'],
#     ['uterotonic-agents'],
#     ['Cervidil', 'Prepidil', 'Prostin E2'],
#     'C',
#     'N'],
#    ['Rx',
#     'Prepidil',
#     ['dinoprostone topical'],
#     ['uterotonic-agents'],
#     ['Cervidil', 'Prepidil', 'Prostin E2'],
#     'C',
#     'N']]],
#  [['acanthosis nigricans'], [[]], []],
#  [['acetaminophen overdose', 'acetaminophen overdose'],
#   [['Acetaminophen Toxicity'], ['Acetaminophen Toxicity']],
#   [['Rx/OTC',
#     'acetylcysteine',
#     ['acetylcysteine'],
#     ['antidotes'],
#     ['NAC', 'N-A-C Sustain'],
#     'B',
#     'N'],
#    ['Rx', 'Acetadote', [], ['antidotes'], [], 'B', 'N']]],
#  [['achlorhydria'], [[]], []],
#  [['acidosis'],
#   [['Acidosis, lactic; Acidosis, respiratory']],
#   [['Rx/OTC',
#     'sodium bicarbonate',
#     ['sodium bicarbonate'],
#     ['antacids'],
#     ['Neut'],
#     'C',
#     'N']]],
#  [['acne rosacea',
#    'acne rosacea',
#    'acne rosacea',
#    'acne rosacea',
#    'acne rosacea',
#    'acne rosacea',
#    'acne rosacea',
#    'acne rosacea',
#    'acne rosacea',
#    'acne rosacea',
#    'acne rosacea',
#    'acne rosacea',
#    'acne rosacea',
#    'acne rosacea',
#    'acne rosacea',
#    'acne rosacea',
#    'acne rosacea',
#    'acne rosacea',
#    'acne rosacea',
#    'acne rosacea',
#    'acne rosacea',
#    'acne rosacea',
#    'acne rosacea',
#    'acne rosacea',
#    'acne rosacea'],
#   [['Acne rosacea'],
#    ['Acne rosacea'],
#    ['Acne rosacea'],
#    ['Acne rosacea'],
#    ['Acne rosacea'],
#    ['Acne rosacea'],
#    ['Acne rosacea'],
#    ['Acne rosacea'],
#    ['Acne rosacea'],
#    ['Acne rosacea'],
#    ['Acne rosacea'],
#    ['Acne rosacea'],
#    ['Acne rosacea'],
#    ['Acne rosacea'],
#    ['Acne rosacea'],
#    ['Acne rosacea'],
#    ['Acne rosacea'],
#    ['Acne rosacea'],
#    ['Acne rosacea'],
#    ['Acne rosacea'],
#    ['Acne rosacea'],
#    ['Acne rosacea'],
#    ['Acne rosacea'],
#    ['Acne rosacea'],
#    ['Acne rosacea']],
#   [['Rx',
#     'doxycycline',
#     ['doxycycline'],
#     ['miscellaneous-antimalarials'],
#     [],
#     'D',
#     'N'],
#    ['Rx',
#     'metronidazole',
#     ['metronidazole topical'],
#     ['topical-anti-rosacea-agents'],
#     ['MetroCream',
#      'MetroGel',
#      'MetroGel Pump',
#      'MetroLotion',
#      'Noritate',
#      'Rosadan'],
#     'B',
#     'N'],
#    ['Rx',
#     'MetroGel',
#     ['metronidazole topical'],
#     ['topical-anti-rosacea-agents'],
#     ['MetroCream',
#      'MetroGel',
#      'MetroGel Pump',
#      'MetroLotion',
#      'Noritate',
#      'Rosadan'],
#     'B',
#     'N'],
#    ['Rx',
#     'Finacea',
#     ['azelaic acid topical'],
#     ['topical-acne-agents'],
#     [],
#     'B',
#     'N'],
#    ['Rx',
#     'Oracea',
#     ['doxycycline'],
#     ['miscellaneous-antimalarials'],
#     [],
#     'D',
#     'N'],
#    ['Rx', 'minocycline', ['minocycline'], ['tetracyclines'], [], 'D', 'N'],
#    ['Rx', 'Soolantra', [], ['topical-anti-infectives'], [], 'C', 'N'],
#    ['Rx',
#     'Doryx',
#     ['Doxycycline Delayed-Release Tablets'],
#     ['miscellaneous-antimalarials'],
#     ['Doryx'],
#     'D',
#     'N'],
#    ['Rx',
#     'MetroCream',
#     ['metronidazole topical'],
#     ['topical-anti-rosacea-agents'],
#     ['MetroCream',
#      'MetroGel',
#      'MetroGel Pump',
#      'MetroLotion',
#      'Noritate',
#      'Rosadan'],
#     'B',
#     'N'],
#    ['Rx',
#     'Mirvaso',
#     ['brimonidine topical'],
#     ['topical-anti-rosacea-agents'],
#     [],
#     'B',
#     'N'],
#    ['Rx',
#     'Azelex',
#     ['azelaic acid topical'],
#     ['topical-acne-agents'],
#     ['Azelex', 'Finacea', 'Finacea Plus'],
#     'B',
#     'N'],
#    ['Rx',
#     'azelaic acid',
#     ['azelaic acid topical'],
#     ['topical-acne-agents'],
#     ['Azelex', 'Finacea', 'Finacea Plus', 'Finevin'],
#     'B',
#     'N'],
#    ['Rx',
#     'Doxy 100',
#     ['Doxycycline Injection'],
#     ['miscellaneous-antimalarials'],
#     ['Doxy 100'],
#     'D',
#     'N'],
#    ['Rx', 'Solodyn', ['minocycline'], ['tetracyclines'], [], 'D', 'N'],
#    ['Rx',
#     'Monodox',
#     ['Doxycycline Tablets and Capsules'],
#     ['miscellaneous-antimalarials'],
#     ['Acticlate',
#      'Adox Pak 2/100',
#      'Adoxa',
#      'Adoxa Pak 1/100',
#      'Adoxa Pak 1/150',
#      'Monodox',
#      'Morgidox',
#      'Oraxyl',
#      'TargaDOX',
#      'Vibramycin',
#      'Avidoxy',
#      'Monodox',
#      'Morgidox',
#      'Oraxyl',
#      'TargaDOX',
#      'Vibramycin'],
#     'D',
#     'N'],
#    ['Rx',
#     'Noritate',
#     ['metronidazole topical'],
#     ['topical-anti-rosacea-agents'],
#     ['MetroCream',
#      'MetroGel',
#      'MetroGel Pump',
#      'MetroLotion',
#      'Noritate',
#      'Rosadan'],
#     'B',
#     'N'],
#    ['Rx',
#     'sulfacetamide sodium / sulfur',
#     ['sulfacetamide sodium and sulfur topical'],
#     ['topical-antibiotics'],
#     ['Avar',
#      'BP 10-Wash',
#      'Clarifoam EF',
#      'Garimide',
#      'Plexion',
#      'Prascion Cleanser',
#      'Rosanil Cleanser',
#      'Rosula',
#      'Sulfacleans 8/4',
#      'Sumadan',
#      'Sumaxin',
#      'Suphera',
#      'Virti-Sulf',
#      'Zencia Wash',
#      'Sulfacet-R',
#      'Zetacet',
#      'Plexion Cleanser',
#      'Plexion TS',
#      'Rosula Cleanser',
#      'Nicosyn',
#      'Avar Cleanser',
#      'Clenia Foaming Wash',
#      'Clenia Emollient Cream',
#      'Avar Gel',
#      'Avar Green',
#      'Rosac',
#      'Avar-E Emollient',
#      'Avar-E Green',
#      'Rosaderm Cleanser',
#      'Zetacet Wash',
#      'Plexion SCT',
#      'Plexion Cleansing Cloths',
#      'Sulfatol',
#      'Sulfatol Cleanser',
#      'Prascion FC Cloths',
#      'Prascion RA',
#      'Rosula Clarifying Wash',
#      'Prascion',
#      'Rosac Wash',
#      'Topisulf',
#      'Sulfatol C',
#      'SulZee Wash',
#      'Sulfatol SS',
#      'Sumaxin Wash',
#      'Avar LS Cleanser',
#      'Avar-e LS',
#      'SE 10-5 SS',
#      'Avar-E',
#      'Sumaxin TS',
#      'Sumadan Wash',
#      'Sumaxin CP',
#      'Avar LS',
#      'Sumadan XLT',
#      'Rosula Wash',
#      'Novacet',
#      'Sulfacet-R',
#      'Zetacet',
#      'Plexion Cleanser',
#      'Plexion TS',
#      'Rosula Cleanser',
#      'Nicosyn',
#      'Avar Cleanser',
#      'Clenia Foaming Wash',
#      'Clenia Emollient Cream',
#      'Avar Gel',
#      'Avar Green',
#      'Rosac',
#      'Avar-E Emollient',
#      'Avar-E Green',
#      'Rosaderm Cleanser',
#      'Zetacet Wash',
#      'Plexion SCT',
#      'Plexion Cleansing Cloths',
#      'Sulfatol (obsolete)',
#      'Sulfatol Cleanser (obsolete)',
#      'Prascion FC Cloths',
#      'Prascion RA',
#      'Rosula Clarifying Wash (obsolete)',
#      'Prascion',
#      'Rosac Wash',
#      'Topisulf',
#      'Sulfatol C',
#      'SulZee Wash',
#      'Sulfatol SS',
#      'Sumaxin Wash',
#      'Avar LS Cleanser',
#      'Avar-e LS',
#      'SE 10-5 SS',
#      'Avar-E',
#      'Sumaxin TS',
#      'Sumadan Wash',
#      'Sumaxin CP',
#      'Avar LS',
#      'Sumadan XLT',
#      'Rosula Wash'],
#     'C',
#     'N'],
#    ['Rx',
#     'Minocin',
#     ['minocycline'],
#     ['tetracyclines'],
#     ['Dynacin', 'Minocin', 'Minocin PAC', 'Solodyn', 'Ximino'],
#     'D',
#     'N'],
#    ['Rx',
#     'isotretinoin',
#     ['isotretinoin'],
#     ['miscellaneous-antineoplastics'],
#     ['Absorica',
#      'Amnesteem',
#      'Claravis',
#      'Myorisan',
#      'Sotret',
#      'Zenatane',
#      'Accutane',
#      'Absorica LD'],
#     'X',
#     'N'],
#    ['Rx',
#     'ivermectin',
#     ['Ivermectin Cream'],
#     ['topical-anti-infectives'],
#     ['Soolantra'],
#     'C',
#     'N'],
#    ['Rx',
#     'MetroLotion',
#     ['metronidazole topical'],
#     ['topical-anti-rosacea-agents'],
#     ['MetroCream',
#      'MetroGel',
#      'MetroGel Pump',
#      'MetroLotion',
#      'Noritate',
#      'Rosadan'],
#     'B',
#     'N'],
#    ['Rx',
#     'Vibramycin',
#     ['Doxycycline Suspension'],
#     ['miscellaneous-antimalarials'],
#     ['Vibramycin'],
#     'D',
#     'N'],
#    ['Rx',
#     'brimonidine',
#     ['brimonidine topical'],
#     ['topical-anti-rosacea-agents'],
#     ['Mirvaso', 'Mirvaso Pump'],
#     'B',
#     'N'],
#    ['Rx', 'Doryx MPC', ['doxycycline'], [], [], 'D', 'N'],
#    ['Rx',
#     'Morgidox',
#     ['Doxycycline Tablets and Capsules'],
#     ['miscellaneous-antimalarials'],
#     ['Acticlate',
#      'Adox Pak 2/100',
#      'Adoxa',
#      'Adoxa Pak 1/100',
#      'Adoxa Pak 1/150',
#      'Monodox',
#      'Morgidox',
#      'Oraxyl',
#      'TargaDOX',
#      'Vibramycin',
#      'Avidoxy',
#      'Monodox',
#      'Morgidox',
#      'Oraxyl',
#      'TargaDOX',
#      'Vibramycin'],
#     'D',
#     'N']]],
#  [['acne',
#    'acne',
#    'acne',
#    'acne',
#    'acne',
#    'acne',
#    'acne',
#    'acne',
#    'acne',
#    'acne',
#    'acne',
#    'acne',
#    'acne',
#    'acne',
#    'acne',
#    'acne',
#    'acne',
#    'acne',
#    'acne',
#    'acne',
#    'acne',
#    'acne',
#    'acne',
#    'acne',
#    'acne'],
#   [['Acne Vulgaris; Blackheads; Breakouts; Cystic acne; Pimples; Whiteheads; Zits'],
#    ['Acne Vulgaris; Blackheads; Breakouts; Cystic acne; Pimples; Whiteheads; Zits'],
#    ['Acne Vulgaris; Blackheads; Breakouts; Cystic acne; Pimples; Whiteheads; Zits'],
#    ['Acne Vulgaris; Blackheads; Breakouts; Cystic acne; Pimples; Whiteheads; Zits'],
#    ['Acne Vulgaris; Blackheads; Breakouts; Cystic acne; Pimples; Whiteheads; Zits'],
#    ['Acne Vulgaris; Blackheads; Breakouts; Cystic acne; Pimples; Whiteheads; Zits'],
#    ['Acne Vulgaris; Blackheads; Breakouts; Cystic acne; Pimples; Whiteheads; Zits'],
#    ['Acne Vulgaris; Blackheads; Breakouts; Cystic acne; Pimples; Whiteheads; Zits'],
#    ['Acne Vulgaris; Blackheads; Breakouts; Cystic acne; Pimples; Whiteheads; Zits'],
#    ['Acne Vulgaris; Blackheads; Breakouts; Cystic acne; Pimples; Whiteheads; Zits'],
#    ['Acne Vulgaris; Blackheads; Breakouts; Cystic acne; Pimples; Whiteheads; Zits'],
#    ['Acne Vulgaris; Blackheads; Breakouts; Cystic acne; Pimples; Whiteheads; Zits'],
#    ['Acne Vulgaris; Blackheads; Breakouts; Cystic acne; Pimples; Whiteheads; Zits'],
#    ['Acne Vulgaris; Blackheads; Breakouts; Cystic acne; Pimples; Whiteheads; Zits'],
#    ['Acne Vulgaris; Blackheads; Breakouts; Cystic acne; Pimples; Whiteheads; Zits'],
#    ['Acne Vulgaris; Blackheads; Breakouts; Cystic acne; Pimples; Whiteheads; Zits'],
#    ['Acne Vulgaris; Blackheads; Breakouts; Cystic acne; Pimples; Whiteheads; Zits'],
#    ['Acne Vulgaris; Blackheads; Breakouts; Cystic acne; Pimples; Whiteheads; Zits'],
#    ['Acne Vulgaris; Blackheads; Breakouts; Cystic acne; Pimples; Whiteheads; Zits'],
#    ['Acne Vulgaris; Blackheads; Breakouts; Cystic acne; Pimples; Whiteheads; Zits'],
#    ['Acne Vulgaris; Blackheads; Breakouts; Cystic acne; Pimples; Whiteheads; Zits'],
#    ['Acne Vulgaris; Blackheads; Breakouts; Cystic acne; Pimples; Whiteheads; Zits'],
#    ['Acne Vulgaris; Blackheads; Breakouts; Cystic acne; Pimples; Whiteheads; Zits'],
#    ['Acne Vulgaris; Blackheads; Breakouts; Cystic acne; Pimples; Whiteheads; Zits'],
#    ['Acne Vulgaris; Blackheads; Breakouts; Cystic acne; Pimples; Whiteheads; Zits']],
#   [['Rx',
#     'doxycycline',
#     ['doxycycline'],
#     ['miscellaneous-antimalarials'],
#     [],
#     'D',
#     'N'],
#    ['Rx',
#     'spironolactone',
#     ['spironolactone'],
#     ['aldosterone-receptor-antagonists'],
#     [],
#     'C',
#     'N'],
#    ['Rx', 'minocycline', ['minocycline'], ['tetracyclines'], [], 'D', 'N'],
#    ['Rx',
#     'Aldactone',
#     ['spironolactone'],
#     ['aldosterone-receptor-antagonists'],
#     [],
#     'C',
#     'N'],
#    ['Rx',
#     'clindamycin',
#     ['clindamycin topical'],
#     ['topical-acne-agents'],
#     ['Cleocin T', 'Clindacin ETZ', 'Clindacin P', 'Clindagel', 'Evoclin'],
#     'B',
#     'N'],
#    ['Rx',
#     'tretinoin',
#     ['tretinoin topical'],
#     ['topical-acne-agents'],
#     ['Altreno',
#      'Atralin',
#      'Avita',
#      'Refissa',
#      'Renova',
#      'Retin-A',
#      'Tretinoin Emollient Topical'],
#     'C',
#     'N'],
#    ['Rx',
#     'Bactrim',
#     ['sulfamethoxazole and trimethoprim'],
#     ['sulfonamides'],
#     [],
#     'D',
#     'N'],
#    ['Rx',
#     'isotretinoin',
#     ['isotretinoin'],
#     ['miscellaneous-antineoplastics'],
#     ['Absorica',
#      'Amnesteem',
#      'Claravis',
#      'Myorisan',
#      'Sotret',
#      'Zenatane',
#      'Accutane',
#      'Absorica LD'],
#     'X',
#     'N'],
#    ['Rx', 'Retin-A', ['Retin-A'], ['topical-acne-agents'], [], 'C', 'N'],
#    ['Rx',
#     'Epiduo',
#     ['adapalene and benzoyl peroxide'],
#     ['topical-acne-agents'],
#     [],
#     'C',
#     'N'],
#    ['Rx',
#     'Aczone',
#     ['dapsone topical'],
#     ['topical-acne-agents'],
#     [],
#     'C',
#     'N'],
#    ['Rx/OTC',
#     'Differin',
#     ['adapalene topical'],
#     ['topical-acne-agents'],
#     [],
#     'C',
#     'N'],
#    ['Rx/OTC',
#     'benzoyl peroxide',
#     ['benzoyl peroxide topical'],
#     ['topical-acne-agents'],
#     ['Acne-Clear',
#      'Benzac AC',
#      'BenzePrO',
#      'Benziq',
#      'Brevoxyl Acne Wash Kit',
#      'Clearskin',
#      'Fostex Wash 10%',
#      'NeoBenz Micro',
#      'Neutrogena Acne Mask',
#      'Oscion',
#      'Oxy Daily Wash',
#      'Oxy-10',
#      'Pacnex',
#      'PanOxyl',
#      'Persa-Gel',
#      'Riax',
#      'SoluCLENZ Rx',
#      'Triaz',
#      'Desquam-X 10',
#      'Benzashave 5',
#      'Benzashave 10',
#      'Panoxyl AQ 2.5',
#      'Desquam-E',
#      'Benzac W',
#      'Brevoxyl',
#      'Panoxyl AQ 5',
#      'Panoxyl 5',
#      'Desquam-X 5',
#      'Persa-Gel W',
#      'Benzagel-5',
#      'Clearplex',
#      'Panoxyl 10',
#      'Panoxyl AQ 10',
#      'Benzagel-10',
#      'Peroxin A 10',
#      'Desquam-X Wash',
#      'Triaz Cleanser',
#      'Benoxyl 5',
#      'Acne Treatment',
#      'Ben-Aqua',
#      'Del-Aqua',
#      'Peroxin A',
#      'Zeroxin',
#      'Acne-10',
#      'Benoxyl 10',
#      'Fostex Bar 10%',
#      'Fostex Gel 10%',
#      'Clear By Design',
#      'Loroxide',
#      'Vanoxide',
#      'Oxy Vanishing Gel',
#      'Neutrogena On Spot Acne Treatment',
#      'Seba-Gel',
#      'Brevoxyl Creamy Wash',
#      'Clinac BPO',
#      'Benzagel Wash',
#      'Ethexderm',
#      'Oxy 10 Balance',
#      'Zaclir',
#      'Oxy Balance',
#      'Benziq LS',
#      'Benziq Wash',
#      'ZoDerm Redi-Pads',
#      'Panoxyl Aqua Gel',
#      'Oscion Cleanser',
#      'Inova',
#      'NeoBenz Micro SD',
#      'Lavoclen-4 Creamy Wash',
#      'Lavoclen-8 Creamy Wash',
#      'Oxy Daily Wash Chill Factor',
#      'Oxy Spot Treatment',
#      'PanOxyl Maximum Strength Foaming Acne Wash',
#      'Lavoclen-4',
#      'Lavoclen-8',
#      'Breze',
#      'Brevoxyl-4 Creamy Wash Complete Pack',
#      'Brevoxyl-8 Creamy Wash Complete Pack',
#      'NeoBenz Micro Wash',
#      'NeoBenz Micro Wash Plus Pack',
#      'Triaz Foaming Cloths',
#      'Triaz Pads',
#      'BenzEFoam',
#      'Pacnex MX Wash',
#      'NeoBenz Micro Cream Plus Pack',
#      'Benzac AC Wash',
#      'BPO Foaming Cloths',
#      'Pacnex HP',
#      'Pacnex LP',
#      'BenzEFoam Ultra',
#      'BP Cleansing Lotion',
#      'BP Wash',
#      'OC8',
#      'Delos',
#      'BPO',
#      'PR Benzoyl Peroxide Wash',
#      'Differin Daily Deep Cleanser',
#      'Benzac',
#      'Desquam-X 10',
#      'Benzashave 5',
#      'Benzashave 10',
#      'Panoxyl AQ 2.5',
#      'Desquam-E',
#      'Benzac W',
#      'Brevoxyl',
#      'Panoxyl AQ 5',
#      'Panoxyl 5',
#      'Desquam-X 5',
#      'Persa-Gel W',
#      'Benzagel-5',
#      'Clearplex',
#      'Panoxyl 10',
#      'Panoxyl AQ 10',
#      'Benzagel-10',
#      'Peroxin A 10',
#      'Desquam-X Wash',
#      'Triaz Cleanser',
#      'Benoxyl 5',
#      'Acne Treatment',
#      'Ben-Aqua',
#      'Del-Aqua',
#      'Peroxin A',
#      'Zeroxin',
#      'Acne-10',
#      'Benoxyl 10',
#      'Fostex Bar 10%',
#      'Fostex Gel 10%',
#      'Clear By Design',
#      'Loroxide',
#      'Vanoxide',
#      'Oxy Vanishing Gel',
#      'Neutrogena On Spot Acne Treatment',
#      'Seba-Gel',
#      'Brevoxyl Creamy Wash',
#      'Clinac BPO',
#      'Benzagel Wash',
#      'Ethexderm',
#      'Oxy 10 Balance',
#      'Zaclir',
#      'Oxy Balance',
#      'Benziq LS',
#      'Benziq Wash',
#      'ZoDerm Redi-Pads (obsolete)',
#      'Panoxyl Aqua Gel',
#      'Oscion Cleanser',
#      'Inova',
#      'NeoBenz Micro SD',
#      'Lavoclen-4 Creamy Wash',
#      'Lavoclen-8 Creamy Wash',
#      'Oxy Daily Wash Chill Factor',
#      'Oxy Spot Treatment',
#      'PanOxyl Maximum Strength Foaming Acne Wash',
#      'Lavoclen-4',
#      'Lavoclen-8',
#      'Breze',
#      'Brevoxyl-4 Creamy Wash Complete Pack',
#      'Brevoxyl-8 Creamy Wash Complete Pack',
#      'NeoBenz Micro Wash',
#      'NeoBenz Micro Wash Plus Pack',
#      'Triaz Foaming Cloths',
#      'Triaz Pads',
#      'BenzEFoam',
#      'Pacnex MX Wash',
#      'NeoBenz Micro Cream Plus Pack',
#      'Benzac AC Wash',
#      'BPO Foaming Cloths',
#      'Pacnex HP',
#      'Pacnex LP',
#      'BenzEFoam Ultra',
#      'BP Cleansing Lotion',
#      'BP Wash',
#      'OC8',
#      'Delos',
#      'BPO',
#      'PR Benzoyl Peroxide Wash',
#      'Differin Daily Deep Cleanser'],
#     'C',
#     'N'],
#    ['Rx', 'Solodyn', ['minocycline'], ['tetracyclines'], [], 'D', 'N'],
#    ['Rx',
#     'Doryx',
#     ['Doxycycline Delayed-Release Tablets'],
#     ['miscellaneous-antimalarials'],
#     ['Doryx'],
#     'D',
#     'N'],
#    ['Rx/OTC',
#     'adapalene',
#     ['adapalene topical'],
#     ['topical-acne-agents'],
#     ['Differin', 'Plixda'],
#     'C',
#     'N'],
#    ['Rx',
#     'Septra',
#     ['sulfamethoxazole and trimethoprim'],
#     ['sulfonamides'],
#     [],
#     'D',
#     'N'],
#    ['Rx', 'tetracycline', ['tetracycline'], ['tetracyclines'], [], 'D', 'N'],
#    ['Rx',
#     'sulfamethoxazole / trimethoprim',
#     ['sulfamethoxazole and trimethoprim'],
#     ['sulfonamides'],
#     ['Bactrim',
#      'Bactrim DS',
#      'Bactrim I.V.',
#      'Septra I.V.',
#      'SMZ-TMP DS',
#      'Sulfatrim Pediatric',
#      'Sulfatrim',
#      'Bethaprim',
#      'Cotrim',
#      'Uroplus',
#      'Uroplus DS',
#      'Cotrim DS',
#      'Bactrim Pediatric',
#      'Bethaprim Pediatric',
#      'Sulfatrim Suspension',
#      'Cotrim Pediatric',
#      'Septra DS',
#      'Septra',
#      'Sulfatrim',
#      'Bethaprim',
#      'Cotrim',
#      'Uroplus',
#      'Uroplus DS',
#      'Cotrim DS',
#      'Bactrim Pediatric',
#      'Bethaprim Pediatric',
#      'Sulfatrim Suspension',
#      'Cotrim Pediatric',
#      'Septra DS'],
#     'D',
#     'N'],
#    ['Rx',
#     'Tazorac',
#     ['tazarotene topical'],
#     ['topical-acne-agents'],
#     ['Arazlo', 'Avage', 'Fabior', 'Tazorac'],
#     'X',
#     'N'],
#    ['Rx',
#     'cephalexin',
#     ['cephalexin'],
#     ['first-generation-cephalosporins'],
#     [],
#     'B',
#     'N'],
#    ['Rx',
#     'Vibramycin',
#     ['Doxycycline Suspension'],
#     ['miscellaneous-antimalarials'],
#     ['Vibramycin'],
#     'D',
#     'N'],
#    ['Rx',
#     'Acticlate',
#     ['Doxycycline Tablets and Capsules'],
#     ['tetracyclines'],
#     ['Acticlate',
#      'Adox Pak 2/100',
#      'Adoxa',
#      'Adoxa Pak 1/100',
#      'Adoxa Pak 1/150',
#      'Monodox',
#      'Morgidox',
#      'Oraxyl',
#      'TargaDOX',
#      'Vibramycin',
#      'Avidoxy',
#      'Monodox',
#      'Morgidox',
#      'Oraxyl',
#      'TargaDOX',
#      'Vibramycin'],
#     'D',
#     'N'],
#    ['Rx',
#     'Bactrim DS',
#     ['Sulfamethoxazole and Trimethoprim Tablets'],
#     ['sulfonamides'],
#     ['Bactrim', 'Bactrim DS'],
#     'D',
#     'N'],
#    ['Rx',
#     'Benzaclin',
#     ['benzoyl peroxide and clindamycin topical'],
#     ['topical-acne-agents'],
#     [],
#     'C',
#     'N']]],
#  [['acromegaly',
#    'acromegaly',
#    'acromegaly',
#    'acromegaly',
#    'acromegaly',
#    'acromegaly',
#    'acromegaly',
#    'acromegaly',
#    'acromegaly',
#    'acromegaly',
#    'acromegaly'],
#   [[], [], [], [], [], [], [], [], [], [], []],
#   [['Rx',
#     'Sandostatin LAR Depot',
#     ['octreotide'],
#     ['somatostatin-and-somatostatin-analogs'],
#     ['SandoSTATIN', 'SandoSTATIN LAR Depot'],
#     'B',
#     'N'],
#    ['Rx',
#     'Somavert',
#     ['pegvisomant'],
#     ['growth-hormone-receptor-blockers'],
#     [],
#     'B',
#     'N'],
#    ['Rx',
#     'bromocriptine',
#     ['bromocriptine'],
#     ['dopaminergic-antiparkinsonism-agents'],
#     ['Parlodel'],
#     'B',
#     'N'],
#    ['Rx',
#     'Somatuline Depot',
#     ['lanreotide'],
#     ['somatostatin-and-somatostatin-analogs'],
#     [],
#     'C',
#     'N'],
#    ['Rx',
#     'Parlodel',
#     ['bromocriptine'],
#     ['dopaminergic-antiparkinsonism-agents'],
#     ['Parlodel'],
#     'B',
#     'N'],
#    ['Rx',
#     'Sandostatin',
#     ['octreotide'],
#     ['somatostatin-and-somatostatin-analogs'],
#     [],
#     'B',
#     'N'],
#    ['Rx',
#     'octreotide',
#     ['octreotide'],
#     ['somatostatin-and-somatostatin-analogs'],
#     ['SandoSTATIN', 'SandoSTATIN LAR Depot', 'Benfyzia'],
#     'B',
#     'N'],
#    ['Rx',
#     'pegvisomant',
#     ['pegvisomant'],
#     ['growth-hormone-receptor-blockers'],
#     ['Somavert'],
#     'B',
#     'N'],
#    ['Rx',
#     'lanreotide',
#     ['lanreotide'],
#     ['somatostatin-and-somatostatin-analogs'],
#     ['Somatuline Depot'],
#     'C',
#     'N'],
#    ['Rx',
#     'pasireotide',
#     ['pasireotide'],
#     ['somatostatin-and-somatostatin-analogs'],
#     ['Signifor', 'Signifor LAR'],
#     'C',
#     'N'],
#    ['Rx',
#     'Signifor LAR',
#     ['pasireotide'],
#     ['somatostatin-and-somatostatin-analogs'],
#     ['Signifor', 'Signifor LAR'],
#     'C',
#     'N']]],
#  [['actinic keratosis',
#    'actinic keratosis',
#    'actinic keratosis',
#    'actinic keratosis',
#    'actinic keratosis',
#    'actinic keratosis',
#    'actinic keratosis',
#    'actinic keratosis',
#    'actinic keratosis'],
#   [[], [], [], [], [], [], [], [], []],
#   [['Rx',
#     'fluorouracil',
#     ['fluorouracil topical'],
#     ['topical-antineoplastics'],
#     ['Carac', 'Efudex', 'Fluoroplex', 'Tolak', 'Efudex Occlusion Pack'],
#     'X',
#     'N'],
#    ['Rx',
#     'Efudex',
#     ['fluorouracil topical'],
#     ['topical-antineoplastics'],
#     ['Carac', 'Efudex', 'Fluoroplex', 'Tolak'],
#     'X',
#     'N'],
#    ['Rx',
#     'Picato',
#     ['ingenol topical'],
#     ['topical-antineoplastics'],
#     [],
#     'C',
#     'N'],
#    ['Rx',
#     'Carac',
#     ['fluorouracil topical'],
#     ['topical-antineoplastics'],
#     ['Carac', 'Efudex', 'Fluoroplex', 'Tolak'],
#     'X',
#     'N'],
#    ['Rx',
#     'Tolak',
#     ['fluorouracil topical'],
#     ['topical-antineoplastics'],
#     ['Carac', 'Efudex', 'Fluoroplex', 'Tolak'],
#     'X',
#     'N'],
#    ['Rx',
#     'Fluoroplex',
#     ['fluorouracil topical'],
#     ['topical-antineoplastics'],
#     ['Carac', 'Efudex', 'Fluoroplex', 'Tolak'],
#     'X',
#     'N'],
#    ['Rx',
#     'aminolevulinic acid',
#     ['aminolevulinic acid'],
#     ['topical-photochemotherapeutics'],
#     ['Ameluz', 'Levulan Kerastick'],
#     'C',
#     'N'],
#    ['Rx',
#     'ingenol',
#     ['ingenol topical'],
#     ['topical-antineoplastics'],
#     ['Picato'],
#     'C',
#     'N'],
#    ['Rx',
#     'Ameluz',
#     ['aminolevulinic acid'],
#     ['topical-photochemotherapeutics'],
#     ['Ameluz', 'Levulan Kerastick'],
#     'C',
#     'N']]],
#  [['actinomycosis',
#    'actinomycosis',
#    'actinomycosis',
#    'actinomycosis',
#    'actinomycosis',
#    'actinomycosis',
#    'actinomycosis',
#    'actinomycosis',
#    'actinomycosis',
#    'actinomycosis',
#    'actinomycosis',
#    'actinomycosis',
#    'actinomycosis',
#    'actinomycosis',
#    'actinomycosis',
#    'actinomycosis',
#    'actinomycosis',
#    'actinomycosis'],
#   [['Lumpy Jaw'],
#    ['Lumpy Jaw'],
#    ['Lumpy Jaw'],
#    ['Lumpy Jaw'],
#    ['Lumpy Jaw'],
#    ['Lumpy Jaw'],
#    ['Lumpy Jaw'],
#    ['Lumpy Jaw'],
#    ['Lumpy Jaw'],
#    ['Lumpy Jaw'],
#    ['Lumpy Jaw'],
#    ['Lumpy Jaw'],
#    ['Lumpy Jaw'],
#    ['Lumpy Jaw'],
#    ['Lumpy Jaw'],
#    ['Lumpy Jaw'],
#    ['Lumpy Jaw'],
#    ['Lumpy Jaw']],
#   [['Rx', 'amoxicillin', ['amoxicillin'], ['aminopenicillins'], [], 'B', 'N'],
#    ['Rx',
#     'doxycycline',
#     ['doxycycline'],
#     ['miscellaneous-antimalarials'],
#     [],
#     'D',
#     'N'],
#    ['Rx', 'Amoxil', ['amoxicillin'], ['aminopenicillins'], [], 'B', 'N'],
#    ['Rx', 'minocycline', ['minocycline'], ['tetracyclines'], [], 'D', 'N'],
#    ['Rx',
#     'Doxy 100',
#     ['Doxycycline Injection'],
#     ['miscellaneous-antimalarials'],
#     ['Doxy 100'],
#     'D',
#     'N'],
#    ['Rx',
#     'Vibramycin',
#     ['Doxycycline Suspension'],
#     ['miscellaneous-antimalarials'],
#     ['Vibramycin'],
#     'D',
#     'N'],
#    ['Rx',
#     'Doryx',
#     ['Doxycycline Delayed-Release Tablets'],
#     ['miscellaneous-antimalarials'],
#     ['Doryx'],
#     'D',
#     'N'],
#    ['Rx',
#     'Monodox',
#     ['Doxycycline Tablets and Capsules'],
#     ['miscellaneous-antimalarials'],
#     ['Acticlate',
#      'Adox Pak 2/100',
#      'Adoxa',
#      'Adoxa Pak 1/100',
#      'Adoxa Pak 1/150',
#      'Monodox',
#      'Morgidox',
#      'Oraxyl',
#      'TargaDOX',
#      'Vibramycin',
#      'Avidoxy',
#      'Monodox',
#      'Morgidox',
#      'Oraxyl',
#      'TargaDOX',
#      'Vibramycin'],
#     'D',
#     'N'],
#    ['Rx', 'Apo-Amoxi', ['amoxicillin'], ['aminopenicillins'], [], 'B', 'N'],
#    ['Rx',
#     'Minocin',
#     ['minocycline'],
#     ['tetracyclines'],
#     ['Dynacin', 'Minocin', 'Minocin PAC', 'Solodyn', 'Ximino'],
#     'D',
#     'N'],
#    ['Rx', 'Doryx MPC', ['doxycycline'], [], [], 'D', 'N'],
#    ['Rx',
#     'Morgidox',
#     ['Doxycycline Tablets and Capsules'],
#     ['miscellaneous-antimalarials'],
#     ['Acticlate',
#      'Adox Pak 2/100',
#      'Adoxa',
#      'Adoxa Pak 1/100',
#      'Adoxa Pak 1/150',
#      'Monodox',
#      'Morgidox',
#      'Oraxyl',
#      'TargaDOX',
#      'Vibramycin',
#      'Avidoxy',
#      'Monodox',
#      'Morgidox',
#      'Oraxyl',
#      'TargaDOX',
#      'Vibramycin'],
#     'D',
#     'N'],
#    ['Rx',
#     'Oraxyl',
#     ['Doxycycline Tablets and Capsules'],
#     ['miscellaneous-antimalarials'],
#     ['Acticlate',
#      'Adox Pak 2/100',
#      'Adoxa',
#      'Adoxa Pak 1/100',
#      'Adoxa Pak 1/150',
#      'Monodox',
#      'Morgidox',
#      'Oraxyl',
#      'TargaDOX',
#      'Vibramycin',
#      'Avidoxy',
#      'Monodox',
#      'Morgidox',
#      'Oraxyl',
#      'TargaDOX',
#      'Vibramycin'],
#     'D',
#     'N'],
#    ['Rx',
#     'penicillin g sodium',
#     ['penicillin G sodium'],
#     ['natural-penicillins'],
#     [''],
#     'B',
#     'N'],
#    ['Rx',
#     'Ximino',
#     ['minocycline'],
#     ['tetracyclines'],
#     ['Dynacin', 'Minocin', 'Minocin PAC', 'Solodyn', 'Ximino'],
#     'D',
#     'N'],
#    ['Rx',
#     'Dynacin',
#     ['minocycline'],
#     ['tetracyclines'],
#     ['Dynacin', 'Minocin', 'Minocin PAC', 'Solodyn', 'Ximino'],
#     'D',
#     'N'],
#    ['Rx',
#     'penicillin g potassium',
#     ['penicillin G potassium'],
#     ['natural-penicillins'],
#     ['Pfizerpen'],
#     'B',
#     'N'],
#    ['Rx',
#     'Pfizerpen',
#     ['penicillin G potassium'],
#     ['natural-penicillins'],
#     ['Pfizerpen'],
#     'B',
#     'N']]],
#  [['acute alcohol intoxication'], [['Alcohol Poisoning']], []],
#  [['acute cholecystitis'], [[]], []],
#  [['acute coronary syndrome prophylaxis',
#    'acute coronary syndrome prophylaxis'],
#   [[], []],
#   [['Rx',
#     'clopidogrel',
#     ['clopidogrel'],
#     ['platelet-aggregation-inhibitors'],
#     ['Plavix'],
#     'B',
#     'N'],
#    ['Rx',
#     'Plavix',
#     ['clopidogrel'],
#     ['platelet-aggregation-inhibitors'],
#     [],
#     'B',
#     'N']]],
#  [['acute coronary syndrome',
#    'acute coronary syndrome',
#    'acute coronary syndrome',
#    'acute coronary syndrome',
#    'acute coronary syndrome',
#    'acute coronary syndrome',
#    'acute coronary syndrome',
#    'acute coronary syndrome',
#    'acute coronary syndrome',
#    'acute coronary syndrome',
#    'acute coronary syndrome',
#    'acute coronary syndrome'],
#   [[], [], [], [], [], [], [], [], [], [], [], []],
#   [['Rx',
#     'Plavix',
#     ['clopidogrel'],
#     ['platelet-aggregation-inhibitors'],
#     [],
#     'B',
#     'N'],
#    ['Rx',
#     'clopidogrel',
#     ['clopidogrel'],
#     ['platelet-aggregation-inhibitors'],
#     ['Plavix'],
#     'B',
#     'N'],
#    ['Rx',
#     'Effient',
#     ['prasugrel'],
#     ['platelet-aggregation-inhibitors'],
#     [],
#     'B',
#     'N'],
#    ['Rx',
#     'Brilinta',
#     ['ticagrelor'],
#     ['platelet-aggregation-inhibitors'],
#     [],
#     'C',
#     'N'],
#    ['Rx',
#     'ticagrelor',
#     ['ticagrelor'],
#     ['platelet-aggregation-inhibitors'],
#     ['Brilinta', 'Brilinta'],
#     'C',
#     'N'],
#    ['Rx',
#     'prasugrel',
#     ['prasugrel'],
#     ['platelet-aggregation-inhibitors'],
#     ['Effient'],
#     'B',
#     'N'],
#    ['Rx',
#     'enoxaparin',
#     ['enoxaparin'],
#     ['heparins'],
#     ['Lovenox', 'Lovenox HP', 'Clexane', 'Clexane Forte'],
#     'B',
#     'N'],
#    ['Rx', 'Lovenox', ['enoxaparin'], ['heparins'], [], 'B', 'N'],
#    ['Rx',
#     'Integrilin',
#     ['eptifibatide'],
#     ['glycoprotein-platelet-inhibitors'],
#     [],
#     'B',
#     'N'],
#    ['Rx',
#     'Aggrastat',
#     ['tirofiban'],
#     ['glycoprotein-platelet-inhibitors'],
#     ['Aggrastat'],
#     'B',
#     'N'],
#    ['Rx',
#     'eptifibatide',
#     ['eptifibatide'],
#     ['glycoprotein-platelet-inhibitors'],
#     ['Integrilin'],
#     'B',
#     'N'],
#    ['Rx',
#     'tirofiban',
#     ['tirofiban'],
#     ['glycoprotein-platelet-inhibitors'],
#     ['Aggrastat'],
#     'B',
#     'N']]],
#  [['acute disseminated encephalomyelitis'], [[]], []],
#  [['acute gout',
#    'acute gout',
#    'acute gout',
#    'acute gout',
#    'acute gout',
#    'acute gout',
#    'acute gout',
#    'acute gout',
#    'acute gout',
#    'acute gout',
#    'acute gout',
#    'acute gout',
#    'acute gout',
#    'acute gout',
#    'acute gout',
#    'acute gout',
#    'acute gout',
#    'acute gout',
#    'acute gout',
#    'acute gout',
#    'acute gout',
#    'acute gout',
#    'acute gout',
#    'acute gout',
#    'acute gout'],
#   [[],
#    [],
#    [],
#    [],
#    [],
#    [],
#    [],
#    [],
#    [],
#    [],
#    [],
#    [],
#    [],
#    [],
#    [],
#    [],
#    [],
#    [],
#    [],
#    [],
#    [],
#    [],
#    [],
#    [],
#    []],
#   [['Rx',
#     'colchicine',
#     ['colchicine'],
#     ['antigout-agents'],
#     ['Colcrys', 'Mitigare', 'Gloperba'],
#     'C',
#     'N'],
#    ['Rx',
#     'indomethacin',
#     ['indomethacin'],
#     ['nonsteroidal-anti-inflammatory-agents'],
#     ['Indocin', 'Indocin SR', 'Tivorbex'],
#     'C',
#     'N'],
#    ['Rx', 'Colcrys', ['colchicine'], ['antigout-agents'], [], 'C', 'N'],
#    ['Rx',
#     'Indocin',
#     ['indomethacin'],
#     ['nonsteroidal-anti-inflammatory-agents'],
#     ['Indocin', 'Indocin SR', 'Tivorbex'],
#     'C',
#     'N'],
#    ['Rx/OTC',
#     'naproxen',
#     ['naproxen'],
#     ['nonsteroidal-anti-inflammatory-agents'],
#     [],
#     'C',
#     'N'],
#    ['Rx/OTC',
#     'ibuprofen',
#     [],
#     ['nonsteroidal-anti-inflammatory-agents'],
#     [],
#     'C',
#     'N'],
#    ['Rx/OTC',
#     'Advil',
#     ['ibuprofen'],
#     ['nonsteroidal-anti-inflammatory-agents'],
#     [],
#     'C',
#     'N'],
#    ['Rx/OTC',
#     'Aleve',
#     ['naproxen'],
#     ['nonsteroidal-anti-inflammatory-agents'],
#     [],
#     'C',
#     'N'],
#    ['Rx',
#     'methylprednisolone',
#     ['methylprednisolone'],
#     ['glucocorticoids'],
#     [],
#     'C',
#     'N'],
#    ['Rx',
#     'MethylPREDNISolone Dose Pack',
#     ['methylprednisolone'],
#     ['glucocorticoids'],
#     ['Medrol', 'Medrol Dosepak', 'MethylPREDNISolone Dose Pack'],
#     'C',
#     'N'],
#    ['Rx/OTC',
#     'Naprosyn',
#     ['naproxen'],
#     ['nonsteroidal-anti-inflammatory-agents'],
#     [],
#     'C',
#     'N'],
#    ['Rx/OTC',
#     'Advil Liqui-Gels',
#     ['Ibuprofen Capsules'],
#     ['nonsteroidal-anti-inflammatory-agents'],
#     ['Advil Liqui-Gels'],
#     'C',
#     'N'],
#    ['Rx/OTC',
#     'Motrin',
#     ['ibuprofen'],
#     ['nonsteroidal-anti-inflammatory-agents'],
#     [],
#     'C',
#     'N'],
#    ['Rx/OTC',
#     'A-G Profen',
#     ['ibuprofen'],
#     ['nonsteroidal-anti-inflammatory-agents'],
#     [],
#     'C',
#     'N'],
#    ['Rx/OTC',
#     'Actiprofen',
#     ['ibuprofen'],
#     ['nonsteroidal-anti-inflammatory-agents'],
#     [],
#     'C',
#     'N'],
#    ['Rx/OTC',
#     'Addaprin',
#     ['ibuprofen'],
#     ['nonsteroidal-anti-inflammatory-agents'],
#     [],
#     'C',
#     'N'],
#    ['Rx/OTC',
#     'Anaprox',
#     ['naproxen'],
#     ['nonsteroidal-anti-inflammatory-agents'],
#     [],
#     'C',
#     'N'],
#    ['Rx',
#     'Clinoril',
#     ['sulindac'],
#     ['nonsteroidal-anti-inflammatory-agents'],
#     ['Clinoril'],
#     'C',
#     'N'],
#    ['Rx/OTC',
#     'Genpril',
#     ['ibuprofen'],
#     ['nonsteroidal-anti-inflammatory-agents'],
#     ['Advil',
#      'Genpril',
#      'IBU',
#      'Midol IB',
#      'Motrin IB',
#      'Proprinal',
#      "Smart Sense Children's Ibuprofen"],
#     'C',
#     'N'],
#    ['Rx/OTC',
#     'IBU-200',
#     ['ibuprofen'],
#     ['nonsteroidal-anti-inflammatory-agents'],
#     [],
#     'C',
#     'N'],
#    ['Rx/OTC',
#     'Midol IB',
#     ['ibuprofen'],
#     ['nonsteroidal-anti-inflammatory-agents'],
#     ['Advil',
#      'Genpril',
#      'IBU',
#      'Midol IB',
#      'Motrin IB',
#      'Proprinal',
#      "Smart Sense Children's Ibuprofen"],
#     'C',
#     'N'],
#    ['Rx/OTC',
#     'Motrin IB',
#     ['ibuprofen'],
#     ['nonsteroidal-anti-inflammatory-agents'],
#     ['Advil',
#      'Genpril',
#      'IBU',
#      'Midol IB',
#      'Motrin IB',
#      'Proprinal',
#      "Smart Sense Children's Ibuprofen"],
#     'C',
#     'N'],
#    ['Rx/OTC',
#     'Nuprin',
#     ['ibuprofen'],
#     ['nonsteroidal-anti-inflammatory-agents'],
#     [],
#     'C',
#     'N'],
#    ['Rx/OTC',
#     'Proprinal',
#     ['ibuprofen'],
#     ['nonsteroidal-anti-inflammatory-agents'],
#     ['Advil',
#      'Genpril',
#      'IBU',
#      'Midol IB',
#      'Motrin IB',
#      'Proprinal',
#      "Smart Sense Children's Ibuprofen"],
#     'C',
#     'N'],
#    ['Rx/OTC',
#     'Aflaxen',
#     ['naproxen'],
#     ['nonsteroidal-anti-inflammatory-agents'],
#     [],
#     'C',
#     'N']]],
#  [['acute lymphoblastic leukemia',
#    'acute lymphoblastic leukemia',
#    'acute lymphoblastic leukemia',
#    'acute lymphoblastic leukemia',
#    'acute lymphoblastic leukemia',
#    'acute lymphoblastic leukemia',
#    'acute lymphoblastic leukemia',
#    'acute lymphoblastic leukemia',
#    'acute lymphoblastic leukemia',
#    'acute lymphoblastic leukemia',
#    'acute lymphoblastic leukemia',
#    'acute lymphoblastic leukemia',
#    'acute lymphoblastic leukemia',
#    'acute lymphoblastic leukemia',
#    'acute lymphoblastic leukemia',
#    'acute lymphoblastic leukemia',
#    'acute lymphoblastic leukemia',
#    'acute lymphoblastic leukemia',
#    'acute lymphoblastic leukemia',
#    'acute lymphoblastic leukemia',
#    'acute lymphoblastic leukemia',
#    'acute lymphoblastic leukemia',
#    'acute lymphoblastic leukemia',
#    'acute lymphoblastic leukemia',
#    'acute lymphoblastic leukemia'],
#   [[],
#    [],
#    [],
#    [],
#    [],
#    [],
#    [],
#    [],
#    [],
#    [],
#    [],
#    [],
#    [],
#    [],
#    [],
#    [],
#    [],
#    [],
#    [],
#    [],
#    [],
#    [],
#    [],
#    [],
#    []],
#   [['Rx', 'methotrexate', ['methotrexate'], ['antimetabolites'], [], 'X', 'N'],
#    ['Rx',
#     'Gleevec',
#     ['imatinib'],
#     ['bcr-abl-tyrosine-kinase-inhibitors'],
#     [],
#     'D',
#     'N'],
#    ['Rx',
#     'mercaptopurine',
#     ['mercaptopurine'],
#     ['antimetabolites'],
#     ['Purixan', 'Purinethol'],
#     'D',
#     'N'],
#    ['Rx',
#     'Sprycel',
#     ['dasatinib'],
#     ['bcr-abl-tyrosine-kinase-inhibitors'],
#     [],
#     'D',
#     'N'],
#    ['Rx',
#     'Blincyto',
#     ['blinatumomab'],
#     ['miscellaneous-antineoplastics'],
#     ['Blincyto'],
#     'C',
#     'N'],
#    ['Rx',
#     'Adriamycin',
#     ['doxorubicin'],
#     ['antibiotics-antineoplastics'],
#     ['Adriamycin'],
#     'D',
#     'N'],
#    ['Rx',
#     'dasatinib',
#     ['dasatinib'],
#     ['bcr-abl-tyrosine-kinase-inhibitors'],
#     ['Sprycel'],
#     'D',
#     'N'],
#    ['Rx',
#     'pegaspargase',
#     ['pegaspargase'],
#     ['miscellaneous-antineoplastics'],
#     ['Oncaspar'],
#     'C',
#     'N'],
#    ['Rx',
#     'Trexall',
#     ['methotrexate'],
#     ['antimetabolites'],
#     ['Trexall', 'Xatmep'],
#     'X',
#     'N'],
#    ['Rx',
#     'Iclusig',
#     ['ponatinib'],
#     ['bcr-abl-tyrosine-kinase-inhibitors'],
#     [],
#     'D',
#     'N'],
#    ['Rx',
#     'doxorubicin',
#     ['doxorubicin'],
#     ['antibiotics-antineoplastics'],
#     ['Adriamycin', 'Adriamycin RDF', 'Rubex', 'Adriamycin PFS'],
#     'D',
#     'N'],
#    ['Rx',
#     'imatinib',
#     ['imatinib'],
#     ['bcr-abl-tyrosine-kinase-inhibitors'],
#     ['Gleevec'],
#     'D',
#     'N'],
#    ['Rx',
#     'Purinethol',
#     ['Mercaptopurine Tablets'],
#     ['antimetabolites'],
#     ['Purinethol'],
#     'D',
#     'N'],
#    ['Rx',
#     'Oncaspar',
#     ['pegaspargase'],
#     ['miscellaneous-antineoplastics'],
#     ['Oncaspar'],
#     'C',
#     'N'],
#    ['Rx',
#     'asparaginase erwinia chrysanthemi',
#     ['asparaginase Erwinia chrysanthemi'],
#     ['miscellaneous-antineoplastics'],
#     ['Erwinaze'],
#     'C',
#     'N'],
#    ['Rx',
#     'vincristine liposome',
#     ['vincristine liposome'],
#     ['mitotic-inhibitors'],
#     ['Marqibo'],
#     'D',
#     'N'],
#    ['Rx',
#     'Xatmep',
#     ['methotrexate'],
#     ['antimetabolites'],
#     ['Trexall', 'Xatmep'],
#     'X',
#     'N'],
#    ['Rx',
#     'blinatumomab',
#     ['blinatumomab'],
#     ['miscellaneous-antineoplastics'],
#     ['Blincyto'],
#     'C',
#     'N'],
#    ['Rx',
#     'Marqibo',
#     ['vincristine liposome'],
#     ['mitotic-inhibitors'],
#     [],
#     'D',
#     'N'],
#    ['Rx',
#     'ponatinib',
#     ['ponatinib'],
#     ['bcr-abl-tyrosine-kinase-inhibitors'],
#     ['Iclusig'],
#     'D',
#     'N'],
#    ['Rx',
#     'Erwinaze',
#     ['asparaginase Erwinia chrysanthemi'],
#     ['miscellaneous-antineoplastics'],
#     [],
#     'C',
#     'N'],
#    ['Rx', 'Arranon', ['nelarabine'], ['antimetabolites'], [], 'D', 'N'],
#    ['Rx',
#     'Besponsa',
#     ['inotuzumab ozogamicin'],
#     ['miscellaneous-antineoplastics'],
# ...
#     ['Isoproterenol'],
#     ['adrenergic-bronchodilators'],
#     ['Isuprel'],
#     'C',
#     'N'],
#    ['Rx/OTC',
#     'Adrenaclick',
#     ['epinephrine'],
#     ['adrenergic-bronchodilators'],
#     [],
#     'C',
#     'N'],
#    ['Rx',
#     'Isuprel',
#     ['Isoproterenol'],
#     ['adrenergic-bronchodilators'],
#     ['Isuprel'],
#     'C',
#     'N'],
#    ['Rx/OTC',
#     'Adrenalin Chloride',
#     ['epinephrine'],
#     ['adrenergic-bronchodilators'],
#     [],
#     'C',
#     'N']]],
#  [['addison s disease',
#    'addison s disease',
#    'addison s disease',
#    'addison s disease',
#    'addison s disease',
#    'addison s disease',
#    'addison s disease',
#    'addison s disease',
#    'addison s disease',
#    'addison s disease',
#    'addison s disease',
#    'addison s disease'],
#   [['Primary Adrenocortical Insufficiency'],
#    ['Primary Adrenocortical Insufficiency'],
#    ['Primary Adrenocortical Insufficiency'],
#    ['Primary Adrenocortical Insufficiency'],
#    ['Primary Adrenocortical Insufficiency'],
#    ['Primary Adrenocortical Insufficiency'],
#    ['Primary Adrenocortical Insufficiency'],
#    ['Primary Adrenocortical Insufficiency'],
#    ['Primary Adrenocortical Insufficiency'],
#    ['Primary Adrenocortical Insufficiency'],
#    ['Primary Adrenocortical Insufficiency'],
#    ['Primary Adrenocortical Insufficiency']],
#   [['Rx',
#     'hydrocortisone',
#     ['hydrocortisone'],
#     ['glucocorticoids'],
#     ['Cortef'],
#     'C',
#     'N'],
#    ['Rx',
#     'fludrocortisone',
#     ['fludrocortisone'],
#     ['mineralocorticoids'],
#     ['Florinef Acetate'],
#     'C',
#     'N'],
#    ['Rx', 'Florinef', [], ['mineralocorticoids'], [], 'C', 'N'],
#    ['Rx',
#     'Cortef',
#     ['hydrocortisone'],
#     ['glucocorticoids'],
#     ['Cortef'],
#     'C',
#     'N'],
#    ['Rx',
#     'dexamethasone',
#     ['dexamethasone'],
#     ['glucocorticoids'],
#     [],
#     'C',
#     'N'],
#    ['Rx',
#     'Florinef Acetate',
#     ['fludrocortisone'],
#     ['mineralocorticoids'],
#     ['Florinef Acetate'],
#     'C',
#     'N'],
#    ['Rx',
#     'Solu-Cortef',
#     ['hydrocortisone'],
#     ['glucocorticoids'],
#     ['Solu-CORTEF'],
#     'C',
#     'N'],
#    ['Rx',
#     'Dexamethasone Intensol',
#     ['dexamethasone'],
#     ['glucocorticoids'],
#     ['Baycadron',
#      'Dexamethasone Intensol',
#      'DexPak 10 Day Taperpak',
#      'DexPak 13 DayTaperpak',
#      'DexPak 6 DayTaperpak'],
#     'C',
#     'N'],
#    ['Rx',
#     'Dexpak Taperpak',
#     ['dexamethasone'],
#     ['glucocorticoids'],
#     ['Baycadron',
#      'Dexamethasone Intensol',
#      'DexPak 10 Day Taperpak',
#      'DexPak 13 DayTaperpak',
#      'DexPak 6 DayTaperpak'],
#     'C',
#     'N'],
#    ['Rx',
#     'De-Sone LA',
#     ['dexamethasone'],
#     ['glucocorticoids'],
#     ['De-Sone LA',
#      'Dexacen-4',
#      'Dexasone',
#      'Dexasone LA',
#      'Solurex',
#      'Solurex LA'],
#     'C',
#     'N'],
#    ['Rx',
#     'ZoDex',
#     ['Dexamethasone Tablets'],
#     ['glucocorticoids'],
#     ['ZoDex'],
#     'C',
#     'N'],
#    ['Rx', 'Dxevo', [], ['glucocorticoids'], [], 'C', 'N']]],
#  [['adenomyosis'], [['Uterine Endometriosis']], []],
#  [['adenosine deaminase deficiency',
#    'adenosine deaminase deficiency',
#    'adenosine deaminase deficiency'],
#   [['ADA Deficiency'], ['ADA Deficiency'], ['ADA Deficiency']],
#   [['Rx',
#     'Revcovi',
#     ['elapegademase'],
#     ['other-immunostimulants'],
#     ['Revcovi'],
#     [],
#     'N'],
#    ['Rx',
#     'pegademase bovine',
#     ['pegademase bovine'],
#     ['other-immunostimulants'],
#     ['Adagen'],
#     'C',
#     'N'],
#    ['Rx',
#     'elapegademase',
#     ['elapegademase'],
#     ['other-immunostimulants'],
#     ['Revcovi'],
#     [],
#     'N']]],
#  [['adenovirus prophylaxis'],
#   [[]],
#   [['Rx', 'adenovirus vaccine', [], ['viral-vaccines'], [], [], 'N']]],
#  [['adhesive arachnoiditis'], [[]], []],
#  [['adjunct to antibiotic therapy'],
#   [[]],
#   [['Rx',
#     'probenecid',
#     ['probenecid'],
#     ['antigout-agents'],
#     ['Benemid'],
#     'N',
#     'N']]],
#  [['adrenal cortical carcinoma', 'adrenal cortical carcinoma'],
#   [[], []],
#   [['Rx',
#     'mitotane',
#     ['mitotane'],
#     ['miscellaneous-antineoplastics'],
#     ['Lysodren'],
#     'D',
#     'N'],
#    ['Rx',
#     'Lysodren',
#     ['mitotane'],
#     ['miscellaneous-antineoplastics'],
#     ['Lysodren'],
#     'D',
#     'N']]],
#  [['adrenal gland disorders'], [[]], []],
#  [['adrenal hemorrhage'], [[]], []],
#  [['adrenal insufficiency',
#    'adrenal insufficiency',
#    'adrenal insufficiency',
#    'adrenal insufficiency',
#    'adrenal insufficiency',
#    'adrenal insufficiency',
#    'adrenal insufficiency',
#    'adrenal insufficiency'],
#   [['Adrenal crisis, acute; Adrenal failure; Adrenal insufficiency, exogenous'],
#    ['Adrenal crisis, acute; Adrenal failure; Adrenal insufficiency, exogenous'],
#    ['Adrenal crisis, acute; Adrenal failure; Adrenal insufficiency, exogenous'],
#    ['Adrenal crisis, acute; Adrenal failure; Adrenal insufficiency, exogenous'],
#    ['Adrenal crisis, acute; Adrenal failure; Adrenal insufficiency, exogenous'],
#    ['Adrenal crisis, acute; Adrenal failure; Adrenal insufficiency, exogenous'],
#    ['Adrenal crisis, acute; Adrenal failure; Adrenal insufficiency, exogenous'],
#    ['Adrenal crisis, acute; Adrenal failure; Adrenal insufficiency, exogenous']],
#   [['Rx',
#     'dexamethasone',
#     ['dexamethasone'],
#     ['glucocorticoids'],
#     [],
#     'C',
#     'N'],
#    ['Rx',
#     'cortisone',
#     ['cortisone'],
#     ['glucocorticoids'],
#     ['Cortone Acetate'],
#     'N',
#     'N'],
#    ['Rx',
#     'Dexamethasone Intensol',
#     ['dexamethasone'],
#     ['glucocorticoids'],
#     ['Baycadron',
#      'Dexamethasone Intensol',
#      'DexPak 10 Day Taperpak',
#      'DexPak 13 DayTaperpak',
#      'DexPak 6 DayTaperpak'],
#     'C',
#     'N'],
#    ['Rx',
#     'Cortone Acetate',
#     ['cortisone'],
#     ['glucocorticoids'],
#     ['Cortone Acetate'],
#     'N',
#     'N'],
#    ['Rx',
#     'Dexpak Taperpak',
#     ['dexamethasone'],
#     ['glucocorticoids'],
#     ['Baycadron',
#      'Dexamethasone Intensol',
#      'DexPak 10 Day Taperpak',
#      'DexPak 13 DayTaperpak',
#      'DexPak 6 DayTaperpak'],
#     'C',
#     'N'],
#    ['Rx',
#     'De-Sone LA',
#     ['dexamethasone'],
#     ['glucocorticoids'],
#     ['De-Sone LA',
#      'Dexacen-4',
#      'Dexasone',
#      'Dexasone LA',
#      'Solurex',
#      'Solurex LA'],
#     'C',
#     'N'],
#    ['Rx',
#     'ZoDex',
#     ['Dexamethasone Tablets'],
#     ['glucocorticoids'],
#     ['ZoDex'],
#     'C',
#     'N'],
#    ['Rx', 'Dxevo', [], ['glucocorticoids'], [], 'C', 'N']]],
#  [['adrenal tuberculosis'], [[]], []],
#  [['adrenal tumor'], [[]], []],
#  [['adrenocortical insufficiency',
#    'adrenocortical insufficiency',
#    'adrenocortical insufficiency',
#    'adrenocortical insufficiency',
#    'adrenocortical insufficiency',
#    'adrenocortical insufficiency',
#    'adrenocortical insufficiency',
#    'adrenocortical insufficiency',
#    'adrenocortical insufficiency',
#    'adrenocortical insufficiency',
#    'adrenocortical insufficiency',
#    'adrenocortical insufficiency',
#    'adrenocortical insufficiency'],
#   [[], [], [], [], [], [], [], [], [], [], [], [], []],
#   [['Rx',
#     'hydrocortisone',
#     ['hydrocortisone'],
#     ['glucocorticoids'],
#     ['Cortef'],
#     'C',
#     'N'],
#    ['Rx',
#     'Cortef',
#     ['hydrocortisone'],
#     ['glucocorticoids'],
#     ['Cortef'],
#     'C',
#     'N'],
#    ['Rx', 'prednisone', ['prednisone'], ['glucocorticoids'], [], 'C', 'N'],
#    ['Rx',
#     'dexamethasone',
#     ['dexamethasone'],
#     ['glucocorticoids'],
#     [],
#     'C',
#     'N'],
#    ['Rx',
#     'Solu-Cortef',
#     ['hydrocortisone'],
#     ['glucocorticoids'],
#     ['Solu-CORTEF'],
#     'C',
#     'N'],
#    ['Rx',
#     'triamcinolone',
#     ['triamcinolone'],
#     ['glucocorticoids'],
#     [],
#     'C',
#     'N'],
#    ['Rx',
#     'Cortrosyn',
#     ['cosyntropin'],
#     ['corticotropin'],
#     ['Cortrosyn'],
#     'C',
#     'N'],
#    ['Rx',
#     'Dexamethasone Intensol',
#     ['dexamethasone'],
#     ['glucocorticoids'],
#     ['Baycadron',
#      'Dexamethasone Intensol',
#      'DexPak 10 Day Taperpak',
#      'DexPak 13 DayTaperpak',
#      'DexPak 6 DayTaperpak'],
#     'C',
#     'N'],
#    ['Rx',
#     'Kenalog-40',
#     ['triamcinolone'],
#     ['glucocorticoids'],
#     ['Kenalog-40', 'Zilretta'],
#     'C',
#     'N'],
#    ['Rx',
#     'cosyntropin',
#     ['cosyntropin'],
#     ['corticotropin'],
#     ['Cortrosyn'],
#     'C',
#     'N'],
#    ['Rx',
#     'De-Sone LA',
#     ['dexamethasone'],
#     ['glucocorticoids'],
#     ['De-Sone LA',
#      'Dexacen-4',
#      'Dexasone',
#      'Dexasone LA',
#      'Solurex',
#      'Solurex LA'],
#     'C',
#     'N'],
#    ['Rx',
#     'Dexpak Taperpak',
#     ['dexamethasone'],
#     ['glucocorticoids'],
#     ['Baycadron',
#      'Dexamethasone Intensol',
#      'DexPak 10 Day Taperpak',
#      'DexPak 13 DayTaperpak',
#      'DexPak 6 DayTaperpak'],
#     'C',
#     'N'],
#    ['Rx', 'Dxevo', [], ['glucocorticoids'], [], 'C', 'N']]],
#  [['adrenogenital syndrome',
#    'adrenogenital syndrome',
#    'adrenogenital syndrome',
#    'adrenogenital syndrome',
#    'adrenogenital syndrome',
#    'adrenogenital syndrome',
#    'adrenogenital syndrome',
#    'adrenogenital syndrome',
#    'adrenogenital syndrome',
#    'adrenogenital syndrome',
#    'adrenogenital syndrome',
#    'adrenogenital syndrome',
#    'adrenogenital syndrome',
#    'adrenogenital syndrome',
#    'adrenogenital syndrome',
#    'adrenogenital syndrome'],
#   [['21-hydroxylase deficiency; Congenital Adrenal Hyperplasia'],
#    ['21-hydroxylase deficiency; Congenital Adrenal Hyperplasia'],
#    ['21-hydroxylase deficiency; Congenital Adrenal Hyperplasia'],
#    ['21-hydroxylase deficiency; Congenital Adrenal Hyperplasia'],
#    ['21-hydroxylase deficiency; Congenital Adrenal Hyperplasia'],
#    ['21-hydroxylase deficiency; Congenital Adrenal Hyperplasia'],
#    ['21-hydroxylase deficiency; Congenital Adrenal Hyperplasia'],
#    ['21-hydroxylase deficiency; Congenital Adrenal Hyperplasia'],
#    ['21-hydroxylase deficiency; Congenital Adrenal Hyperplasia'],
#    ['21-hydroxylase deficiency; Congenital Adrenal Hyperplasia'],
#    ['21-hydroxylase deficiency; Congenital Adrenal Hyperplasia'],
#    ['21-hydroxylase deficiency; Congenital Adrenal Hyperplasia'],
#    ['21-hydroxylase deficiency; Congenital Adrenal Hyperplasia'],
#    ['21-hydroxylase deficiency; Congenital Adrenal Hyperplasia'],
#    ['21-hydroxylase deficiency; Congenital Adrenal Hyperplasia'],
#    ['21-hydroxylase deficiency; Congenital Adrenal Hyperplasia']],
#   [['Rx',
#     'fludrocortisone',
#     ['fludrocortisone'],
#     ['mineralocorticoids'],
#     ['Florinef Acetate'],
#     'C',
#     'N'],
#    ['Rx', 'Florinef', [], ['mineralocorticoids'], [], 'C', 'N'],
#    ['Rx', 'prednisone', ['prednisone'], ['glucocorticoids'], [], 'C', 'N'],
#    ['Rx',
#     'dexamethasone',
#     ['dexamethasone'],
#     ['glucocorticoids'],
#     [],
#     'C',
#     'N'],
#    ['Rx',
#     'methylprednisolone',
#     ['methylprednisolone'],
#     ['glucocorticoids'],
#     [],
#     'C',
#     'N'],
#    ['Rx',
#     'Florinef Acetate',
#     ['fludrocortisone'],
#     ['mineralocorticoids'],
#     ['Florinef Acetate'],
#     'C',
#     'N'],
#    ['Rx',
#     'Depo-Medrol',
#     ['methylprednisolone'],
#     ['glucocorticoids'],
#     ['A-Methapred', 'DEPO-Medrol', 'SOLU-Medrol'],
#     'C',
#     'N'],
#    ['Rx',
#     'Dexamethasone Intensol',
#     ['dexamethasone'],
#     ['glucocorticoids'],
#     ['Baycadron',
#      'Dexamethasone Intensol',
#      'DexPak 10 Day Taperpak',
#      'DexPak 13 DayTaperpak',
#      'DexPak 6 DayTaperpak'],
#     'C',
#     'N'],
#    ['Rx',
#     'MethylPREDNISolone Dose Pack',
#     ['methylprednisolone'],
#     ['glucocorticoids'],
#     ['Medrol', 'Medrol Dosepak', 'MethylPREDNISolone Dose Pack'],
#     'C',
#     'N'],
#    ['Rx',
#     'Medrol Dosepak',
#     ['methylprednisolone'],
#     ['glucocorticoids'],
#     ['Medrol', 'Medrol Dosepak', 'MethylPREDNISolone Dose Pack'],
#     'C',
#     'N'],
#    ['Rx',
#     'Solu-Medrol',
#     ['methylprednisolone'],
#     ['glucocorticoids'],
#     ['A-Methapred', 'DEPO-Medrol', 'SOLU-Medrol'],
#     'C',
#     'N'],
#    ['Rx',
#     'Medrol',
#     ['methylprednisolone'],
#     ['glucocorticoids'],
#     ['Medrol', 'Medrol Dosepak', 'MethylPREDNISolone Dose Pack'],
#     'C',
#     'N'],
#    ['Rx',
#     'De-Sone LA',
#     ['dexamethasone'],
#     ['glucocorticoids'],
#     ['De-Sone LA',
#      'Dexacen-4',
#      'Dexasone',
#      'Dexasone LA',
#      'Solurex',
#      'Solurex LA'],
#     'C',
#     'N'],
#    ['Rx',
#     'Dexpak Taperpak',
#     ['dexamethasone'],
#     ['glucocorticoids'],
#     ['Baycadron',
#      'Dexamethasone Intensol',
#      'DexPak 10 Day Taperpak',
#      'DexPak 13 DayTaperpak',
#      'DexPak 6 DayTaperpak'],
#     'C',
#     'N'],
#    ['Rx',
#     'ZoDex',
#     ['Dexamethasone Tablets'],
#     ['glucocorticoids'],
#     ['ZoDex'],
#     'C',
#     'N'],
#    ['Rx', 'Dxevo', [], ['glucocorticoids'], [], 'C', 'N']]],
#  [['adult human growth hormone deficiency',
#    'adult human growth hormone deficiency',
#    'adult human growth hormone deficiency',
#    'adult human growth hormone deficiency',
#    'adult human growth hormone deficiency',
#    'adult human growth hormone deficiency',
#    'adult human growth hormone deficiency',
#    'adult human growth hormone deficiency',
#    'adult human growth hormone deficiency'],
#   [[], [], [], [], [], [], [], [], []],
#   [['Rx',
#     'somatropin',
#     ['somatropin'],
#     ['growth-hormones'],
#     ['Genotropin',
#      'Humatrope',
#      'Norditropin FlexPro Pen',
#      'Nutropin AQ NuSpin 10',
#      'Omnitrope',
#      'Saizen',
#      'Serostim',
#      'Zomacton',
#      'Zorbtive',
#      'Norditropin',
#      'Nutropin AQ',
#      'Nutropin Depot',
#      'Norditropin Cartridge',
#      'Genotropin Miniquick',
#      'Tev-tropin',
#      'Norditropin Nordiflex Pen',
#      'Saizen Click-Easy',
#      'Omnitrope Pen 5 Cartridge',
#      'HumatroPen',
#      'Omnitrope Pen 10 Cartridge',
#      'Nutropin AQ Pen 20 Cartridge',
#      'Nutropin AQ Pen 10 Cartridge',
#      'Nutropin AQ NuSpin 5',
#      'Nutropin AQ NuSpin 20',
#      'Saizen Kit',
#      'Nutropin',
#      'Norditropin',
#      'Nutropin AQ',
#      'Nutropin Depot',
#      'Norditropin Cartridge',
#      'Genotropin Miniquick',
#      'Tev-tropin',
#      'Norditropin Nordiflex Pen',
#      'Saizen Click-Easy',
#      'Omnitrope Pen 5 Cartridge',
#      'HumatroPen',
#      'Omnitrope Pen 10 Cartridge',
#      'Nutropin AQ Pen 20 Cartridge',
#      'Nutropin AQ Pen 10 Cartridge',
#      'Nutropin AQ NuSpin 5',
#      'Nutropin AQ NuSpin 20',
#      'Saizen Kit'],
#     'C',
#     'N'],
#    ['Rx',
#     'Genotropin',
#     ['somatropin'],
#     ['growth-hormones'],
#     ['Genotropin',
#      'Humatrope',
#      'Norditropin FlexPro Pen',
#      'Nutropin AQ NuSpin 10',
#      'Omnitrope',
#      'Saizen',
#      'Serostim',
#      'Zomacton',
#      'Zorbtive'],
#     'C',
#     'N'],
#    ['Rx',
#     'Saizen',
#     ['somatropin'],
#     ['growth-hormones'],
#     ['Genotropin',
#      'Humatrope',
#      'Norditropin FlexPro Pen',
#      'Nutropin AQ NuSpin 10',
#      'Omnitrope',
#      'Saizen',
#      'Serostim',
#      'Zomacton',
#      'Zorbtive'],
#     'C',
#     'N'],
#    ['Rx',
#     'Humatrope',
#     ['somatropin'],
#     ['growth-hormones'],
#     ['Genotropin',
#      'Humatrope',
#      'Norditropin FlexPro Pen',
#      'Nutropin AQ NuSpin 10',
#      'Omnitrope',
#      'Saizen',
#      'Serostim',
#      'Zomacton',
#      'Zorbtive'],
#     'C',
#     'N'],
#    ['Rx',
#     'Norditropin FlexPro',
#     ['somatropin'],
#     ['growth-hormones'],
#     ['Genotropin',
#      'Humatrope',
#      'Norditropin FlexPro Pen',
#      'Nutropin AQ NuSpin 10',
#      'Omnitrope',
#      'Saizen',
#      'Serostim',
#      'Zomacton',
#      'Zorbtive'],
#     'C',
#     'N'],
#    ['Rx',
#     'Nutropin AQ',
#     ['somatropin'],
#     ['growth-hormones'],
#     ['Genotropin',
#      'Humatrope',
#      'Norditropin FlexPro Pen',
#      'Nutropin AQ NuSpin 10',
#      'Omnitrope',
#      'Saizen',
#      'Serostim',
#      'Zomacton',
#      'Zorbtive'],
#     'C',
#     'N'],
#    ['Rx', 'Omnitrope', ['somatropin'], ['growth-hormones'], [], 'C', 'N'],
#    ['Rx',
#     'Nutropin',
#     ['somatropin', 'mammalian derived'],
#     ['growth-hormones'],
#     [],
#     'C',
#     'N'],
#    ['Rx',
#     'Zomacton',
#     ['somatropin'],
#     ['growth-hormones'],
#     ['Genotropin',
#      'Humatrope',
#      'Norditropin FlexPro Pen',
#      'Nutropin AQ NuSpin 10',
#      'Omnitrope',
#      'Saizen',
#      'Serostim',
#      'Zomacton',
#      'Zorbtive'],
#     'C',
#     'N']]],
#  [['diabetes'], [[]], []],
#  [['fibromyalgia'], [[]], []]]

# %%
output_lst_copy[8]
# Out:
# [['abortion',
#   'abortion',
#   'abortion',
#   'abortion',
#   'abortion',
#   'abortion',
#   'abortion',
#   'abortion',
#   'abortion',
#   'abortion',
#   'abortion',
#   'abortion'],
#  [['Complete Abortion'],
#   ['Complete Abortion'],
#   ['Complete Abortion'],
#   ['Complete Abortion'],
#   ['Complete Abortion'],
#   ['Complete Abortion'],
#   ['Complete Abortion'],
#   ['Complete Abortion'],
#   ['Complete Abortion'],
#   ['Complete Abortion'],
#   ['Complete Abortion'],
#   ['Complete Abortion']],
#  [['Rx',
#    'misoprostol',
#    ['misoprostol'],
#    ['miscellaneous-gi-agents'],
#    ['Cytotec'],
#    'X',
#    'N'],
#   ['Rx',
#    'Cytotec',
#    ['misoprostol'],
#    ['miscellaneous-gi-agents'],
#    ['Cytotec'],
#    'X',
#    'N'],
#   ['Rx',
#    'mifepristone',
#    ['mifepristone'],
#    ['progesterone-receptor-modulators'],
#    ['Korlym'],
#    'X',
#    'N'],
#   ['Rx',
#    'oxytocin',
#    ['oxytocin'],
#    ['uterotonic-agents'],
#    ['Pitocin', 'Syntocinon'],
#    'X',
#    'N'],
#   ['Rx',
#    'Pitocin',
#    ['oxytocin'],
#    ['uterotonic-agents'],
#    ['Pitocin'],
#    'X',
#    'N'],
#   ['Rx',
#    'Mifeprex',
#    ['mifepristone'],
#    ['progesterone-receptor-modulators'],
#    ['Mifeprex'],
#    'X',
#    'N'],
#   ['Rx',
#    'Hemabate',
#    ['carboprost'],
#    ['uterotonic-agents'],
#    ['Hemabate'],
#    'C',
#    'N'],
#   ['Rx',
#    'carboprost',
#    ['carboprost'],
#    ['uterotonic-agents'],
#    ['Hemabate'],
#    'C',
#    'N'],
#   ['Rx',
#    'Cervidil',
#    ['dinoprostone topical'],
#    ['uterotonic-agents'],
#    ['Cervidil', 'Prepidil', 'Prostin E2'],
#    'C',
#    'N'],
#   ['Rx',
#    'Prostin E2',
#    ['dinoprostone topical'],
#    ['uterotonic-agents'],
#    ['Cervidil', 'Prepidil', 'Prostin E2'],
#    'C',
#    'N'],
#   ['Rx',
#    'dinoprostone',
#    ['dinoprostone topical'],
#    ['uterotonic-agents'],
#    ['Cervidil', 'Prepidil', 'Prostin E2'],
#    'C',
#    'N'],
#   ['Rx',
#    'Prepidil',
#    ['dinoprostone topical'],
#    ['uterotonic-agents'],
#    ['Cervidil', 'Prepidil', 'Prostin E2'],
#    'C',
#    'N']]]

# %%
import csv
with open("output/output_full.csv", 'w') as file:
        pen = csv.writer(file)
        # header
        pen.writerow(["disease name", "other names", "RX/OTC", "drug", "generic name", "drug class", "brand names", "pregnancy label", "CSA label"])
        
        # every row is a medication
        for row in output_lst_copy:
            for i in range(len(row[0])):
                if row[2]:
                    pen.writerow([row[0][i],row[1][i],row[2][i][0],row[2][i][1],row[2][i][2],
                                  row[2][i][3],row[2][i][4],row[2][i][5],row[2][i][6]])
                else:
                    pen.writerow([row[0][i],row[1][i]])

file.close()
